# %%
import dask
dask.config.set({"dataframe.query-planning": False})

import numpy as np
import pandas as pd
import sys
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.patches import Patch
import itertools
import gseapy as gp
import PyComplexHeatmap as pch
from PyComplexHeatmap import HeatmapAnnotation, DotClustermapPlotter, anno_simple, anno_label
from scipy.stats import zscore
from tqdm import tqdm
from pathlib import Path

sys.path.append("../../../workflow/scripts/")
import _utils
import readwrite
cfg = readwrite.config()
sns.set_style('ticks')

import matplotlib as mpl

mpl.rcParams.update(
    {
        "pdf.fonttype": 42,  # embed TrueType fonts (keeps text as text)
        "ps.fonttype": 42,
        "svg.fonttype": "none",  # if exporting SVG
        "text.usetex": False,
        "font.family": "sans-serif",
        "font.sans-serif": ["DejaVu Sans"],
        "savefig.transparent": True,
    }
)


def get_top_n_genes(group,n=20,value_vars=None,agg_func='mean',ascending=False):
    '''Sort each row by descending value, keep top n '''

    if value_vars is None:
        value_vars = group.columns

    if len(group) == 1:
        top = group.iloc[0][value_vars].dropna()
    else:
        if agg_func=='mean':
            top = group[value_vars].mean()
        elif agg_func=='median':
            top = group[value_vars].median()
        else:
            raise ValueError('unrecognized agg_func')

    if ascending:
        top_genes = top.nsmallest(n).index.tolist()
    else:
        top_genes = top.nlargest(n).index.tolist()
    
    return top_genes


def winsorize_asymmetric(data, neg_q=0.01, pos_q=0.99, return_data=False):
    data = np.asarray(data)
    negative_vals = data[data < 0]
    positive_vals = data[data > 0]

    # compute separate thresholds
    neg_clip = np.quantile(negative_vals, neg_q) if negative_vals.size > 0 else None
    pos_clip = np.quantile(positive_vals, pos_q) if positive_vals.size > 0 else None

    # clip 
    if return_data:
        clipped = data.copy()
        if neg_clip is not None:
            clipped[data < neg_clip] = neg_clip
        if pos_clip is not None:
            clipped[data > pos_clip] = pos_clip
        return clipped
    else:
        return neg_clip, pos_clip

def get_df_gsea(df,gene_sets,id_vars,min_size=0):

    def _filter_gene_sets(gene_sets, rnk):
        ''' avoid empty or NaN gene sets'''
        gene_sets_filtered = {}

        for k, gset in gene_sets.items():
            gset_found = [g for g in gset if g in rnk.index]
            gset_rnk = rnk.loc[gset_found]

            if len(gset_found) == 0 or  gset_rnk.sum() == 0 or gset_rnk.isna().all():
                continue
            else:
                gene_sets_filtered[k] = gset_found

        return gene_sets_filtered

    df_gsea = {}
    for i, row in tqdm(df.iterrows(),total=len(df)):
        rnk = row[len(id_vars):].astype(float)
        gene_sets_filtered = _filter_gene_sets(gene_sets=gene_sets, rnk=rnk)
        
        df_gsea[tuple(row[id_vars])] = gp.prerank(rnk=rnk, # Your ranked gene list
                            ascending=False,
                            gene_sets=gene_sets_filtered, # Or path to GMT file(s)
                            min_size=min_size,
                            ).res2d

    df_gsea = pd.concat(df_gsea).reset_index()
    value_vars = df_gsea.columns[len(id_vars):].tolist()
    df_gsea.columns = id_vars + value_vars
    df_gsea['Term'] = df_gsea['Term'].str.replace('0__','')
    return df_gsea

# %% [markdown]
# # Params

# %%
# cfg paths
xenium_processed_data_dir = Path(cfg['xenium_processed_data_dir'])
xenium_count_correction_dir = Path(cfg['xenium_count_correction_dir'])
xenium_std_seurat_analysis_dir = Path(cfg['xenium_std_seurat_analysis_dir'])
xenium_cell_type_annotation_dir = Path(cfg['xenium_cell_type_annotation_dir'])
results_dir = Path(cfg['results_dir'])
palette_dir = Path(cfg['xenium_metadata_dir'])
std_seurat_analysis_dir = Path(cfg['xenium_std_seurat_analysis_dir'])
scrnaseq_processed_data_dir = Path(cfg['scrnaseq_processed_data_dir'])
seurat_to_h5_dir = results_dir / 'seurat_to_h5'

# Params
use_batch = True
signal_integrity_thresholds = [0.5, 0.7]
correction_methods = ['raw','split_fully_purified',f'resolvi_panel_{use_batch=}',f'resolvi_panel_supervised_{use_batch=}']
correction_methods += [f'ovrlpy_correction_{signal_integrity_threshold=}' for signal_integrity_threshold in signal_integrity_thresholds]
num_samples = 30
mixture_k = 50
normalisation = 'lognorm'
layer = 'data'
reference = 'matched_reference_combo'
method = 'rctd_class_aware'
level = 'Level2.1'
segmentation_palette = pd.read_csv(palette_dir / 'col_palette_segmentation.csv', index_col=0).iloc[:, 0]
count_correction_palette = pd.read_csv(palette_dir / 'col_palette_correction_method.csv', index_col=0).iloc[:, 0]
sample_palette = pd.read_csv(palette_dir / 'col_palette_sample.csv', index_col=0).iloc[:, 0]

list_n_markers = [10, 20, 30, 40, 50]
radius = 15
n_neighbors = 15
n_permutations = 30
n_splits= 5
n_repeats = 5
top_n = 20
scoring = 'precision'
markers_mode = 'diffexpr'
cv_mode = 'spatial'

xenium_levels = ["segmentation", "condition", "panel", "donor", "sample"]
order = ['breast','chuvio','lung','5k']

hue_segmentation = "segmentation"
hue_segmentation_order = [
    "MM 0µm",
    "MM",
    "MM 15µm",
    "0µm",
    "5µm",
    "15µm",
    "Baysor",
    "ProSeg",
    "ProSeg mode",
    "Segger",
]

hue_correction = 'correction_method'
hue_correction_order = [
    'raw',
    'ResolVI',
    'ResolVI supervised',
    'ovrlpy 0.5',
    'ovrlpy 0.7',
    'SPLIT',
]

rank_metrics = ["importances"]
plot_metrics = ['hypergeometric_pvalue','NES',f"n_hits_{top_n=}"]
labels_key = level

# %% [markdown]
# # Load results diffexpr

# %%
dfs_diffexpr = readwrite.read_contamination_metrics_results(
    results_dir,
    correction_methods,
    xenium_std_seurat_analysis_dir,
    reference,
    method,
    level,
    mixture_k,
    num_samples,
    normalisation,
    layer,
    markers_mode=markers_mode,
    radius=radius,
    top_n=top_n,
    
    evaluation='diffexpr',
    genes_name='all',#'Xenium_hLung_v1_metadata',

)
# Out:
# Using Level1 for melanoma
# Using external_reference for melanoma
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_top_n=20/all/raw/proseg_expected/PDAC/immuno_oncology/pdacdonor1/pdacdonor1/lognorm/data_matched_reference_combo_rctd_class_aware_Level2.1_marker_genes.parquet
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_top_n=20/all/raw/proseg_expected/PDAC/immuno_oncology/pdacdonor1/pdacdonor1/lognorm/data_matched_reference_combo_rctd_class_aware_Level2.1_diffexpr.parquet
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_top_n=20/all/raw/proseg_expected/PDAC/immuno_oncology/pdacdonor1/pdacdonor1/lognorm/data_matched_reference_combo_rctd_class_aware_Level2.1_markers_rank_significance_diffexpr.parquet
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_top_n=20/all/raw/proseg_expected/PDAC/immuno_oncology/pdacdonor1/pdacdonor1/lognorm/data_matched_reference_combo_rctd_class_aware_Level2.1_summary_stats.json
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_top_n=20/all/raw/proseg_expected/melanoma/5k/mlndonor2/mlndonor2/lognorm/data_external_reference_rctd_class_aware_Level1_marker_genes.parquet
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_top_n=20/all/raw/proseg_expected/melanoma/5k/mlndonor2/mlndonor2/lognorm/data_external_reference_rctd_class_aware_Level1_diffexpr.parquet
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_top_n=20/all/raw/proseg_expected/melanoma/5k/mlndonor2/mlndonor2/lognorm/data_external_reference_rctd_class_aware_Level1_markers_rank_significance_diffexpr.parquet
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_top_n=20/all/raw/proseg_expected/melanoma/5k/mlndonor2/mlndonor2/lognorm/data_external_reference_rctd_class_aware_Level1_summary_stats.json
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_top_n=20/all/raw/proseg_expected/melanoma/skin/mlndonor1/mlndonor1/lognorm/data_external_reference_rctd_class_aware_Level1_marker_genes.parquet
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_top_n=20/all/raw/proseg_expected/melanoma/skin/mlndonor1/mlndonor1/lognorm/data_external_reference_rctd_class_aware_Level1_diffexpr.parquet
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_top_n=20/all/raw/proseg_expected/melanoma/skin/mlndonor1/mlndonor1/lognorm/data_external_reference_rctd_class_aware_Level1_markers_rank_significance_diffexpr.parquet
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_top_n=20/all/raw/proseg_expected/melanoma/skin/mlndonor1/mlndonor1/lognorm/data_external_reference_rctd_class_aware_Level1_summary_stats.json
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_top_n=20/all/raw/proseg_expected/CRC/immuno_oncology/crcdonor1/crcdonor1/lognorm/data_matched_reference_combo_rctd_class_aware_Level2.1_marker_genes.parquet
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_top_n=20/all/raw/proseg_expected/CRC/immuno_oncology/crcdonor1/crcdonor1/lognorm/data_matched_reference_combo_rctd_class_aware_Level2.1_diffexpr.parquet
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_top_n=20/all/raw/proseg_expected/CRC/immuno_oncology/crcdonor1/crcdonor1/lognorm/data_matched_reference_combo_rctd_class_aware_Level2.1_markers_rank_significance_diffexpr.parquet
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_top_n=20/all/raw/proseg_expected/CRC/immuno_oncology/crcdonor1/crcdonor1/lognorm/data_matched_reference_combo_rctd_class_aware_Level2.1_summary_stats.json
# Processing futures:   6%|▌         | 133/2160 [00:09<01:43, 19.57it/s]
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_top_n=20/all/raw/10x_5um/PDAC/immuno_oncology/pdacdonor1/pdacdonor1/lognorm/data_matched_reference_combo_rctd_class_aware_Level2.1_marker_genes.parquet
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_top_n=20/all/raw/10x_5um/PDAC/immuno_oncology/pdacdonor1/pdacdonor1/lognorm/data_matched_reference_combo_rctd_class_aware_Level2.1_diffexpr.parquet
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_top_n=20/all/raw/10x_5um/PDAC/immuno_oncology/pdacdonor1/pdacdonor1/lognorm/data_matched_reference_combo_rctd_class_aware_Level2.1_markers_rank_significance_diffexpr.parquet
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_top_n=20/all/raw/10x_5um/PDAC/immuno_oncology/pdacdonor1/pdacdonor1/lognorm/data_matched_reference_combo_rctd_class_aware_Level2.1_summary_stats.json
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_top_n=20/all/raw/10x_5um/melanoma/5k/mlndonor2/mlndonor2/lognorm/data_external_reference_rctd_class_aware_Level1_marker_genes.parquet
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_top_n=20/all/raw/10x_5um/melanoma/5k/mlndonor2/mlndonor2/lognorm/data_external_reference_rctd_class_aware_Level1_diffexpr.parquet
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_top_n=20/all/raw/10x_5um/melanoma/5k/mlndonor2/mlndonor2/lognorm/data_external_reference_rctd_class_aware_Level1_markers_rank_significance_diffexpr.parquet
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_top_n=20/all/raw/10x_5um/melanoma/5k/mlndonor2/mlndonor2/lognorm/data_external_reference_rctd_class_aware_Level1_summary_stats.json
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_top_n=20/all/raw/10x_5um/melanoma/skin/mlndonor1/mlndonor1/lognorm/data_external_reference_rctd_class_aware_Level1_marker_genes.parquet
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_top_n=20/all/raw/10x_5um/melanoma/skin/mlndonor1/mlndonor1/lognorm/data_external_reference_rctd_class_aware_Level1_diffexpr.parquet
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_top_n=20/all/raw/10x_5um/melanoma/skin/mlndonor1/mlndonor1/lognorm/data_external_reference_rctd_class_aware_Level1_markers_rank_significance_diffexpr.parquet
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_top_n=20/all/raw/10x_5um/melanoma/skin/mlndonor1/mlndonor1/lognorm/data_external_reference_rctd_class_aware_Level1_summary_stats.json
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_top_n=20/all/raw/10x_5um/CRC/immuno_oncology/crcdonor1/crcdonor1/lognorm/data_matched_reference_combo_rctd_class_aware_Level2.1_marker_genes.parquet
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_top_n=20/all/raw/10x_5um/CRC/immuno_oncology/crcdonor1/crcdonor1/lognorm/data_matched_reference_combo_rctd_class_aware_Level2.1_diffexpr.parquet
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_top_n=20/all/raw/10x_5um/CRC/immuno_oncology/crcdonor1/crcdonor1/lognorm/data_matched_reference_combo_rctd_class_aware_Level2.1_markers_rank_significance_diffexpr.parquet
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_top_n=20/all/raw/10x_5um/CRC/immuno_oncology/crcdonor1/crcdonor1/lognorm/data_matched_reference_combo_rctd_class_aware_Level2.1_summary_stats.json
# Processing futures:  11%|█         | 228/2160 [00:18<03:57,  8.13it/s]
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_top_n=20/all/raw/10x_mm_5um/melanoma/5k/mlndonor2/mlndonor2/lognorm/data_external_reference_rctd_class_aware_Level1_marker_genes.parquet
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_top_n=20/all/raw/10x_mm_5um/melanoma/5k/mlndonor2/mlndonor2/lognorm/data_external_reference_rctd_class_aware_Level1_diffexpr.parquet
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_top_n=20/all/raw/10x_mm_5um/melanoma/5k/mlndonor2/mlndonor2/lognorm/data_external_reference_rctd_class_aware_Level1_markers_rank_significance_diffexpr.parquet
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_top_n=20/all/raw/10x_mm_5um/melanoma/5k/mlndonor2/mlndonor2/lognorm/data_external_reference_rctd_class_aware_Level1_summary_stats.json
# Processing futures:  14%|█▍        | 311/2160 [00:26<01:56, 15.88it/s]
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_top_n=20/all/raw/10x_0um/PDAC/immuno_oncology/pdacdonor1/pdacdonor1/lognorm/data_matched_reference_combo_rctd_class_aware_Level2.1_marker_genes.parquet
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_top_n=20/all/raw/10x_0um/PDAC/immuno_oncology/pdacdonor1/pdacdonor1/lognorm/data_matched_reference_combo_rctd_class_aware_Level2.1_diffexpr.parquet
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_top_n=20/all/raw/10x_0um/PDAC/immuno_oncology/pdacdonor1/pdacdonor1/lognorm/data_matched_reference_combo_rctd_class_aware_Level2.1_markers_rank_significance_diffexpr.parquet
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_top_n=20/all/raw/10x_0um/PDAC/immuno_oncology/pdacdonor1/pdacdonor1/lognorm/data_matched_reference_combo_rctd_class_aware_Level2.1_summary_stats.json
# Processing futures:  15%|█▌        | 324/2160 [00:26<01:08, 26.96it/s]
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_top_n=20/all/raw/10x_0um/melanoma/5k/mlndonor2/mlndonor2/lognorm/data_external_reference_rctd_class_aware_Level1_marker_genes.parquet
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_top_n=20/all/raw/10x_0um/melanoma/5k/mlndonor2/mlndonor2/lognorm/data_external_reference_rctd_class_aware_Level1_diffexpr.parquet
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_top_n=20/all/raw/10x_0um/melanoma/5k/mlndonor2/mlndonor2/lognorm/data_external_reference_rctd_class_aware_Level1_markers_rank_significance_diffexpr.parquet
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_top_n=20/all/raw/10x_0um/melanoma/5k/mlndonor2/mlndonor2/lognorm/data_external_reference_rctd_class_aware_Level1_summary_stats.json
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_top_n=20/all/raw/10x_0um/melanoma/skin/mlndonor1/mlndonor1/lognorm/data_external_reference_rctd_class_aware_Level1_marker_genes.parquet
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_top_n=20/all/raw/10x_0um/melanoma/skin/mlndonor1/mlndonor1/lognorm/data_external_reference_rctd_class_aware_Level1_diffexpr.parquet
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_top_n=20/all/raw/10x_0um/melanoma/skin/mlndonor1/mlndonor1/lognorm/data_external_reference_rctd_class_aware_Level1_markers_rank_significance_diffexpr.parquet
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_top_n=20/all/raw/10x_0um/melanoma/skin/mlndonor1/mlndonor1/lognorm/data_external_reference_rctd_class_aware_Level1_summary_stats.json
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_top_n=20/all/raw/10x_0um/CRC/immuno_oncology/crcdonor1/crcdonor1/lognorm/data_matched_reference_combo_rctd_class_aware_Level2.1_marker_genes.parquet
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_top_n=20/all/raw/10x_0um/CRC/immuno_oncology/crcdonor1/crcdonor1/lognorm/data_matched_reference_combo_rctd_class_aware_Level2.1_diffexpr.parquet
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_top_n=20/all/raw/10x_0um/CRC/immuno_oncology/crcdonor1/crcdonor1/lognorm/data_matched_reference_combo_rctd_class_aware_Level2.1_markers_rank_significance_diffexpr.parquet
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_top_n=20/all/raw/10x_0um/CRC/immuno_oncology/crcdonor1/crcdonor1/lognorm/data_matched_reference_combo_rctd_class_aware_Level2.1_summary_stats.json
# Processing futures:  17%|█▋        | 375/2160 [00:31<01:43, 17.27it/s]
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_top_n=20/all/split_fully_purified/proseg_expected/PDAC/immuno_oncology/pdacdonor1/pdacdonor1/lognorm/reference_based/matched_reference_combo/rctd_class_aware/Level2.1/single_cell/split_fully_purified/lognorm/data_matched_reference_combo_rctd_class_aware_Level2.1_marker_genes.parquet
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_top_n=20/all/split_fully_purified/proseg_expected/PDAC/immuno_oncology/pdacdonor1/pdacdonor1/lognorm/reference_based/matched_reference_combo/rctd_class_aware/Level2.1/single_cell/split_fully_purified/lognorm/data_matched_reference_combo_rctd_class_aware_Level2.1_diffexpr.parquet
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_top_n=20/all/split_fully_purified/proseg_expected/PDAC/immuno_oncology/pdacdonor1/pdacdonor1/lognorm/reference_based/matched_reference_combo/rctd_class_aware/Level2.1/single_cell/split_fully_purified/lognorm/data_matched_reference_combo_rctd_class_aware_Level2.1_markers_rank_significance_diffexpr.parquet
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_top_n=20/all/split_fully_purified/proseg_expected/PDAC/immuno_oncology/pdacdonor1/pdacdonor1/lognorm/reference_based/matched_reference_combo/rctd_class_aware/Level2.1/single_cell/split_fully_purified/lognorm/data_matched_reference_combo_rctd_class_aware_Level2.1_summary_stats.json
# Processing futures:  18%|█▊        | 378/2160 [00:31<01:36, 18.50it/s]
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_top_n=20/all/split_fully_purified/proseg_expected/melanoma/5k/mlndonor2/mlndonor2/lognorm/reference_based/external_reference/rctd_class_aware/Level1/single_cell/split_fully_purified/lognorm/data_external_reference_rctd_class_aware_Level1_marker_genes.parquet
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_top_n=20/all/split_fully_purified/proseg_expected/melanoma/5k/mlndonor2/mlndonor2/lognorm/reference_based/external_reference/rctd_class_aware/Level1/single_cell/split_fully_purified/lognorm/data_external_reference_rctd_class_aware_Level1_diffexpr.parquet
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_top_n=20/all/split_fully_purified/proseg_expected/melanoma/5k/mlndonor2/mlndonor2/lognorm/reference_based/external_reference/rctd_class_aware/Level1/single_cell/split_fully_purified/lognorm/data_external_reference_rctd_class_aware_Level1_markers_rank_significance_diffexpr.parquet
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_top_n=20/all/split_fully_purified/proseg_expected/melanoma/5k/mlndonor2/mlndonor2/lognorm/reference_based/external_reference/rctd_class_aware/Level1/single_cell/split_fully_purified/lognorm/data_external_reference_rctd_class_aware_Level1_summary_stats.json
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_top_n=20/all/split_fully_purified/proseg_expected/melanoma/skin/mlndonor1/mlndonor1/lognorm/reference_based/external_reference/rctd_class_aware/Level1/single_cell/split_fully_purified/lognorm/data_external_reference_rctd_class_aware_Level1_marker_genes.parquet
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_top_n=20/all/split_fully_purified/proseg_expected/melanoma/skin/mlndonor1/mlndonor1/lognorm/reference_based/external_reference/rctd_class_aware/Level1/single_cell/split_fully_purified/lognorm/data_external_reference_rctd_class_aware_Level1_diffexpr.parquet
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_top_n=20/all/split_fully_purified/proseg_expected/melanoma/skin/mlndonor1/mlndonor1/lognorm/reference_based/external_reference/rctd_class_aware/Level1/single_cell/split_fully_purified/lognorm/data_external_reference_rctd_class_aware_Level1_markers_rank_significance_diffexpr.parquet
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_top_n=20/all/split_fully_purified/proseg_expected/melanoma/skin/mlndonor1/mlndonor1/lognorm/reference_based/external_reference/rctd_class_aware/Level1/single_cell/split_fully_purified/lognorm/data_external_reference_rctd_class_aware_Level1_summary_stats.json
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_top_n=20/all/split_fully_purified/proseg_expected/CRC/immuno_oncology/crcdonor1/crcdonor1/lognorm/reference_based/matched_reference_combo/rctd_class_aware/Level2.1/single_cell/split_fully_purified/lognorm/data_matched_reference_combo_rctd_class_aware_Level2.1_marker_genes.parquet
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_top_n=20/all/split_fully_purified/proseg_expected/CRC/immuno_oncology/crcdonor1/crcdonor1/lognorm/reference_based/matched_reference_combo/rctd_class_aware/Level2.1/single_cell/split_fully_purified/lognorm/data_matched_reference_combo_rctd_class_aware_Level2.1_diffexpr.parquet
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_top_n=20/all/split_fully_purified/proseg_expected/CRC/immuno_oncology/crcdonor1/crcdonor1/lognorm/reference_based/matched_reference_combo/rctd_class_aware/Level2.1/single_cell/split_fully_purified/lognorm/data_matched_reference_combo_rctd_class_aware_Level2.1_markers_rank_significance_diffexpr.parquet
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_top_n=20/all/split_fully_purified/proseg_expected/CRC/immuno_oncology/crcdonor1/crcdonor1/lognorm/reference_based/matched_reference_combo/rctd_class_aware/Level2.1/single_cell/split_fully_purified/lognorm/data_matched_reference_combo_rctd_class_aware_Level2.1_summary_stats.json
# Processing futures:  23%|██▎       | 490/2160 [00:41<01:26, 19.34it/s]
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_top_n=20/all/split_fully_purified/10x_5um/PDAC/immuno_oncology/pdacdonor1/pdacdonor1/lognorm/reference_based/matched_reference_combo/rctd_class_aware/Level2.1/single_cell/split_fully_purified/lognorm/data_matched_reference_combo_rctd_class_aware_Level2.1_marker_genes.parquet
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_top_n=20/all/split_fully_purified/10x_5um/PDAC/immuno_oncology/pdacdonor1/pdacdonor1/lognorm/reference_based/matched_reference_combo/rctd_class_aware/Level2.1/single_cell/split_fully_purified/lognorm/data_matched_reference_combo_rctd_class_aware_Level2.1_diffexpr.parquet
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_top_n=20/all/split_fully_purified/10x_5um/PDAC/immuno_oncology/pdacdonor1/pdacdonor1/lognorm/reference_based/matched_reference_combo/rctd_class_aware/Level2.1/single_cell/split_fully_purified/lognorm/data_matched_reference_combo_rctd_class_aware_Level2.1_markers_rank_significance_diffexpr.parquet
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_top_n=20/all/split_fully_purified/10x_5um/PDAC/immuno_oncology/pdacdonor1/pdacdonor1/lognorm/reference_based/matched_reference_combo/rctd_class_aware/Level2.1/single_cell/split_fully_purified/lognorm/data_matched_reference_combo_rctd_class_aware_Level2.1_summary_stats.json
# Processing futures:  23%|██▎       | 501/2160 [00:41<01:03, 25.96it/s]
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_top_n=20/all/split_fully_purified/10x_5um/melanoma/5k/mlndonor2/mlndonor2/lognorm/reference_based/external_reference/rctd_class_aware/Level1/single_cell/split_fully_purified/lognorm/data_external_reference_rctd_class_aware_Level1_marker_genes.parquet
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_top_n=20/all/split_fully_purified/10x_5um/melanoma/5k/mlndonor2/mlndonor2/lognorm/reference_based/external_reference/rctd_class_aware/Level1/single_cell/split_fully_purified/lognorm/data_external_reference_rctd_class_aware_Level1_diffexpr.parquet
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_top_n=20/all/split_fully_purified/10x_5um/melanoma/5k/mlndonor2/mlndonor2/lognorm/reference_based/external_reference/rctd_class_aware/Level1/single_cell/split_fully_purified/lognorm/data_external_reference_rctd_class_aware_Level1_markers_rank_significance_diffexpr.parquet
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_top_n=20/all/split_fully_purified/10x_5um/melanoma/5k/mlndonor2/mlndonor2/lognorm/reference_based/external_reference/rctd_class_aware/Level1/single_cell/split_fully_purified/lognorm/data_external_reference_rctd_class_aware_Level1_summary_stats.json
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_top_n=20/all/split_fully_purified/10x_5um/melanoma/skin/mlndonor1/mlndonor1/lognorm/reference_based/external_reference/rctd_class_aware/Level1/single_cell/split_fully_purified/lognorm/data_external_reference_rctd_class_aware_Level1_marker_genes.parquet
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_top_n=20/all/split_fully_purified/10x_5um/melanoma/skin/mlndonor1/mlndonor1/lognorm/reference_based/external_reference/rctd_class_aware/Level1/single_cell/split_fully_purified/lognorm/data_external_reference_rctd_class_aware_Level1_diffexpr.parquet
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_top_n=20/all/split_fully_purified/10x_5um/melanoma/skin/mlndonor1/mlndonor1/lognorm/reference_based/external_reference/rctd_class_aware/Level1/single_cell/split_fully_purified/lognorm/data_external_reference_rctd_class_aware_Level1_markers_rank_significance_diffexpr.parquet
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_top_n=20/all/split_fully_purified/10x_5um/melanoma/skin/mlndonor1/mlndonor1/lognorm/reference_based/external_reference/rctd_class_aware/Level1/single_cell/split_fully_purified/lognorm/data_external_reference_rctd_class_aware_Level1_summary_stats.json
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_top_n=20/all/split_fully_purified/10x_5um/CRC/immuno_oncology/crcdonor1/crcdonor1/lognorm/reference_based/matched_reference_combo/rctd_class_aware/Level2.1/single_cell/split_fully_purified/lognorm/data_matched_reference_combo_rctd_class_aware_Level2.1_marker_genes.parquet
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_top_n=20/all/split_fully_purified/10x_5um/CRC/immuno_oncology/crcdonor1/crcdonor1/lognorm/reference_based/matched_reference_combo/rctd_class_aware/Level2.1/single_cell/split_fully_purified/lognorm/data_matched_reference_combo_rctd_class_aware_Level2.1_diffexpr.parquet
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_top_n=20/all/split_fully_purified/10x_5um/CRC/immuno_oncology/crcdonor1/crcdonor1/lognorm/reference_based/matched_reference_combo/rctd_class_aware/Level2.1/single_cell/split_fully_purified/lognorm/data_matched_reference_combo_rctd_class_aware_Level2.1_markers_rank_significance_diffexpr.parquet
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_top_n=20/all/split_fully_purified/10x_5um/CRC/immuno_oncology/crcdonor1/crcdonor1/lognorm/reference_based/matched_reference_combo/rctd_class_aware/Level2.1/single_cell/split_fully_purified/lognorm/data_matched_reference_combo_rctd_class_aware_Level2.1_summary_stats.json
# Processing futures:  27%|██▋       | 587/2160 [00:48<02:29, 10.53it/s]
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_top_n=20/all/split_fully_purified/10x_mm_5um/melanoma/5k/mlndonor2/mlndonor2/lognorm/reference_based/external_reference/rctd_class_aware/Level1/single_cell/split_fully_purified/lognorm/data_external_reference_rctd_class_aware_Level1_marker_genes.parquet
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_top_n=20/all/split_fully_purified/10x_mm_5um/melanoma/5k/mlndonor2/mlndonor2/lognorm/reference_based/external_reference/rctd_class_aware/Level1/single_cell/split_fully_purified/lognorm/data_external_reference_rctd_class_aware_Level1_diffexpr.parquet
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_top_n=20/all/split_fully_purified/10x_mm_5um/melanoma/5k/mlndonor2/mlndonor2/lognorm/reference_based/external_reference/rctd_class_aware/Level1/single_cell/split_fully_purified/lognorm/data_external_reference_rctd_class_aware_Level1_markers_rank_significance_diffexpr.parquet
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_top_n=20/all/split_fully_purified/10x_mm_5um/melanoma/5k/mlndonor2/mlndonor2/lognorm/reference_based/external_reference/rctd_class_aware/Level1/single_cell/split_fully_purified/lognorm/data_external_reference_rctd_class_aware_Level1_summary_stats.json
# Processing futures:  31%|███       | 674/2160 [00:56<01:15, 19.57it/s]
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_top_n=20/all/split_fully_purified/10x_0um/PDAC/immuno_oncology/pdacdonor1/pdacdonor1/lognorm/reference_based/matched_reference_combo/rctd_class_aware/Level2.1/single_cell/split_fully_purified/lognorm/data_matched_reference_combo_rctd_class_aware_Level2.1_marker_genes.parquet
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_top_n=20/all/split_fully_purified/10x_0um/PDAC/immuno_oncology/pdacdonor1/pdacdonor1/lognorm/reference_based/matched_reference_combo/rctd_class_aware/Level2.1/single_cell/split_fully_purified/lognorm/data_matched_reference_combo_rctd_class_aware_Level2.1_diffexpr.parquet
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_top_n=20/all/split_fully_purified/10x_0um/PDAC/immuno_oncology/pdacdonor1/pdacdonor1/lognorm/reference_based/matched_reference_combo/rctd_class_aware/Level2.1/single_cell/split_fully_purified/lognorm/data_matched_reference_combo_rctd_class_aware_Level2.1_markers_rank_significance_diffexpr.parquet
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_top_n=20/all/split_fully_purified/10x_0um/PDAC/immuno_oncology/pdacdonor1/pdacdonor1/lognorm/reference_based/matched_reference_combo/rctd_class_aware/Level2.1/single_cell/split_fully_purified/lognorm/data_matched_reference_combo_rctd_class_aware_Level2.1_summary_stats.json
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_top_n=20/all/split_fully_purified/10x_0um/melanoma/skin/mlndonor1/mlndonor1/lognorm/reference_based/external_reference/rctd_class_aware/Level1/single_cell/split_fully_purified/lognorm/data_external_reference_rctd_class_aware_Level1_marker_genes.parquet
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_top_n=20/all/split_fully_purified/10x_0um/melanoma/5k/mlndonor2/mlndonor2/lognorm/reference_based/external_reference/rctd_class_aware/Level1/single_cell/split_fully_purified/lognorm/data_external_reference_rctd_class_aware_Level1_marker_genes.parquet
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_top_n=20/all/split_fully_purified/10x_0um/melanoma/skin/mlndonor1/mlndonor1/lognorm/reference_based/external_reference/rctd_class_aware/Level1/single_cell/split_fully_purified/lognorm/data_external_reference_rctd_class_aware_Level1_diffexpr.parquet
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_top_n=20/all/split_fully_purified/10x_0um/melanoma/5k/mlndonor2/mlndonor2/lognorm/reference_based/external_reference/rctd_class_aware/Level1/single_cell/split_fully_purified/lognorm/data_external_reference_rctd_class_aware_Level1_diffexpr.parquet
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_top_n=20/all/split_fully_purified/10x_0um/melanoma/skin/mlndonor1/mlndonor1/lognorm/reference_based/external_reference/rctd_class_aware/Level1/single_cell/split_fully_purified/lognorm/data_external_reference_rctd_class_aware_Level1_markers_rank_significance_diffexpr.parquet
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_top_n=20/all/split_fully_purified/10x_0um/melanoma/5k/mlndonor2/mlndonor2/lognorm/reference_based/external_reference/rctd_class_aware/Level1/single_cell/split_fully_purified/lognorm/data_external_reference_rctd_class_aware_Level1_markers_rank_significance_diffexpr.parquet
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_top_n=20/all/split_fully_purified/10x_0um/melanoma/skin/mlndonor1/mlndonor1/lognorm/reference_based/external_reference/rctd_class_aware/Level1/single_cell/split_fully_purified/lognorm/data_external_reference_rctd_class_aware_Level1_summary_stats.json
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_top_n=20/all/split_fully_purified/10x_0um/melanoma/5k/mlndonor2/mlndonor2/lognorm/reference_based/external_reference/rctd_class_aware/Level1/single_cell/split_fully_purified/lognorm/data_external_reference_rctd_class_aware_Level1_summary_stats.json
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_top_n=20/all/split_fully_purified/10x_0um/CRC/immuno_oncology/crcdonor1/crcdonor1/lognorm/reference_based/matched_reference_combo/rctd_class_aware/Level2.1/single_cell/split_fully_purified/lognorm/data_matched_reference_combo_rctd_class_aware_Level2.1_marker_genes.parquet
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_top_n=20/all/split_fully_purified/10x_0um/CRC/immuno_oncology/crcdonor1/crcdonor1/lognorm/reference_based/matched_reference_combo/rctd_class_aware/Level2.1/single_cell/split_fully_purified/lognorm/data_matched_reference_combo_rctd_class_aware_Level2.1_diffexpr.parquet
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_top_n=20/all/split_fully_purified/10x_0um/CRC/immuno_oncology/crcdonor1/crcdonor1/lognorm/reference_based/matched_reference_combo/rctd_class_aware/Level2.1/single_cell/split_fully_purified/lognorm/data_matched_reference_combo_rctd_class_aware_Level2.1_markers_rank_significance_diffexpr.parquet
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_top_n=20/all/split_fully_purified/10x_0um/CRC/immuno_oncology/crcdonor1/crcdonor1/lognorm/reference_based/matched_reference_combo/rctd_class_aware/Level2.1/single_cell/split_fully_purified/lognorm/data_matched_reference_combo_rctd_class_aware_Level2.1_summary_stats.json
# Processing futures:  34%|███▍      | 732/2160 [01:01<01:15, 18.98it/s]
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_top_n=20/all/resolvi_panel_use_batch=True/proseg_expected/PDAC/immuno_oncology/pdacdonor1/pdacdonor1/mixture_k=50/num_samples=30/lognorm/data_matched_reference_combo_rctd_class_aware_Level2.1_marker_genes.parquet
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_top_n=20/all/resolvi_panel_use_batch=True/proseg_expected/PDAC/immuno_oncology/pdacdonor1/pdacdonor1/mixture_k=50/num_samples=30/lognorm/data_matched_reference_combo_rctd_class_aware_Level2.1_diffexpr.parquet
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_top_n=20/all/resolvi_panel_use_batch=True/proseg_expected/PDAC/immuno_oncology/pdacdonor1/pdacdonor1/mixture_k=50/num_samples=30/lognorm/data_matched_reference_combo_rctd_class_aware_Level2.1_markers_rank_significance_diffexpr.parquet
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_top_n=20/all/resolvi_panel_use_batch=True/proseg_expected/PDAC/immuno_oncology/pdacdonor1/pdacdonor1/mixture_k=50/num_samples=30/lognorm/data_matched_reference_combo_rctd_class_aware_Level2.1_summary_stats.json
# Processing futures:  35%|███▍      | 746/2160 [01:01<00:58, 24.09it/s]
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_top_n=20/all/resolvi_panel_use_batch=True/proseg_expected/melanoma/5k/mlndonor2/mlndonor2/mixture_k=50/num_samples=30/lognorm/data_external_reference_rctd_class_aware_Level1_marker_genes.parquet
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_top_n=20/all/resolvi_panel_use_batch=True/proseg_expected/melanoma/5k/mlndonor2/mlndonor2/mixture_k=50/num_samples=30/lognorm/data_external_reference_rctd_class_aware_Level1_diffexpr.parquet
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_top_n=20/all/resolvi_panel_use_batch=True/proseg_expected/melanoma/5k/mlndonor2/mlndonor2/mixture_k=50/num_samples=30/lognorm/data_external_reference_rctd_class_aware_Level1_markers_rank_significance_diffexpr.parquet
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_top_n=20/all/resolvi_panel_use_batch=True/proseg_expected/melanoma/skin/mlndonor1/mlndonor1/mixture_k=50/num_samples=30/lognorm/data_external_reference_rctd_class_aware_Level1_marker_genes.parquet
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_top_n=20/all/resolvi_panel_use_batch=True/proseg_expected/melanoma/5k/mlndonor2/mlndonor2/mixture_k=50/num_samples=30/lognorm/data_external_reference_rctd_class_aware_Level1_summary_stats.json
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_top_n=20/all/resolvi_panel_use_batch=True/proseg_expected/CRC/immuno_oncology/crcdonor1/crcdonor1/mixture_k=50/num_samples=30/lognorm/data_matched_reference_combo_rctd_class_aware_Level2.1_marker_genes.parquet
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_top_n=20/all/resolvi_panel_use_batch=True/proseg_expected/CRC/immuno_oncology/crcdonor1/crcdonor1/mixture_k=50/num_samples=30/lognorm/data_matched_reference_combo_rctd_class_aware_Level2.1_diffexpr.parquet
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_top_n=20/all/resolvi_panel_use_batch=True/proseg_expected/CRC/immuno_oncology/crcdonor1/crcdonor1/mixture_k=50/num_samples=30/lognorm/data_matched_reference_combo_rctd_class_aware_Level2.1_markers_rank_significance_diffexpr.parquet
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_top_n=20/all/resolvi_panel_use_batch=True/proseg_expected/CRC/immuno_oncology/crcdonor1/crcdonor1/mixture_k=50/num_samples=30/lognorm/data_matched_reference_combo_rctd_class_aware_Level2.1_summary_stats.json
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_top_n=20/all/resolvi_panel_use_batch=True/proseg_expected/melanoma/skin/mlndonor1/mlndonor1/mixture_k=50/num_samples=30/lognorm/data_external_reference_rctd_class_aware_Level1_diffexpr.parquet
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_top_n=20/all/resolvi_panel_use_batch=True/proseg_expected/melanoma/skin/mlndonor1/mlndonor1/mixture_k=50/num_samples=30/lognorm/data_external_reference_rctd_class_aware_Level1_markers_rank_significance_diffexpr.parquet
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_top_n=20/all/resolvi_panel_use_batch=True/proseg_expected/melanoma/skin/mlndonor1/mlndonor1/mixture_k=50/num_samples=30/lognorm/data_external_reference_rctd_class_aware_Level1_summary_stats.json
# Processing futures:  40%|███▉      | 854/2160 [01:09<00:59, 21.92it/s]
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_top_n=20/all/resolvi_panel_use_batch=True/10x_5um/PDAC/immuno_oncology/pdacdonor1/pdacdonor1/mixture_k=50/num_samples=30/lognorm/data_matched_reference_combo_rctd_class_aware_Level2.1_marker_genes.parquet
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_top_n=20/all/resolvi_panel_use_batch=True/10x_5um/PDAC/immuno_oncology/pdacdonor1/pdacdonor1/mixture_k=50/num_samples=30/lognorm/data_matched_reference_combo_rctd_class_aware_Level2.1_diffexpr.parquet
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_top_n=20/all/resolvi_panel_use_batch=True/10x_5um/PDAC/immuno_oncology/pdacdonor1/pdacdonor1/mixture_k=50/num_samples=30/lognorm/data_matched_reference_combo_rctd_class_aware_Level2.1_markers_rank_significance_diffexpr.parquet
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_top_n=20/all/resolvi_panel_use_batch=True/10x_5um/PDAC/immuno_oncology/pdacdonor1/pdacdonor1/mixture_k=50/num_samples=30/lognorm/data_matched_reference_combo_rctd_class_aware_Level2.1_summary_stats.json
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_top_n=20/all/resolvi_panel_use_batch=True/10x_5um/melanoma/5k/mlndonor2/mlndonor2/mixture_k=50/num_samples=30/lognorm/data_external_reference_rctd_class_aware_Level1_marker_genes.parquet
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_top_n=20/all/resolvi_panel_use_batch=True/10x_5um/melanoma/5k/mlndonor2/mlndonor2/mixture_k=50/num_samples=30/lognorm/data_external_reference_rctd_class_aware_Level1_diffexpr.parquet
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_top_n=20/all/resolvi_panel_use_batch=True/10x_5um/melanoma/5k/mlndonor2/mlndonor2/mixture_k=50/num_samples=30/lognorm/data_external_reference_rctd_class_aware_Level1_markers_rank_significance_diffexpr.parquet
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_top_n=20/all/resolvi_panel_use_batch=True/10x_5um/melanoma/5k/mlndonor2/mlndonor2/mixture_k=50/num_samples=30/lognorm/data_external_reference_rctd_class_aware_Level1_summary_stats.json
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_top_n=20/all/resolvi_panel_use_batch=True/10x_5um/melanoma/skin/mlndonor1/mlndonor1/mixture_k=50/num_samples=30/lognorm/data_external_reference_rctd_class_aware_Level1_marker_genes.parquet
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_top_n=20/all/resolvi_panel_use_batch=True/10x_5um/melanoma/skin/mlndonor1/mlndonor1/mixture_k=50/num_samples=30/lognorm/data_external_reference_rctd_class_aware_Level1_diffexpr.parquet
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_top_n=20/all/resolvi_panel_use_batch=True/10x_5um/melanoma/skin/mlndonor1/mlndonor1/mixture_k=50/num_samples=30/lognorm/data_external_reference_rctd_class_aware_Level1_markers_rank_significance_diffexpr.parquet
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_top_n=20/all/resolvi_panel_use_batch=True/10x_5um/melanoma/skin/mlndonor1/mlndonor1/mixture_k=50/num_samples=30/lognorm/data_external_reference_rctd_class_aware_Level1_summary_stats.json
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_top_n=20/all/resolvi_panel_use_batch=True/10x_5um/CRC/immuno_oncology/crcdonor1/crcdonor1/mixture_k=50/num_samples=30/lognorm/data_matched_reference_combo_rctd_class_aware_Level2.1_marker_genes.parquet
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_top_n=20/all/resolvi_panel_use_batch=True/10x_5um/CRC/immuno_oncology/crcdonor1/crcdonor1/mixture_k=50/num_samples=30/lognorm/data_matched_reference_combo_rctd_class_aware_Level2.1_diffexpr.parquet
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_top_n=20/all/resolvi_panel_use_batch=True/10x_5um/CRC/immuno_oncology/crcdonor1/crcdonor1/mixture_k=50/num_samples=30/lognorm/data_matched_reference_combo_rctd_class_aware_Level2.1_markers_rank_significance_diffexpr.parquet
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_top_n=20/all/resolvi_panel_use_batch=True/10x_5um/CRC/immuno_oncology/crcdonor1/crcdonor1/mixture_k=50/num_samples=30/lognorm/data_matched_reference_combo_rctd_class_aware_Level2.1_summary_stats.json
# Processing futures:  44%|████▍     | 946/2160 [01:15<01:56, 10.41it/s]
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_top_n=20/all/resolvi_panel_use_batch=True/10x_mm_5um/melanoma/5k/mlndonor2/mlndonor2/mixture_k=50/num_samples=30/lognorm/data_external_reference_rctd_class_aware_Level1_marker_genes.parquet
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_top_n=20/all/resolvi_panel_use_batch=True/10x_mm_5um/melanoma/5k/mlndonor2/mlndonor2/mixture_k=50/num_samples=30/lognorm/data_external_reference_rctd_class_aware_Level1_diffexpr.parquet
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_top_n=20/all/resolvi_panel_use_batch=True/10x_mm_5um/melanoma/5k/mlndonor2/mlndonor2/mixture_k=50/num_samples=30/lognorm/data_external_reference_rctd_class_aware_Level1_markers_rank_significance_diffexpr.parquet
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_top_n=20/all/resolvi_panel_use_batch=True/10x_mm_5um/melanoma/5k/mlndonor2/mlndonor2/mixture_k=50/num_samples=30/lognorm/data_external_reference_rctd_class_aware_Level1_summary_stats.json
# Processing futures:  48%|████▊     | 1034/2160 [01:21<00:58, 19.40it/s]
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_top_n=20/all/resolvi_panel_use_batch=True/10x_0um/PDAC/immuno_oncology/pdacdonor1/pdacdonor1/mixture_k=50/num_samples=30/lognorm/data_matched_reference_combo_rctd_class_aware_Level2.1_marker_genes.parquet
# ...
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_top_n=20/all/ovrlpy_correction_signal_integrity_threshold=0.7/10x_5um/melanoma/5k/mlndonor2/mlndonor2/lognorm/data_external_reference_rctd_class_aware_Level1_summary_stats.json
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_top_n=20/all/ovrlpy_correction_signal_integrity_threshold=0.7/10x_5um/melanoma/skin/mlndonor1/mlndonor1/lognorm/data_external_reference_rctd_class_aware_Level1_marker_genes.parquet
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_top_n=20/all/ovrlpy_correction_signal_integrity_threshold=0.7/10x_5um/melanoma/skin/mlndonor1/mlndonor1/lognorm/data_external_reference_rctd_class_aware_Level1_diffexpr.parquet
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_top_n=20/all/ovrlpy_correction_signal_integrity_threshold=0.7/10x_5um/melanoma/skin/mlndonor1/mlndonor1/lognorm/data_external_reference_rctd_class_aware_Level1_markers_rank_significance_diffexpr.parquet
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_top_n=20/all/ovrlpy_correction_signal_integrity_threshold=0.7/10x_5um/melanoma/skin/mlndonor1/mlndonor1/lognorm/data_external_reference_rctd_class_aware_Level1_summary_stats.json
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_top_n=20/all/ovrlpy_correction_signal_integrity_threshold=0.7/10x_5um/CRC/immuno_oncology/crcdonor1/crcdonor1/lognorm/data_matched_reference_combo_rctd_class_aware_Level2.1_marker_genes.parquet
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_top_n=20/all/ovrlpy_correction_signal_integrity_threshold=0.7/10x_5um/CRC/immuno_oncology/crcdonor1/crcdonor1/lognorm/data_matched_reference_combo_rctd_class_aware_Level2.1_diffexpr.parquet
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_top_n=20/all/ovrlpy_correction_signal_integrity_threshold=0.7/10x_5um/CRC/immuno_oncology/crcdonor1/crcdonor1/lognorm/data_matched_reference_combo_rctd_class_aware_Level2.1_markers_rank_significance_diffexpr.parquet
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_top_n=20/all/ovrlpy_correction_signal_integrity_threshold=0.7/10x_5um/CRC/immuno_oncology/crcdonor1/crcdonor1/lognorm/data_matched_reference_combo_rctd_class_aware_Level2.1_summary_stats.json
# Processing futures:  91%|█████████ | 1960/2160 [02:23<00:10, 19.94it/s]
# File is empty: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_top_n=20/all/ovrlpy_correction_signal_integrity_threshold=0.7/10x_5um/NSCLC/5k/1GAC/1GAC/lognorm/data_matched_reference_combo_rctd_class_aware_Level2.1_diffexpr.parquet
# File is empty: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_top_n=20/all/ovrlpy_correction_signal_integrity_threshold=0.7/10x_5um/NSCLC/5k/1GAC/1GAC/lognorm/data_matched_reference_combo_rctd_class_aware_Level2.1_markers_rank_significance_diffexpr.parquet
# File is empty: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_top_n=20/all/ovrlpy_correction_signal_integrity_threshold=0.7/10x_5um/NSCLC/5k/1GVD/1GVD/lognorm/data_matched_reference_combo_rctd_class_aware_Level2.1_diffexpr.parquet
# File is empty: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_top_n=20/all/ovrlpy_correction_signal_integrity_threshold=0.7/10x_5um/NSCLC/5k/1GVD/1GVD/lognorm/data_matched_reference_combo_rctd_class_aware_Level2.1_markers_rank_significance_diffexpr.parquet
# Processing futures:  93%|█████████▎| 2016/2160 [02:26<00:06, 23.64it/s]
# File is empty: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_top_n=20/all/ovrlpy_correction_signal_integrity_threshold=0.7/10x_15um/NSCLC/5k/1GAC/1GAC/lognorm/data_matched_reference_combo_rctd_class_aware_Level2.1_diffexpr.parquet
# File is empty: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_top_n=20/all/ovrlpy_correction_signal_integrity_threshold=0.7/10x_15um/NSCLC/5k/1GAC/1GAC/lognorm/data_matched_reference_combo_rctd_class_aware_Level2.1_markers_rank_significance_diffexpr.parquet
# File is empty: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_top_n=20/all/ovrlpy_correction_signal_integrity_threshold=0.7/10x_15um/NSCLC/5k/1GVD/1GVD/lognorm/data_matched_reference_combo_rctd_class_aware_Level2.1_diffexpr.parquet
# File is empty: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_top_n=20/all/ovrlpy_correction_signal_integrity_threshold=0.7/10x_15um/NSCLC/5k/1GVD/1GVD/lognorm/data_matched_reference_combo_rctd_class_aware_Level2.1_markers_rank_significance_diffexpr.parquet
# Processing futures:  94%|█████████▍| 2029/2160 [02:27<00:06, 21.45it/s]
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_top_n=20/all/ovrlpy_correction_signal_integrity_threshold=0.7/10x_mm_5um/melanoma/5k/mlndonor2/mlndonor2/lognorm/data_external_reference_rctd_class_aware_Level1_marker_genes.parquet
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_top_n=20/all/ovrlpy_correction_signal_integrity_threshold=0.7/10x_mm_5um/melanoma/5k/mlndonor2/mlndonor2/lognorm/data_external_reference_rctd_class_aware_Level1_diffexpr.parquet
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_top_n=20/all/ovrlpy_correction_signal_integrity_threshold=0.7/10x_mm_5um/melanoma/5k/mlndonor2/mlndonor2/lognorm/data_external_reference_rctd_class_aware_Level1_markers_rank_significance_diffexpr.parquet
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_top_n=20/all/ovrlpy_correction_signal_integrity_threshold=0.7/10x_mm_5um/melanoma/5k/mlndonor2/mlndonor2/lognorm/data_external_reference_rctd_class_aware_Level1_summary_stats.json
# File is empty: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_top_n=20/all/ovrlpy_correction_signal_integrity_threshold=0.7/10x_mm_5um/NSCLC/5k/0PSV/0PSV/lognorm/data_matched_reference_combo_rctd_class_aware_Level2.1_diffexpr.parquet
# File is empty: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_top_n=20/all/ovrlpy_correction_signal_integrity_threshold=0.7/10x_mm_5um/NSCLC/5k/0PSV/0PSV/lognorm/data_matched_reference_combo_rctd_class_aware_Level2.1_markers_rank_significance_diffexpr.parquet
# Processing futures:  95%|█████████▍| 2042/2160 [02:28<00:06, 19.57it/s]
# File is empty: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_top_n=20/all/ovrlpy_correction_signal_integrity_threshold=0.7/10x_mm_5um/NSCLC/5k/1GAC/1GAC/lognorm/data_matched_reference_combo_rctd_class_aware_Level2.1_diffexpr.parquet
# File is empty: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_top_n=20/all/ovrlpy_correction_signal_integrity_threshold=0.7/10x_mm_5um/NSCLC/5k/1GAC/1GAC/lognorm/data_matched_reference_combo_rctd_class_aware_Level2.1_markers_rank_significance_diffexpr.parquet
# File is empty: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_top_n=20/all/ovrlpy_correction_signal_integrity_threshold=0.7/10x_mm_5um/NSCLC/5k/1GVD/1GVD/lognorm/data_matched_reference_combo_rctd_class_aware_Level2.1_diffexpr.parquet
# File is empty: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_top_n=20/all/ovrlpy_correction_signal_integrity_threshold=0.7/10x_mm_5um/NSCLC/5k/1GVD/1GVD/lognorm/data_matched_reference_combo_rctd_class_aware_Level2.1_markers_rank_significance_diffexpr.parquet
# Processing futures:  98%|█████████▊| 2115/2160 [02:33<00:01, 23.52it/s]
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_top_n=20/all/ovrlpy_correction_signal_integrity_threshold=0.7/10x_0um/PDAC/immuno_oncology/pdacdonor1/pdacdonor1/lognorm/data_matched_reference_combo_rctd_class_aware_Level2.1_marker_genes.parquet
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_top_n=20/all/ovrlpy_correction_signal_integrity_threshold=0.7/10x_0um/PDAC/immuno_oncology/pdacdonor1/pdacdonor1/lognorm/data_matched_reference_combo_rctd_class_aware_Level2.1_diffexpr.parquet
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_top_n=20/all/ovrlpy_correction_signal_integrity_threshold=0.7/10x_0um/PDAC/immuno_oncology/pdacdonor1/pdacdonor1/lognorm/data_matched_reference_combo_rctd_class_aware_Level2.1_markers_rank_significance_diffexpr.parquet
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_top_n=20/all/ovrlpy_correction_signal_integrity_threshold=0.7/10x_0um/PDAC/immuno_oncology/pdacdonor1/pdacdonor1/lognorm/data_matched_reference_combo_rctd_class_aware_Level2.1_summary_stats.json
# Processing futures:  98%|█████████▊| 2123/2160 [02:33<00:01, 25.01it/s]
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_top_n=20/all/ovrlpy_correction_signal_integrity_threshold=0.7/10x_0um/melanoma/5k/mlndonor2/mlndonor2/lognorm/data_external_reference_rctd_class_aware_Level1_marker_genes.parquet
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_top_n=20/all/ovrlpy_correction_signal_integrity_threshold=0.7/10x_0um/melanoma/5k/mlndonor2/mlndonor2/lognorm/data_external_reference_rctd_class_aware_Level1_diffexpr.parquet
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_top_n=20/all/ovrlpy_correction_signal_integrity_threshold=0.7/10x_0um/melanoma/5k/mlndonor2/mlndonor2/lognorm/data_external_reference_rctd_class_aware_Level1_markers_rank_significance_diffexpr.parquet
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_top_n=20/all/ovrlpy_correction_signal_integrity_threshold=0.7/10x_0um/melanoma/5k/mlndonor2/mlndonor2/lognorm/data_external_reference_rctd_class_aware_Level1_summary_stats.json
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_top_n=20/all/ovrlpy_correction_signal_integrity_threshold=0.7/10x_0um/melanoma/skin/mlndonor1/mlndonor1/lognorm/data_external_reference_rctd_class_aware_Level1_marker_genes.parquet
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_top_n=20/all/ovrlpy_correction_signal_integrity_threshold=0.7/10x_0um/melanoma/skin/mlndonor1/mlndonor1/lognorm/data_external_reference_rctd_class_aware_Level1_diffexpr.parquet
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_top_n=20/all/ovrlpy_correction_signal_integrity_threshold=0.7/10x_0um/melanoma/skin/mlndonor1/mlndonor1/lognorm/data_external_reference_rctd_class_aware_Level1_markers_rank_significance_diffexpr.parquet
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_top_n=20/all/ovrlpy_correction_signal_integrity_threshold=0.7/10x_0um/melanoma/skin/mlndonor1/mlndonor1/lognorm/data_external_reference_rctd_class_aware_Level1_summary_stats.json
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_top_n=20/all/ovrlpy_correction_signal_integrity_threshold=0.7/10x_0um/CRC/immuno_oncology/crcdonor1/crcdonor1/lognorm/data_matched_reference_combo_rctd_class_aware_Level2.1_marker_genes.parquet
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_top_n=20/all/ovrlpy_correction_signal_integrity_threshold=0.7/10x_0um/CRC/immuno_oncology/crcdonor1/crcdonor1/lognorm/data_matched_reference_combo_rctd_class_aware_Level2.1_diffexpr.parquet
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_top_n=20/all/ovrlpy_correction_signal_integrity_threshold=0.7/10x_0um/CRC/immuno_oncology/crcdonor1/crcdonor1/lognorm/data_matched_reference_combo_rctd_class_aware_Level2.1_markers_rank_significance_diffexpr.parquet
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_top_n=20/all/ovrlpy_correction_signal_integrity_threshold=0.7/10x_0um/CRC/immuno_oncology/crcdonor1/crcdonor1/lognorm/data_matched_reference_combo_rctd_class_aware_Level2.1_summary_stats.json
# Processing futures:  99%|█████████▉| 2140/2160 [02:34<00:00, 24.50it/s]
# File is empty: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_top_n=20/all/ovrlpy_correction_signal_integrity_threshold=0.7/10x_0um/NSCLC/5k/0PSV/0PSV/lognorm/data_matched_reference_combo_rctd_class_aware_Level2.1_diffexpr.parquet
# File is empty: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_top_n=20/all/ovrlpy_correction_signal_integrity_threshold=0.7/10x_0um/NSCLC/5k/0PSV/0PSV/lognorm/data_matched_reference_combo_rctd_class_aware_Level2.1_markers_rank_significance_diffexpr.parquet
# File is empty: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_top_n=20/all/ovrlpy_correction_signal_integrity_threshold=0.7/10x_0um/NSCLC/5k/1GAC/1GAC/lognorm/data_matched_reference_combo_rctd_class_aware_Level2.1_diffexpr.parquet
# File is empty: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_top_n=20/all/ovrlpy_correction_signal_integrity_threshold=0.7/10x_0um/NSCLC/5k/1GAC/1GAC/lognorm/data_matched_reference_combo_rctd_class_aware_Level2.1_markers_rank_significance_diffexpr.parquet
# File is empty: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_top_n=20/all/ovrlpy_correction_signal_integrity_threshold=0.7/10x_0um/NSCLC/5k/1GVD/1GVD/lognorm/data_matched_reference_combo_rctd_class_aware_Level2.1_diffexpr.parquet
# File is empty: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_top_n=20/all/ovrlpy_correction_signal_integrity_threshold=0.7/10x_0um/NSCLC/5k/1GVD/1GVD/lognorm/data_matched_reference_combo_rctd_class_aware_Level2.1_markers_rank_significance_diffexpr.parquet
# Processing futures: 100%|██████████| 2160/2160 [02:35<00:00, 13.86it/s]

# %% [markdown]
# # Load results logreg

# %%
dfs = readwrite.read_contamination_metrics_results(
    results_dir,
    correction_methods,
    xenium_std_seurat_analysis_dir,
    reference,
    method,
    level,
    mixture_k,
    num_samples,
    normalisation,
    layer,
    radius=radius,
    n_splits=n_splits,
    n_permutations=n_permutations,
    n_repeats=n_repeats,
    top_n=top_n,
    markers_mode=markers_mode,
    cv_mode=cv_mode,
    scoring=scoring,

    evaluation = "logreg",
    genes_name='all', #'Xenium_hLung_v1_metadata', 
    train_mode='multivariate',#'univariate',
    # ref_panel='5k',
)
# Out:
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_top_n=20/all/raw/proseg_expected/PDAC/immuno_oncology/pdacdonor1/pdacdonor1/lognorm/data_matched_reference_combo_rctd_class_aware_Level2.1_marker_genes.parquet
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_n_permutations=30_n_splits=5_top_n=20_precision_spatial_multivariate_logreg/all/raw/proseg_expected/PDAC/immuno_oncology/pdacdonor1/pdacdonor1/lognorm/data_matched_reference_combo_rctd_class_aware_Level2.1_permutations_logreg.parquet
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_n_permutations=30_n_splits=5_top_n=20_precision_spatial_multivariate_logreg/all/raw/proseg_expected/PDAC/immuno_oncology/pdacdonor1/pdacdonor1/lognorm/data_matched_reference_combo_rctd_class_aware_Level2.1_importances_logreg.parquet
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_n_permutations=30_n_splits=5_top_n=20_precision_spatial_multivariate_logreg/all/raw/proseg_expected/PDAC/immuno_oncology/pdacdonor1/pdacdonor1/lognorm/data_matched_reference_combo_rctd_class_aware_Level2.1_markers_rank_significance_logreg.parquet
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_top_n=20/all/raw/proseg_expected/melanoma/5k/mlndonor2/mlndonor2/lognorm/data_external_reference_rctd_class_aware_Level1_marker_genes.parquet
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_n_permutations=30_n_splits=5_top_n=20_precision_spatial_multivariate_logreg/all/raw/proseg_expected/melanoma/5k/mlndonor2/mlndonor2/lognorm/data_external_reference_rctd_class_aware_Level1_permutations_logreg.parquet
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_n_permutations=30_n_splits=5_top_n=20_precision_spatial_multivariate_logreg/all/raw/proseg_expected/melanoma/5k/mlndonor2/mlndonor2/lognorm/data_external_reference_rctd_class_aware_Level1_importances_logreg.parquet
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_n_permutations=30_n_splits=5_top_n=20_precision_spatial_multivariate_logreg/all/raw/proseg_expected/melanoma/5k/mlndonor2/mlndonor2/lognorm/data_external_reference_rctd_class_aware_Level1_markers_rank_significance_logreg.parquet
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_top_n=20/all/raw/proseg_expected/melanoma/skin/mlndonor1/mlndonor1/lognorm/data_external_reference_rctd_class_aware_Level1_marker_genes.parquet
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_n_permutations=30_n_splits=5_top_n=20_precision_spatial_multivariate_logreg/all/raw/proseg_expected/melanoma/skin/mlndonor1/mlndonor1/lognorm/data_external_reference_rctd_class_aware_Level1_permutations_logreg.parquet
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_n_permutations=30_n_splits=5_top_n=20_precision_spatial_multivariate_logreg/all/raw/proseg_expected/melanoma/skin/mlndonor1/mlndonor1/lognorm/data_external_reference_rctd_class_aware_Level1_importances_logreg.parquet
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_n_permutations=30_n_splits=5_top_n=20_precision_spatial_multivariate_logreg/all/raw/proseg_expected/melanoma/skin/mlndonor1/mlndonor1/lognorm/data_external_reference_rctd_class_aware_Level1_markers_rank_significance_logreg.parquet
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_top_n=20/all/raw/proseg_expected/CRC/immuno_oncology/crcdonor1/crcdonor1/lognorm/data_matched_reference_combo_rctd_class_aware_Level2.1_marker_genes.parquet
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_n_permutations=30_n_splits=5_top_n=20_precision_spatial_multivariate_logreg/all/raw/proseg_expected/CRC/immuno_oncology/crcdonor1/crcdonor1/lognorm/data_matched_reference_combo_rctd_class_aware_Level2.1_permutations_logreg.parquet
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_n_permutations=30_n_splits=5_top_n=20_precision_spatial_multivariate_logreg/all/raw/proseg_expected/CRC/immuno_oncology/crcdonor1/crcdonor1/lognorm/data_matched_reference_combo_rctd_class_aware_Level2.1_importances_logreg.parquet
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_n_permutations=30_n_splits=5_top_n=20_precision_spatial_multivariate_logreg/all/raw/proseg_expected/CRC/immuno_oncology/crcdonor1/crcdonor1/lognorm/data_matched_reference_combo_rctd_class_aware_Level2.1_markers_rank_significance_logreg.parquet
# Processing futures:   6%|▌         | 130/2160 [00:09<02:22, 14.29it/s]
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_top_n=20/all/raw/10x_5um/PDAC/immuno_oncology/pdacdonor1/pdacdonor1/lognorm/data_matched_reference_combo_rctd_class_aware_Level2.1_marker_genes.parquet
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_n_permutations=30_n_splits=5_top_n=20_precision_spatial_multivariate_logreg/all/raw/10x_5um/PDAC/immuno_oncology/pdacdonor1/pdacdonor1/lognorm/data_matched_reference_combo_rctd_class_aware_Level2.1_permutations_logreg.parquet
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_n_permutations=30_n_splits=5_top_n=20_precision_spatial_multivariate_logreg/all/raw/10x_5um/PDAC/immuno_oncology/pdacdonor1/pdacdonor1/lognorm/data_matched_reference_combo_rctd_class_aware_Level2.1_importances_logreg.parquet
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_n_permutations=30_n_splits=5_top_n=20_precision_spatial_multivariate_logreg/all/raw/10x_5um/PDAC/immuno_oncology/pdacdonor1/pdacdonor1/lognorm/data_matched_reference_combo_rctd_class_aware_Level2.1_markers_rank_significance_logreg.parquet
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_top_n=20/all/raw/10x_5um/melanoma/5k/mlndonor2/mlndonor2/lognorm/data_external_reference_rctd_class_aware_Level1_marker_genes.parquet
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_top_n=20/all/raw/10x_5um/melanoma/skin/mlndonor1/mlndonor1/lognorm/data_external_reference_rctd_class_aware_Level1_marker_genes.parquet
# Processing futures:   6%|▋         | 140/2160 [00:09<01:27, 23.12it/s]
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_n_permutations=30_n_splits=5_top_n=20_precision_spatial_multivariate_logreg/all/raw/10x_5um/melanoma/5k/mlndonor2/mlndonor2/lognorm/data_external_reference_rctd_class_aware_Level1_permutations_logreg.parquet
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_n_permutations=30_n_splits=5_top_n=20_precision_spatial_multivariate_logreg/all/raw/10x_5um/melanoma/5k/mlndonor2/mlndonor2/lognorm/data_external_reference_rctd_class_aware_Level1_importances_logreg.parquet
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_n_permutations=30_n_splits=5_top_n=20_precision_spatial_multivariate_logreg/all/raw/10x_5um/melanoma/skin/mlndonor1/mlndonor1/lognorm/data_external_reference_rctd_class_aware_Level1_permutations_logreg.parquet
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_n_permutations=30_n_splits=5_top_n=20_precision_spatial_multivariate_logreg/all/raw/10x_5um/melanoma/5k/mlndonor2/mlndonor2/lognorm/data_external_reference_rctd_class_aware_Level1_markers_rank_significance_logreg.parquet
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_n_permutations=30_n_splits=5_top_n=20_precision_spatial_multivariate_logreg/all/raw/10x_5um/melanoma/skin/mlndonor1/mlndonor1/lognorm/data_external_reference_rctd_class_aware_Level1_importances_logreg.parquet
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_top_n=20/all/raw/10x_5um/CRC/immuno_oncology/crcdonor1/crcdonor1/lognorm/data_matched_reference_combo_rctd_class_aware_Level2.1_marker_genes.parquet
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_n_permutations=30_n_splits=5_top_n=20_precision_spatial_multivariate_logreg/all/raw/10x_5um/melanoma/skin/mlndonor1/mlndonor1/lognorm/data_external_reference_rctd_class_aware_Level1_markers_rank_significance_logreg.parquet
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_n_permutations=30_n_splits=5_top_n=20_precision_spatial_multivariate_logreg/all/raw/10x_5um/CRC/immuno_oncology/crcdonor1/crcdonor1/lognorm/data_matched_reference_combo_rctd_class_aware_Level2.1_permutations_logreg.parquet
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_n_permutations=30_n_splits=5_top_n=20_precision_spatial_multivariate_logreg/all/raw/10x_5um/CRC/immuno_oncology/crcdonor1/crcdonor1/lognorm/data_matched_reference_combo_rctd_class_aware_Level2.1_importances_logreg.parquet
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_n_permutations=30_n_splits=5_top_n=20_precision_spatial_multivariate_logreg/all/raw/10x_5um/CRC/immuno_oncology/crcdonor1/crcdonor1/lognorm/data_matched_reference_combo_rctd_class_aware_Level2.1_markers_rank_significance_logreg.parquet
# Processing futures:  11%|█         | 233/2160 [00:18<02:50, 11.28it/s]
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_top_n=20/all/raw/10x_mm_5um/melanoma/5k/mlndonor2/mlndonor2/lognorm/data_external_reference_rctd_class_aware_Level1_marker_genes.parquet
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_n_permutations=30_n_splits=5_top_n=20_precision_spatial_multivariate_logreg/all/raw/10x_mm_5um/melanoma/5k/mlndonor2/mlndonor2/lognorm/data_external_reference_rctd_class_aware_Level1_permutations_logreg.parquet
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_n_permutations=30_n_splits=5_top_n=20_precision_spatial_multivariate_logreg/all/raw/10x_mm_5um/melanoma/5k/mlndonor2/mlndonor2/lognorm/data_external_reference_rctd_class_aware_Level1_importances_logreg.parquet
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_n_permutations=30_n_splits=5_top_n=20_precision_spatial_multivariate_logreg/all/raw/10x_mm_5um/melanoma/5k/mlndonor2/mlndonor2/lognorm/data_external_reference_rctd_class_aware_Level1_markers_rank_significance_logreg.parquet
# Processing futures:  15%|█▍        | 317/2160 [00:26<01:38, 18.73it/s]
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_top_n=20/all/raw/10x_0um/PDAC/immuno_oncology/pdacdonor1/pdacdonor1/lognorm/data_matched_reference_combo_rctd_class_aware_Level2.1_marker_genes.parquet
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_n_permutations=30_n_splits=5_top_n=20_precision_spatial_multivariate_logreg/all/raw/10x_0um/PDAC/immuno_oncology/pdacdonor1/pdacdonor1/lognorm/data_matched_reference_combo_rctd_class_aware_Level2.1_permutations_logreg.parquet
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_n_permutations=30_n_splits=5_top_n=20_precision_spatial_multivariate_logreg/all/raw/10x_0um/PDAC/immuno_oncology/pdacdonor1/pdacdonor1/lognorm/data_matched_reference_combo_rctd_class_aware_Level2.1_importances_logreg.parquet
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_n_permutations=30_n_splits=5_top_n=20_precision_spatial_multivariate_logreg/all/raw/10x_0um/PDAC/immuno_oncology/pdacdonor1/pdacdonor1/lognorm/data_matched_reference_combo_rctd_class_aware_Level2.1_markers_rank_significance_logreg.parquet
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_top_n=20/all/raw/10x_0um/melanoma/5k/mlndonor2/mlndonor2/lognorm/data_external_reference_rctd_class_aware_Level1_marker_genes.parquet
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_n_permutations=30_n_splits=5_top_n=20_precision_spatial_multivariate_logreg/all/raw/10x_0um/melanoma/5k/mlndonor2/mlndonor2/lognorm/data_external_reference_rctd_class_aware_Level1_permutations_logreg.parquet
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_n_permutations=30_n_splits=5_top_n=20_precision_spatial_multivariate_logreg/all/raw/10x_0um/melanoma/5k/mlndonor2/mlndonor2/lognorm/data_external_reference_rctd_class_aware_Level1_importances_logreg.parquet
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_n_permutations=30_n_splits=5_top_n=20_precision_spatial_multivariate_logreg/all/raw/10x_0um/melanoma/5k/mlndonor2/mlndonor2/lognorm/data_external_reference_rctd_class_aware_Level1_markers_rank_significance_logreg.parquet
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_top_n=20/all/raw/10x_0um/melanoma/skin/mlndonor1/mlndonor1/lognorm/data_external_reference_rctd_class_aware_Level1_marker_genes.parquet
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_n_permutations=30_n_splits=5_top_n=20_precision_spatial_multivariate_logreg/all/raw/10x_0um/melanoma/skin/mlndonor1/mlndonor1/lognorm/data_external_reference_rctd_class_aware_Level1_permutations_logreg.parquet
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_n_permutations=30_n_splits=5_top_n=20_precision_spatial_multivariate_logreg/all/raw/10x_0um/melanoma/skin/mlndonor1/mlndonor1/lognorm/data_external_reference_rctd_class_aware_Level1_importances_logreg.parquet
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_n_permutations=30_n_splits=5_top_n=20_precision_spatial_multivariate_logreg/all/raw/10x_0um/melanoma/skin/mlndonor1/mlndonor1/lognorm/data_external_reference_rctd_class_aware_Level1_markers_rank_significance_logreg.parquet
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_top_n=20/all/raw/10x_0um/CRC/immuno_oncology/crcdonor1/crcdonor1/lognorm/data_matched_reference_combo_rctd_class_aware_Level2.1_marker_genes.parquet
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_n_permutations=30_n_splits=5_top_n=20_precision_spatial_multivariate_logreg/all/raw/10x_0um/CRC/immuno_oncology/crcdonor1/crcdonor1/lognorm/data_matched_reference_combo_rctd_class_aware_Level2.1_permutations_logreg.parquet
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_n_permutations=30_n_splits=5_top_n=20_precision_spatial_multivariate_logreg/all/raw/10x_0um/CRC/immuno_oncology/crcdonor1/crcdonor1/lognorm/data_matched_reference_combo_rctd_class_aware_Level2.1_importances_logreg.parquet
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_n_permutations=30_n_splits=5_top_n=20_precision_spatial_multivariate_logreg/all/raw/10x_0um/CRC/immuno_oncology/crcdonor1/crcdonor1/lognorm/data_matched_reference_combo_rctd_class_aware_Level2.1_markers_rank_significance_logreg.parquet
# Processing futures:  17%|█▋        | 374/2160 [00:31<01:31, 19.59it/s]
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_top_n=20/all/split_fully_purified/proseg_expected/PDAC/immuno_oncology/pdacdonor1/pdacdonor1/lognorm/reference_based/matched_reference_combo/rctd_class_aware/Level2.1/single_cell/split_fully_purified/lognorm/data_matched_reference_combo_rctd_class_aware_Level2.1_marker_genes.parquet
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_n_permutations=30_n_splits=5_top_n=20_precision_spatial_multivariate_logreg/all/split_fully_purified/proseg_expected/PDAC/immuno_oncology/pdacdonor1/pdacdonor1/lognorm/reference_based/matched_reference_combo/rctd_class_aware/Level2.1/single_cell/split_fully_purified/lognorm/data_matched_reference_combo_rctd_class_aware_Level2.1_permutations_logreg.parquet
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_n_permutations=30_n_splits=5_top_n=20_precision_spatial_multivariate_logreg/all/split_fully_purified/proseg_expected/PDAC/immuno_oncology/pdacdonor1/pdacdonor1/lognorm/reference_based/matched_reference_combo/rctd_class_aware/Level2.1/single_cell/split_fully_purified/lognorm/data_matched_reference_combo_rctd_class_aware_Level2.1_importances_logreg.parquet
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_n_permutations=30_n_splits=5_top_n=20_precision_spatial_multivariate_logreg/all/split_fully_purified/proseg_expected/PDAC/immuno_oncology/pdacdonor1/pdacdonor1/lognorm/reference_based/matched_reference_combo/rctd_class_aware/Level2.1/single_cell/split_fully_purified/lognorm/data_matched_reference_combo_rctd_class_aware_Level2.1_markers_rank_significance_logreg.parquet
# Processing futures:  18%|█▊        | 382/2160 [00:32<01:23, 21.33it/s]
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_top_n=20/all/split_fully_purified/proseg_expected/melanoma/5k/mlndonor2/mlndonor2/lognorm/reference_based/external_reference/rctd_class_aware/Level1/single_cell/split_fully_purified/lognorm/data_external_reference_rctd_class_aware_Level1_marker_genes.parquet
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_n_permutations=30_n_splits=5_top_n=20_precision_spatial_multivariate_logreg/all/split_fully_purified/proseg_expected/melanoma/5k/mlndonor2/mlndonor2/lognorm/reference_based/external_reference/rctd_class_aware/Level1/single_cell/split_fully_purified/lognorm/data_external_reference_rctd_class_aware_Level1_permutations_logreg.parquet
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_n_permutations=30_n_splits=5_top_n=20_precision_spatial_multivariate_logreg/all/split_fully_purified/proseg_expected/melanoma/5k/mlndonor2/mlndonor2/lognorm/reference_based/external_reference/rctd_class_aware/Level1/single_cell/split_fully_purified/lognorm/data_external_reference_rctd_class_aware_Level1_importances_logreg.parquet
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_n_permutations=30_n_splits=5_top_n=20_precision_spatial_multivariate_logreg/all/split_fully_purified/proseg_expected/melanoma/5k/mlndonor2/mlndonor2/lognorm/reference_based/external_reference/rctd_class_aware/Level1/single_cell/split_fully_purified/lognorm/data_external_reference_rctd_class_aware_Level1_markers_rank_significance_logreg.parquet
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_top_n=20/all/split_fully_purified/proseg_expected/melanoma/skin/mlndonor1/mlndonor1/lognorm/reference_based/external_reference/rctd_class_aware/Level1/single_cell/split_fully_purified/lognorm/data_external_reference_rctd_class_aware_Level1_marker_genes.parquet
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_n_permutations=30_n_splits=5_top_n=20_precision_spatial_multivariate_logreg/all/split_fully_purified/proseg_expected/melanoma/skin/mlndonor1/mlndonor1/lognorm/reference_based/external_reference/rctd_class_aware/Level1/single_cell/split_fully_purified/lognorm/data_external_reference_rctd_class_aware_Level1_permutations_logreg.parquet
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_n_permutations=30_n_splits=5_top_n=20_precision_spatial_multivariate_logreg/all/split_fully_purified/proseg_expected/melanoma/skin/mlndonor1/mlndonor1/lognorm/reference_based/external_reference/rctd_class_aware/Level1/single_cell/split_fully_purified/lognorm/data_external_reference_rctd_class_aware_Level1_importances_logreg.parquet
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_n_permutations=30_n_splits=5_top_n=20_precision_spatial_multivariate_logreg/all/split_fully_purified/proseg_expected/melanoma/skin/mlndonor1/mlndonor1/lognorm/reference_based/external_reference/rctd_class_aware/Level1/single_cell/split_fully_purified/lognorm/data_external_reference_rctd_class_aware_Level1_markers_rank_significance_logreg.parquet
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_top_n=20/all/split_fully_purified/proseg_expected/CRC/immuno_oncology/crcdonor1/crcdonor1/lognorm/reference_based/matched_reference_combo/rctd_class_aware/Level2.1/single_cell/split_fully_purified/lognorm/data_matched_reference_combo_rctd_class_aware_Level2.1_marker_genes.parquet
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_n_permutations=30_n_splits=5_top_n=20_precision_spatial_multivariate_logreg/all/split_fully_purified/proseg_expected/CRC/immuno_oncology/crcdonor1/crcdonor1/lognorm/reference_based/matched_reference_combo/rctd_class_aware/Level2.1/single_cell/split_fully_purified/lognorm/data_matched_reference_combo_rctd_class_aware_Level2.1_permutations_logreg.parquet
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_n_permutations=30_n_splits=5_top_n=20_precision_spatial_multivariate_logreg/all/split_fully_purified/proseg_expected/CRC/immuno_oncology/crcdonor1/crcdonor1/lognorm/reference_based/matched_reference_combo/rctd_class_aware/Level2.1/single_cell/split_fully_purified/lognorm/data_matched_reference_combo_rctd_class_aware_Level2.1_importances_logreg.parquet
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_n_permutations=30_n_splits=5_top_n=20_precision_spatial_multivariate_logreg/all/split_fully_purified/proseg_expected/CRC/immuno_oncology/crcdonor1/crcdonor1/lognorm/reference_based/matched_reference_combo/rctd_class_aware/Level2.1/single_cell/split_fully_purified/lognorm/data_matched_reference_combo_rctd_class_aware_Level2.1_markers_rank_significance_logreg.parquet
# Processing futures:  23%|██▎       | 499/2160 [00:41<01:02, 26.39it/s]
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_top_n=20/all/split_fully_purified/10x_5um/PDAC/immuno_oncology/pdacdonor1/pdacdonor1/lognorm/reference_based/matched_reference_combo/rctd_class_aware/Level2.1/single_cell/split_fully_purified/lognorm/data_matched_reference_combo_rctd_class_aware_Level2.1_marker_genes.parquet
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_n_permutations=30_n_splits=5_top_n=20_precision_spatial_multivariate_logreg/all/split_fully_purified/10x_5um/PDAC/immuno_oncology/pdacdonor1/pdacdonor1/lognorm/reference_based/matched_reference_combo/rctd_class_aware/Level2.1/single_cell/split_fully_purified/lognorm/data_matched_reference_combo_rctd_class_aware_Level2.1_permutations_logreg.parquet
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_n_permutations=30_n_splits=5_top_n=20_precision_spatial_multivariate_logreg/all/split_fully_purified/10x_5um/PDAC/immuno_oncology/pdacdonor1/pdacdonor1/lognorm/reference_based/matched_reference_combo/rctd_class_aware/Level2.1/single_cell/split_fully_purified/lognorm/data_matched_reference_combo_rctd_class_aware_Level2.1_importances_logreg.parquet
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_n_permutations=30_n_splits=5_top_n=20_precision_spatial_multivariate_logreg/all/split_fully_purified/10x_5um/PDAC/immuno_oncology/pdacdonor1/pdacdonor1/lognorm/reference_based/matched_reference_combo/rctd_class_aware/Level2.1/single_cell/split_fully_purified/lognorm/data_matched_reference_combo_rctd_class_aware_Level2.1_markers_rank_significance_logreg.parquet
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_top_n=20/all/split_fully_purified/10x_5um/melanoma/5k/mlndonor2/mlndonor2/lognorm/reference_based/external_reference/rctd_class_aware/Level1/single_cell/split_fully_purified/lognorm/data_external_reference_rctd_class_aware_Level1_marker_genes.parquet
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_n_permutations=30_n_splits=5_top_n=20_precision_spatial_multivariate_logreg/all/split_fully_purified/10x_5um/melanoma/5k/mlndonor2/mlndonor2/lognorm/reference_based/external_reference/rctd_class_aware/Level1/single_cell/split_fully_purified/lognorm/data_external_reference_rctd_class_aware_Level1_permutations_logreg.parquet
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_n_permutations=30_n_splits=5_top_n=20_precision_spatial_multivariate_logreg/all/split_fully_purified/10x_5um/melanoma/5k/mlndonor2/mlndonor2/lognorm/reference_based/external_reference/rctd_class_aware/Level1/single_cell/split_fully_purified/lognorm/data_external_reference_rctd_class_aware_Level1_importances_logreg.parquet
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_n_permutations=30_n_splits=5_top_n=20_precision_spatial_multivariate_logreg/all/split_fully_purified/10x_5um/melanoma/5k/mlndonor2/mlndonor2/lognorm/reference_based/external_reference/rctd_class_aware/Level1/single_cell/split_fully_purified/lognorm/data_external_reference_rctd_class_aware_Level1_markers_rank_significance_logreg.parquet
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_top_n=20/all/split_fully_purified/10x_5um/melanoma/skin/mlndonor1/mlndonor1/lognorm/reference_based/external_reference/rctd_class_aware/Level1/single_cell/split_fully_purified/lognorm/data_external_reference_rctd_class_aware_Level1_marker_genes.parquet
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_n_permutations=30_n_splits=5_top_n=20_precision_spatial_multivariate_logreg/all/split_fully_purified/10x_5um/melanoma/skin/mlndonor1/mlndonor1/lognorm/reference_based/external_reference/rctd_class_aware/Level1/single_cell/split_fully_purified/lognorm/data_external_reference_rctd_class_aware_Level1_permutations_logreg.parquet
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_n_permutations=30_n_splits=5_top_n=20_precision_spatial_multivariate_logreg/all/split_fully_purified/10x_5um/melanoma/skin/mlndonor1/mlndonor1/lognorm/reference_based/external_reference/rctd_class_aware/Level1/single_cell/split_fully_purified/lognorm/data_external_reference_rctd_class_aware_Level1_importances_logreg.parquet
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_n_permutations=30_n_splits=5_top_n=20_precision_spatial_multivariate_logreg/all/split_fully_purified/10x_5um/melanoma/skin/mlndonor1/mlndonor1/lognorm/reference_based/external_reference/rctd_class_aware/Level1/single_cell/split_fully_purified/lognorm/data_external_reference_rctd_class_aware_Level1_markers_rank_significance_logreg.parquet
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_top_n=20/all/split_fully_purified/10x_5um/CRC/immuno_oncology/crcdonor1/crcdonor1/lognorm/reference_based/matched_reference_combo/rctd_class_aware/Level2.1/single_cell/split_fully_purified/lognorm/data_matched_reference_combo_rctd_class_aware_Level2.1_marker_genes.parquet
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_n_permutations=30_n_splits=5_top_n=20_precision_spatial_multivariate_logreg/all/split_fully_purified/10x_5um/CRC/immuno_oncology/crcdonor1/crcdonor1/lognorm/reference_based/matched_reference_combo/rctd_class_aware/Level2.1/single_cell/split_fully_purified/lognorm/data_matched_reference_combo_rctd_class_aware_Level2.1_permutations_logreg.parquet
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_n_permutations=30_n_splits=5_top_n=20_precision_spatial_multivariate_logreg/all/split_fully_purified/10x_5um/CRC/immuno_oncology/crcdonor1/crcdonor1/lognorm/reference_based/matched_reference_combo/rctd_class_aware/Level2.1/single_cell/split_fully_purified/lognorm/data_matched_reference_combo_rctd_class_aware_Level2.1_importances_logreg.parquet
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_n_permutations=30_n_splits=5_top_n=20_precision_spatial_multivariate_logreg/all/split_fully_purified/10x_5um/CRC/immuno_oncology/crcdonor1/crcdonor1/lognorm/reference_based/matched_reference_combo/rctd_class_aware/Level2.1/single_cell/split_fully_purified/lognorm/data_matched_reference_combo_rctd_class_aware_Level2.1_markers_rank_significance_logreg.parquet
# Processing futures:  27%|██▋       | 589/2160 [00:48<02:06, 12.43it/s]
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_top_n=20/all/split_fully_purified/10x_mm_5um/melanoma/5k/mlndonor2/mlndonor2/lognorm/reference_based/external_reference/rctd_class_aware/Level1/single_cell/split_fully_purified/lognorm/data_external_reference_rctd_class_aware_Level1_marker_genes.parquet
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_n_permutations=30_n_splits=5_top_n=20_precision_spatial_multivariate_logreg/all/split_fully_purified/10x_mm_5um/melanoma/5k/mlndonor2/mlndonor2/lognorm/reference_based/external_reference/rctd_class_aware/Level1/single_cell/split_fully_purified/lognorm/data_external_reference_rctd_class_aware_Level1_permutations_logreg.parquet
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_n_permutations=30_n_splits=5_top_n=20_precision_spatial_multivariate_logreg/all/split_fully_purified/10x_mm_5um/melanoma/5k/mlndonor2/mlndonor2/lognorm/reference_based/external_reference/rctd_class_aware/Level1/single_cell/split_fully_purified/lognorm/data_external_reference_rctd_class_aware_Level1_importances_logreg.parquet
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_n_permutations=30_n_splits=5_top_n=20_precision_spatial_multivariate_logreg/all/split_fully_purified/10x_mm_5um/melanoma/5k/mlndonor2/mlndonor2/lognorm/reference_based/external_reference/rctd_class_aware/Level1/single_cell/split_fully_purified/lognorm/data_external_reference_rctd_class_aware_Level1_markers_rank_significance_logreg.parquet
# Processing futures:  31%|███       | 671/2160 [00:56<01:51, 13.40it/s]
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_top_n=20/all/split_fully_purified/10x_0um/PDAC/immuno_oncology/pdacdonor1/pdacdonor1/lognorm/reference_based/matched_reference_combo/rctd_class_aware/Level2.1/single_cell/split_fully_purified/lognorm/data_matched_reference_combo_rctd_class_aware_Level2.1_marker_genes.parquet
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_n_permutations=30_n_splits=5_top_n=20_precision_spatial_multivariate_logreg/all/split_fully_purified/10x_0um/PDAC/immuno_oncology/pdacdonor1/pdacdonor1/lognorm/reference_based/matched_reference_combo/rctd_class_aware/Level2.1/single_cell/split_fully_purified/lognorm/data_matched_reference_combo_rctd_class_aware_Level2.1_permutations_logreg.parquet
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_n_permutations=30_n_splits=5_top_n=20_precision_spatial_multivariate_logreg/all/split_fully_purified/10x_0um/PDAC/immuno_oncology/pdacdonor1/pdacdonor1/lognorm/reference_based/matched_reference_combo/rctd_class_aware/Level2.1/single_cell/split_fully_purified/lognorm/data_matched_reference_combo_rctd_class_aware_Level2.1_importances_logreg.parquet
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_n_permutations=30_n_splits=5_top_n=20_precision_spatial_multivariate_logreg/all/split_fully_purified/10x_0um/PDAC/immuno_oncology/pdacdonor1/pdacdonor1/lognorm/reference_based/matched_reference_combo/rctd_class_aware/Level2.1/single_cell/split_fully_purified/lognorm/data_matched_reference_combo_rctd_class_aware_Level2.1_markers_rank_significance_logreg.parquet
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_top_n=20/all/split_fully_purified/10x_0um/melanoma/5k/mlndonor2/mlndonor2/lognorm/reference_based/external_reference/rctd_class_aware/Level1/single_cell/split_fully_purified/lognorm/data_external_reference_rctd_class_aware_Level1_marker_genes.parquet
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_n_permutations=30_n_splits=5_top_n=20_precision_spatial_multivariate_logreg/all/split_fully_purified/10x_0um/melanoma/5k/mlndonor2/mlndonor2/lognorm/reference_based/external_reference/rctd_class_aware/Level1/single_cell/split_fully_purified/lognorm/data_external_reference_rctd_class_aware_Level1_permutations_logreg.parquet
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_n_permutations=30_n_splits=5_top_n=20_precision_spatial_multivariate_logreg/all/split_fully_purified/10x_0um/melanoma/5k/mlndonor2/mlndonor2/lognorm/reference_based/external_reference/rctd_class_aware/Level1/single_cell/split_fully_purified/lognorm/data_external_reference_rctd_class_aware_Level1_importances_logreg.parquet
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_n_permutations=30_n_splits=5_top_n=20_precision_spatial_multivariate_logreg/all/split_fully_purified/10x_0um/melanoma/5k/mlndonor2/mlndonor2/lognorm/reference_based/external_reference/rctd_class_aware/Level1/single_cell/split_fully_purified/lognorm/data_external_reference_rctd_class_aware_Level1_markers_rank_significance_logreg.parquet
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_top_n=20/all/split_fully_purified/10x_0um/melanoma/skin/mlndonor1/mlndonor1/lognorm/reference_based/external_reference/rctd_class_aware/Level1/single_cell/split_fully_purified/lognorm/data_external_reference_rctd_class_aware_Level1_marker_genes.parquet
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_n_permutations=30_n_splits=5_top_n=20_precision_spatial_multivariate_logreg/all/split_fully_purified/10x_0um/melanoma/skin/mlndonor1/mlndonor1/lognorm/reference_based/external_reference/rctd_class_aware/Level1/single_cell/split_fully_purified/lognorm/data_external_reference_rctd_class_aware_Level1_permutations_logreg.parquet
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_n_permutations=30_n_splits=5_top_n=20_precision_spatial_multivariate_logreg/all/split_fully_purified/10x_0um/melanoma/skin/mlndonor1/mlndonor1/lognorm/reference_based/external_reference/rctd_class_aware/Level1/single_cell/split_fully_purified/lognorm/data_external_reference_rctd_class_aware_Level1_importances_logreg.parquet
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_n_permutations=30_n_splits=5_top_n=20_precision_spatial_multivariate_logreg/all/split_fully_purified/10x_0um/melanoma/skin/mlndonor1/mlndonor1/lognorm/reference_based/external_reference/rctd_class_aware/Level1/single_cell/split_fully_purified/lognorm/data_external_reference_rctd_class_aware_Level1_markers_rank_significance_logreg.parquet
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_top_n=20/all/split_fully_purified/10x_0um/CRC/immuno_oncology/crcdonor1/crcdonor1/lognorm/reference_based/matched_reference_combo/rctd_class_aware/Level2.1/single_cell/split_fully_purified/lognorm/data_matched_reference_combo_rctd_class_aware_Level2.1_marker_genes.parquet
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_n_permutations=30_n_splits=5_top_n=20_precision_spatial_multivariate_logreg/all/split_fully_purified/10x_0um/CRC/immuno_oncology/crcdonor1/crcdonor1/lognorm/reference_based/matched_reference_combo/rctd_class_aware/Level2.1/single_cell/split_fully_purified/lognorm/data_matched_reference_combo_rctd_class_aware_Level2.1_permutations_logreg.parquet
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_n_permutations=30_n_splits=5_top_n=20_precision_spatial_multivariate_logreg/all/split_fully_purified/10x_0um/CRC/immuno_oncology/crcdonor1/crcdonor1/lognorm/reference_based/matched_reference_combo/rctd_class_aware/Level2.1/single_cell/split_fully_purified/lognorm/data_matched_reference_combo_rctd_class_aware_Level2.1_importances_logreg.parquet
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_n_permutations=30_n_splits=5_top_n=20_precision_spatial_multivariate_logreg/all/split_fully_purified/10x_0um/CRC/immuno_oncology/crcdonor1/crcdonor1/lognorm/reference_based/matched_reference_combo/rctd_class_aware/Level2.1/single_cell/split_fully_purified/lognorm/data_matched_reference_combo_rctd_class_aware_Level2.1_markers_rank_significance_logreg.parquet
# Processing futures:  34%|███▍      | 742/2160 [01:01<00:55, 25.60it/s]
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_top_n=20/all/resolvi_panel_use_batch=True/proseg_expected/PDAC/immuno_oncology/pdacdonor1/pdacdonor1/mixture_k=50/num_samples=30/lognorm/data_matched_reference_combo_rctd_class_aware_Level2.1_marker_genes.parquet
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_n_permutations=30_n_splits=5_top_n=20_precision_spatial_multivariate_logreg/all/resolvi_panel_use_batch=True/proseg_expected/PDAC/immuno_oncology/pdacdonor1/pdacdonor1/mixture_k=50/num_samples=30/lognorm/data_matched_reference_combo_rctd_class_aware_Level2.1_permutations_logreg.parquet
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_n_permutations=30_n_splits=5_top_n=20_precision_spatial_multivariate_logreg/all/resolvi_panel_use_batch=True/proseg_expected/PDAC/immuno_oncology/pdacdonor1/pdacdonor1/mixture_k=50/num_samples=30/lognorm/data_matched_reference_combo_rctd_class_aware_Level2.1_importances_logreg.parquet
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_n_permutations=30_n_splits=5_top_n=20_precision_spatial_multivariate_logreg/all/resolvi_panel_use_batch=True/proseg_expected/PDAC/immuno_oncology/pdacdonor1/pdacdonor1/mixture_k=50/num_samples=30/lognorm/data_matched_reference_combo_rctd_class_aware_Level2.1_markers_rank_significance_logreg.parquet
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_top_n=20/all/resolvi_panel_use_batch=True/proseg_expected/melanoma/5k/mlndonor2/mlndonor2/mixture_k=50/num_samples=30/lognorm/data_external_reference_rctd_class_aware_Level1_marker_genes.parquet
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_n_permutations=30_n_splits=5_top_n=20_precision_spatial_multivariate_logreg/all/resolvi_panel_use_batch=True/proseg_expected/melanoma/5k/mlndonor2/mlndonor2/mixture_k=50/num_samples=30/lognorm/data_external_reference_rctd_class_aware_Level1_permutations_logreg.parquet
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_n_permutations=30_n_splits=5_top_n=20_precision_spatial_multivariate_logreg/all/resolvi_panel_use_batch=True/proseg_expected/melanoma/5k/mlndonor2/mlndonor2/mixture_k=50/num_samples=30/lognorm/data_external_reference_rctd_class_aware_Level1_importances_logreg.parquet
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_n_permutations=30_n_splits=5_top_n=20_precision_spatial_multivariate_logreg/all/resolvi_panel_use_batch=True/proseg_expected/melanoma/5k/mlndonor2/mlndonor2/mixture_k=50/num_samples=30/lognorm/data_external_reference_rctd_class_aware_Level1_markers_rank_significance_logreg.parquet
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_top_n=20/all/resolvi_panel_use_batch=True/proseg_expected/melanoma/skin/mlndonor1/mlndonor1/mixture_k=50/num_samples=30/lognorm/data_external_reference_rctd_class_aware_Level1_marker_genes.parquet
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_n_permutations=30_n_splits=5_top_n=20_precision_spatial_multivariate_logreg/all/resolvi_panel_use_batch=True/proseg_expected/melanoma/skin/mlndonor1/mlndonor1/mixture_k=50/num_samples=30/lognorm/data_external_reference_rctd_class_aware_Level1_permutations_logreg.parquet
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_n_permutations=30_n_splits=5_top_n=20_precision_spatial_multivariate_logreg/all/resolvi_panel_use_batch=True/proseg_expected/melanoma/skin/mlndonor1/mlndonor1/mixture_k=50/num_samples=30/lognorm/data_external_reference_rctd_class_aware_Level1_importances_logreg.parquet
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_n_permutations=30_n_splits=5_top_n=20_precision_spatial_multivariate_logreg/all/resolvi_panel_use_batch=True/proseg_expected/melanoma/skin/mlndonor1/mlndonor1/mixture_k=50/num_samples=30/lognorm/data_external_reference_rctd_class_aware_Level1_markers_rank_significance_logreg.parquet
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_top_n=20/all/resolvi_panel_use_batch=True/proseg_expected/CRC/immuno_oncology/crcdonor1/crcdonor1/mixture_k=50/num_samples=30/lognorm/data_matched_reference_combo_rctd_class_aware_Level2.1_marker_genes.parquet
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_n_permutations=30_n_splits=5_top_n=20_precision_spatial_multivariate_logreg/all/resolvi_panel_use_batch=True/proseg_expected/CRC/immuno_oncology/crcdonor1/crcdonor1/mixture_k=50/num_samples=30/lognorm/data_matched_reference_combo_rctd_class_aware_Level2.1_permutations_logreg.parquet
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_n_permutations=30_n_splits=5_top_n=20_precision_spatial_multivariate_logreg/all/resolvi_panel_use_batch=True/proseg_expected/CRC/immuno_oncology/crcdonor1/crcdonor1/mixture_k=50/num_samples=30/lognorm/data_matched_reference_combo_rctd_class_aware_Level2.1_importances_logreg.parquet
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_n_permutations=30_n_splits=5_top_n=20_precision_spatial_multivariate_logreg/all/resolvi_panel_use_batch=True/proseg_expected/CRC/immuno_oncology/crcdonor1/crcdonor1/mixture_k=50/num_samples=30/lognorm/data_matched_reference_combo_rctd_class_aware_Level2.1_markers_rank_significance_logreg.parquet
# Processing futures:  39%|███▉      | 850/2160 [01:08<01:21, 16.01it/s]
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_top_n=20/all/resolvi_panel_use_batch=True/10x_5um/PDAC/immuno_oncology/pdacdonor1/pdacdonor1/mixture_k=50/num_samples=30/lognorm/data_matched_reference_combo_rctd_class_aware_Level2.1_marker_genes.parquet
# ...
# File is empty: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_n_permutations=30_n_splits=5_top_n=20_precision_spatial_multivariate_logreg/all/ovrlpy_correction_signal_integrity_threshold=0.7/10x_15um/NSCLC/5k/1GVD/1GVD/lognorm/data_matched_reference_combo_rctd_class_aware_Level2.1_permutations_logreg.parquet
# Processing futures:  93%|█████████▎| 2019/2160 [02:26<00:08, 16.81it/s]
# File is empty: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_n_permutations=30_n_splits=5_top_n=20_precision_spatial_multivariate_logreg/all/ovrlpy_correction_signal_integrity_threshold=0.7/10x_15um/NSCLC/5k/1GVD/1GVD/lognorm/data_matched_reference_combo_rctd_class_aware_Level2.1_importances_logreg.parquet
# File is empty: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_n_permutations=30_n_splits=5_top_n=20_precision_spatial_multivariate_logreg/all/ovrlpy_correction_signal_integrity_threshold=0.7/10x_15um/NSCLC/5k/1GVD/1GVD/lognorm/data_matched_reference_combo_rctd_class_aware_Level2.1_markers_rank_significance_logreg.parquet
# Processing futures:  94%|█████████▍| 2029/2160 [02:27<00:07, 17.52it/s]
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_top_n=20/all/ovrlpy_correction_signal_integrity_threshold=0.7/10x_mm_5um/melanoma/5k/mlndonor2/mlndonor2/lognorm/data_external_reference_rctd_class_aware_Level1_marker_genes.parquet
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_n_permutations=30_n_splits=5_top_n=20_precision_spatial_multivariate_logreg/all/ovrlpy_correction_signal_integrity_threshold=0.7/10x_mm_5um/melanoma/5k/mlndonor2/mlndonor2/lognorm/data_external_reference_rctd_class_aware_Level1_permutations_logreg.parquet
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_n_permutations=30_n_splits=5_top_n=20_precision_spatial_multivariate_logreg/all/ovrlpy_correction_signal_integrity_threshold=0.7/10x_mm_5um/melanoma/5k/mlndonor2/mlndonor2/lognorm/data_external_reference_rctd_class_aware_Level1_importances_logreg.parquet
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_n_permutations=30_n_splits=5_top_n=20_precision_spatial_multivariate_logreg/all/ovrlpy_correction_signal_integrity_threshold=0.7/10x_mm_5um/melanoma/5k/mlndonor2/mlndonor2/lognorm/data_external_reference_rctd_class_aware_Level1_markers_rank_significance_logreg.parquet
# File is empty: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_n_permutations=30_n_splits=5_top_n=20_precision_spatial_multivariate_logreg/all/ovrlpy_correction_signal_integrity_threshold=0.7/10x_mm_5um/NSCLC/5k/0PSV/0PSV/lognorm/data_matched_reference_combo_rctd_class_aware_Level2.1_permutations_logreg.parquet
# File is empty: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_n_permutations=30_n_splits=5_top_n=20_precision_spatial_multivariate_logreg/all/ovrlpy_correction_signal_integrity_threshold=0.7/10x_mm_5um/NSCLC/5k/0PSV/0PSV/lognorm/data_matched_reference_combo_rctd_class_aware_Level2.1_importances_logreg.parquet
# File is empty: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_n_permutations=30_n_splits=5_top_n=20_precision_spatial_multivariate_logreg/all/ovrlpy_correction_signal_integrity_threshold=0.7/10x_mm_5um/NSCLC/5k/0PSV/0PSV/lognorm/data_matched_reference_combo_rctd_class_aware_Level2.1_markers_rank_significance_logreg.parquet
# File is empty: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_n_permutations=30_n_splits=5_top_n=20_precision_spatial_multivariate_logreg/all/ovrlpy_correction_signal_integrity_threshold=0.7/10x_mm_5um/NSCLC/5k/1GAC/1GAC/lognorm/data_matched_reference_combo_rctd_class_aware_Level2.1_permutations_logreg.parquet
# File is empty: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_n_permutations=30_n_splits=5_top_n=20_precision_spatial_multivariate_logreg/all/ovrlpy_correction_signal_integrity_threshold=0.7/10x_mm_5um/NSCLC/5k/1GAC/1GAC/lognorm/data_matched_reference_combo_rctd_class_aware_Level2.1_importances_logreg.parquet
# File is empty: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_n_permutations=30_n_splits=5_top_n=20_precision_spatial_multivariate_logreg/all/ovrlpy_correction_signal_integrity_threshold=0.7/10x_mm_5um/NSCLC/5k/1GAC/1GAC/lognorm/data_matched_reference_combo_rctd_class_aware_Level2.1_markers_rank_significance_logreg.parquet
# Processing futures:  94%|█████████▍| 2041/2160 [02:27<00:05, 19.88it/s]
# File is empty: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_n_permutations=30_n_splits=5_top_n=20_precision_spatial_multivariate_logreg/all/ovrlpy_correction_signal_integrity_threshold=0.7/10x_mm_5um/NSCLC/5k/1GVD/1GVD/lognorm/data_matched_reference_combo_rctd_class_aware_Level2.1_permutations_logreg.parquet
# File is empty: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_n_permutations=30_n_splits=5_top_n=20_precision_spatial_multivariate_logreg/all/ovrlpy_correction_signal_integrity_threshold=0.7/10x_mm_5um/NSCLC/5k/1GVD/1GVD/lognorm/data_matched_reference_combo_rctd_class_aware_Level2.1_importances_logreg.parquet
# File is empty: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_n_permutations=30_n_splits=5_top_n=20_precision_spatial_multivariate_logreg/all/ovrlpy_correction_signal_integrity_threshold=0.7/10x_mm_5um/NSCLC/5k/1GVD/1GVD/lognorm/data_matched_reference_combo_rctd_class_aware_Level2.1_markers_rank_significance_logreg.parquet
# Processing futures:  98%|█████████▊| 2111/2160 [02:32<00:02, 18.64it/s]
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_top_n=20/all/ovrlpy_correction_signal_integrity_threshold=0.7/10x_0um/PDAC/immuno_oncology/pdacdonor1/pdacdonor1/lognorm/data_matched_reference_combo_rctd_class_aware_Level2.1_marker_genes.parquet
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_n_permutations=30_n_splits=5_top_n=20_precision_spatial_multivariate_logreg/all/ovrlpy_correction_signal_integrity_threshold=0.7/10x_0um/PDAC/immuno_oncology/pdacdonor1/pdacdonor1/lognorm/data_matched_reference_combo_rctd_class_aware_Level2.1_permutations_logreg.parquet
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_n_permutations=30_n_splits=5_top_n=20_precision_spatial_multivariate_logreg/all/ovrlpy_correction_signal_integrity_threshold=0.7/10x_0um/PDAC/immuno_oncology/pdacdonor1/pdacdonor1/lognorm/data_matched_reference_combo_rctd_class_aware_Level2.1_importances_logreg.parquet
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_n_permutations=30_n_splits=5_top_n=20_precision_spatial_multivariate_logreg/all/ovrlpy_correction_signal_integrity_threshold=0.7/10x_0um/PDAC/immuno_oncology/pdacdonor1/pdacdonor1/lognorm/data_matched_reference_combo_rctd_class_aware_Level2.1_markers_rank_significance_logreg.parquet
# Processing futures:  98%|█████████▊| 2123/2160 [02:32<00:01, 27.03it/s]
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_top_n=20/all/ovrlpy_correction_signal_integrity_threshold=0.7/10x_0um/melanoma/5k/mlndonor2/mlndonor2/lognorm/data_external_reference_rctd_class_aware_Level1_marker_genes.parquet
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_n_permutations=30_n_splits=5_top_n=20_precision_spatial_multivariate_logreg/all/ovrlpy_correction_signal_integrity_threshold=0.7/10x_0um/melanoma/5k/mlndonor2/mlndonor2/lognorm/data_external_reference_rctd_class_aware_Level1_permutations_logreg.parquet
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_n_permutations=30_n_splits=5_top_n=20_precision_spatial_multivariate_logreg/all/ovrlpy_correction_signal_integrity_threshold=0.7/10x_0um/melanoma/5k/mlndonor2/mlndonor2/lognorm/data_external_reference_rctd_class_aware_Level1_importances_logreg.parquet
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_n_permutations=30_n_splits=5_top_n=20_precision_spatial_multivariate_logreg/all/ovrlpy_correction_signal_integrity_threshold=0.7/10x_0um/melanoma/5k/mlndonor2/mlndonor2/lognorm/data_external_reference_rctd_class_aware_Level1_markers_rank_significance_logreg.parquet
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_top_n=20/all/ovrlpy_correction_signal_integrity_threshold=0.7/10x_0um/melanoma/skin/mlndonor1/mlndonor1/lognorm/data_external_reference_rctd_class_aware_Level1_marker_genes.parquet
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_n_permutations=30_n_splits=5_top_n=20_precision_spatial_multivariate_logreg/all/ovrlpy_correction_signal_integrity_threshold=0.7/10x_0um/melanoma/skin/mlndonor1/mlndonor1/lognorm/data_external_reference_rctd_class_aware_Level1_permutations_logreg.parquet
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_n_permutations=30_n_splits=5_top_n=20_precision_spatial_multivariate_logreg/all/ovrlpy_correction_signal_integrity_threshold=0.7/10x_0um/melanoma/skin/mlndonor1/mlndonor1/lognorm/data_external_reference_rctd_class_aware_Level1_importances_logreg.parquet
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_top_n=20/all/ovrlpy_correction_signal_integrity_threshold=0.7/10x_0um/CRC/immuno_oncology/crcdonor1/crcdonor1/lognorm/data_matched_reference_combo_rctd_class_aware_Level2.1_marker_genes.parquet
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_n_permutations=30_n_splits=5_top_n=20_precision_spatial_multivariate_logreg/all/ovrlpy_correction_signal_integrity_threshold=0.7/10x_0um/CRC/immuno_oncology/crcdonor1/crcdonor1/lognorm/data_matched_reference_combo_rctd_class_aware_Level2.1_permutations_logreg.parquet
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_n_permutations=30_n_splits=5_top_n=20_precision_spatial_multivariate_logreg/all/ovrlpy_correction_signal_integrity_threshold=0.7/10x_0um/melanoma/skin/mlndonor1/mlndonor1/lognorm/data_external_reference_rctd_class_aware_Level1_markers_rank_significance_logreg.parquet
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_n_permutations=30_n_splits=5_top_n=20_precision_spatial_multivariate_logreg/all/ovrlpy_correction_signal_integrity_threshold=0.7/10x_0um/CRC/immuno_oncology/crcdonor1/crcdonor1/lognorm/data_matched_reference_combo_rctd_class_aware_Level2.1_importances_logreg.parquet
# File does not exist: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_n_permutations=30_n_splits=5_top_n=20_precision_spatial_multivariate_logreg/all/ovrlpy_correction_signal_integrity_threshold=0.7/10x_0um/CRC/immuno_oncology/crcdonor1/crcdonor1/lognorm/data_matched_reference_combo_rctd_class_aware_Level2.1_markers_rank_significance_logreg.parquet
# Processing futures:  99%|█████████▉| 2140/2160 [02:33<00:00, 24.58it/s]
# File is empty: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_n_permutations=30_n_splits=5_top_n=20_precision_spatial_multivariate_logreg/all/ovrlpy_correction_signal_integrity_threshold=0.7/10x_0um/NSCLC/5k/0PSV/0PSV/lognorm/data_matched_reference_combo_rctd_class_aware_Level2.1_permutations_logreg.parquet
# File is empty: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_n_permutations=30_n_splits=5_top_n=20_precision_spatial_multivariate_logreg/all/ovrlpy_correction_signal_integrity_threshold=0.7/10x_0um/NSCLC/5k/1GAC/1GAC/lognorm/data_matched_reference_combo_rctd_class_aware_Level2.1_permutations_logreg.parquet
# File is empty: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_n_permutations=30_n_splits=5_top_n=20_precision_spatial_multivariate_logreg/all/ovrlpy_correction_signal_integrity_threshold=0.7/10x_0um/NSCLC/5k/0PSV/0PSV/lognorm/data_matched_reference_combo_rctd_class_aware_Level2.1_importances_logreg.parquet
# File is empty: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_n_permutations=30_n_splits=5_top_n=20_precision_spatial_multivariate_logreg/all/ovrlpy_correction_signal_integrity_threshold=0.7/10x_0um/NSCLC/5k/0PSV/0PSV/lognorm/data_matched_reference_combo_rctd_class_aware_Level2.1_markers_rank_significance_logreg.parquet
# File is empty: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_n_permutations=30_n_splits=5_top_n=20_precision_spatial_multivariate_logreg/all/ovrlpy_correction_signal_integrity_threshold=0.7/10x_0um/NSCLC/5k/1GAC/1GAC/lognorm/data_matched_reference_combo_rctd_class_aware_Level2.1_importances_logreg.parquet
# File is empty: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_n_permutations=30_n_splits=5_top_n=20_precision_spatial_multivariate_logreg/all/ovrlpy_correction_signal_integrity_threshold=0.7/10x_0um/NSCLC/5k/1GAC/1GAC/lognorm/data_matched_reference_combo_rctd_class_aware_Level2.1_markers_rank_significance_logreg.parquet
# File is empty: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_n_permutations=30_n_splits=5_top_n=20_precision_spatial_multivariate_logreg/all/ovrlpy_correction_signal_integrity_threshold=0.7/10x_0um/NSCLC/5k/1GVD/1GVD/lognorm/data_matched_reference_combo_rctd_class_aware_Level2.1_permutations_logreg.parquet
# File is empty: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_n_permutations=30_n_splits=5_top_n=20_precision_spatial_multivariate_logreg/all/ovrlpy_correction_signal_integrity_threshold=0.7/10x_0um/NSCLC/5k/1GVD/1GVD/lognorm/data_matched_reference_combo_rctd_class_aware_Level2.1_importances_logreg.parquet
# File is empty: /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/results/contamination_metrics_diffexpr_radius=15_n_permutations=30_n_splits=5_top_n=20_precision_spatial_multivariate_logreg/all/ovrlpy_correction_signal_integrity_threshold=0.7/10x_0um/NSCLC/5k/1GVD/1GVD/lognorm/data_matched_reference_combo_rctd_class_aware_Level2.1_markers_rank_significance_logreg.parquet
# Processing futures: 100%|██████████| 2160/2160 [02:35<00:00, 13.93it/s]

# %% [markdown]
# # Plot decontamination results marker ranks

# %%
ref_panel = '5k'
cti = 'T cell'
ctj = 'malignant cell'
use_precomputed = True
n = 20
min_sample_size = None
min_sample_size_mode = 'specific'

if min_sample_size is not None:
    plot_metric_summary_stats = 'df_has_neighbor_counts'
    df_sample_sizes = _utils.get_df_summary_stats_plot(dfs_diffexpr,plot_metric=plot_metric_summary_stats)
    df_sample_sizes[f'{cti}_has_{ctj}_neighbor'] = _utils.extract_info_cell_type_pair(df_sample_sizes[plot_metric_summary_stats],cti,ctj,True)
    df_sample_sizes[f'{cti}_has_no_{ctj}_neighbor'] = _utils.extract_info_cell_type_pair(df_sample_sizes[plot_metric_summary_stats],cti,ctj,False)
    df_sample_sizes['min_class_sample_size'] = df_sample_sizes[[f'{cti}_has_{ctj}_neighbor',f'{cti}_has_no_{ctj}_neighbor']].min(1)
    
    unique_labels = [c for c in hue_correction_order if c in np.unique(df_sample_sizes[hue_correction].dropna())]
    unique_labels = unique_labels + [c for c in np.unique(df_sample_sizes[hue_correction].dropna()) if c not in unique_labels]
    palette = {u: count_correction_palette[u] for u in unique_labels}
    legend_handles = [Patch(color=color, label=label) for label, color in palette.items()]

    f = plt.figure(figsize=(10, 4))
    ax = plt.subplot()
    sns.boxplot(df_sample_sizes,x='segmentation',y='min_class_sample_size',
                hue=hue_correction, hue_order=unique_labels, 
                legend=False, palette=palette,ax=ax,
                order=[s for s in hue_segmentation_order if s in df_sample_sizes['segmentation'].unique()],
                boxprops={"alpha": 0.4},
                showfliers=False,
    )
    sns.stripplot(
        df_sample_sizes,
        x="segmentation",
        y='min_class_sample_size',
        hue=hue_correction,
        hue_order=unique_labels,
        legend=False,
        palette=palette,
        ax=ax,
        order=[s for s in hue_segmentation_order if s in df_sample_sizes["segmentation"].unique()],
        dodge=True,
        jitter=True,
        s=3.5,
    )

    sns.despine()

    plt.suptitle("Min class sample sizes",y=1.05)
    f.legend(
        handles=legend_handles,
        loc="center left",
        bbox_to_anchor=(1, 0.5),
        title=hue_correction,
        frameon=False,
    )
    plt.show()
    plt.close()


for rank_metric in rank_metrics:
    plot_metrics_ = plot_metrics[-1:] if rank_metric == 'mean_zscore' else plot_metrics
    for plot_metric in plot_metrics_:
        df = _utils.get_df_marker_rank_significance_plot(dfs['df_markers_rank_significance_logreg'],
                        rank_metric=rank_metric,plot_metric=plot_metric,
                        correction_methods=correction_methods,use_precomputed=use_precomputed,
                        n = n)

        df = df.query("panel == @ref_panel and cti == @cti and ctj == @ctj")
        if min_sample_size is not None:

            if min_sample_size_mode == 'all':
                result = df_sample_sizes.groupby(xenium_levels[1:])['min_class_sample_size'].min().reset_index()
                df = df.merge(result,on=xenium_levels[1:])
                df = df.query("min_class_sample_size >= @min_sample_size")

            elif min_sample_size_mode == 'specific':
                df = df.merge(df_sample_sizes,on=xenium_levels+['correction_method'])
                df = df.query("min_class_sample_size >= @min_sample_size")

        if plot_metric in ['hypergeometric_pvalue','mean_zscore_pvalue']:
            df['-log10pvalue'] = -np.log10(df[plot_metric].astype(float))
            plot_metric = '-log10pvalue'

        # plotting params, palette
        title = f"Panel: {ref_panel}, Reference: {reference}, Method: {method}, Level: {level} \n{cti} contaminated by {ctj}\n rank metric: {rank_metric}, plot metric: {plot_metric}, {use_precomputed=}"
        unique_labels = [c for c in hue_correction_order if c in np.unique(df[hue_correction].dropna())]
        unique_labels = unique_labels + [c for c in np.unique(df[hue_correction].dropna()) if c not in unique_labels]
        palette = {u: count_correction_palette[u] for u in unique_labels}
        legend_handles = [Patch(color=color, label=label) for label, color in palette.items()]

        ### hypergeometric pvalue boxplot
        f = plt.figure(figsize=(7, 6))
        ax = plt.subplot()
        g = sns.boxplot(
            df,
            x="segmentation",
            y=plot_metric,
            hue=hue_correction,
            hue_order=unique_labels,
            legend=False,
            palette=palette,
            ax=ax,
            order=[s for s in hue_segmentation_order if s in df["segmentation"].unique()],
            # flierprops={
            #     "marker": "o",
            #     "color": "black",
            #     "markersize": 1,
            #     "markerfacecolor": "w",
            # },
            boxprops={"alpha": 0.4},
            showfliers=False,
        )
        sns.stripplot(
            df,
            x="segmentation",
            y=plot_metric,
            hue=hue_correction,
            hue_order=unique_labels,
            legend=False,
            palette=palette,
            ax=ax,
            order=[s for s in hue_segmentation_order if s in df["segmentation"].unique()],
            dodge=True,
            jitter=True,
            s=3.5,
        )

        sns.despine()
        ax.yaxis.grid(True)
        ax.tick_params(axis='x', labelsize=14)
        ax.tick_params(axis='y', labelsize=16)
        if plot_metric == '"-log10pvalue"':
            ax.set.ylabel(r"$-\log_{10} \text{ p-value}$", fontsize=14)
        else:
            ax.set_ylabel(plot_metric, fontsize=14)
        plt.show()
        plt.close()

# %%
ref_segmentation = '10x_5um'
cti = 'T cell'
ctj = 'malignant cell'
use_precomputed = True

for rank_metric in rank_metrics:
    for plot_metric in plot_metrics:
        # extract df for rank_metric used for diffexpr and plot_metric used for GSEA/hypergeometric test
        df = _utils.get_df_marker_rank_significance_plot(dfs['df_markers_rank_significance_logreg'],
                        rank_metric=rank_metric,plot_metric=plot_metric,
                        correction_methods=correction_methods,use_precomputed=use_precomputed)
        
        df[plot_metric] = df[plot_metric].astype(float)
        
        if plot_metric == 'hypergeometric_pvalue':
            df['-log10pvalue'] = -np.log10(df[plot_metric])
            plot_metric = '-log10pvalue'

        u_condition_panel = df[['condition','panel']].drop_duplicates().values

        for condition,panel in u_condition_panel:

            df_plot = df.query(f"segmentation == '{ref_segmentation}' and condition == '{condition}' and panel == '{panel}'")
            df_plot = df_plot.groupby(['cti', 'ctj'])[plot_metric].mean().unstack()
            df_plot = df_plot.loc[df_plot.sum(1).sort_values(ascending=False).index]
            df_plot = df_plot[df_plot.sum(0).sort_values(ascending=False).index]

            title = f"Condition: {condition}, Panel: {panel}, Reference: {reference}, Method: {method}, Level: {level} \nrank metric: {rank_metric}, plot metric: {plot_metric}, {use_precomputed=}"

            f = plt.figure(figsize=(8,8))
            ax = plt.subplot()
            ax.set_title(title,fontsize=20)
            g = sns.heatmap(df_plot,cmap='coolwarm',center=-np.log10(0.05) if plot_metric == '-log10pvalue' else 0.)
            plt.show()

# %% [markdown]
# # Plot results permutation precision scores

# %%
ref_panel = '5k'
cti = 'T cell'
ctj = 'malignant cell'

df = _utils.get_df_permutations_logreg_plot(dfs['df_permutations_logreg'],correction_methods)
df = df.query("panel == @ref_panel and cti == @cti and ctj == @ctj")
df['precision_difference'] = df['precision_score'] - df['perm_meanprecision_score']

df_palette = pd.read_csv(count_correction_palette, index_col=0).iloc[:, 0]

for plot_metric in ['precision_score','perm_meanprecision_score','precision_difference','p_value','effect_size']:
    if plot_metric in ['p_value']:
        df['-log10pvalue'] = -np.log10(df[plot_metric].astype(float))
        plot_metric = '-log10pvalue'

    # plotting params, palette
    title = f"Panel: {ref_panel}, Reference: {reference}, Method: {method}, Level: {level} \n{cti} contaminated by {ctj}\n rank metric: {rank_metric}, plot metric: {plot_metric}, {use_precomputed=}"
    unique_labels = [c for c in hue_correction_order if c in np.unique(df[hue_correction].dropna())]
    unique_labels = unique_labels + [c for c in np.unique(df[hue_correction].dropna()) if c not in unique_labels]
    palette = {u: df_palette[u] for u in unique_labels}
    legend_handles = [Patch(color=color, label=label) for label, color in palette.items()]

    ### hypergeometric pvalue boxplot
    f = plt.figure(figsize=(10, 4))
    ax = plt.subplot()
    g = sns.boxplot(df,x='segmentation',y=plot_metric, 
                    hue=hue_correction, hue_order=unique_labels, 
                    legend=False, palette=palette,ax=ax,
                    order=[s for s in hue_segmentation_order if s in df['segmentation'].unique()],
                    # log_scale=True
                    )

    sns.despine()
    ax.yaxis.grid(True)

    plt.suptitle(title,y=1.05)
    f.legend(
        handles=legend_handles,
        loc="center left",
        bbox_to_anchor=(1, 0.5),
        title=hue_correction,
        frameon=False,
    )
    # plt.tight_layout(rect=[0, 0, 1, 0.95])
    # plt.savefig(out_file, dpi=dpi, bbox_inches="tight")
    plt.show()

# %% [markdown]
# # Plot sample sizes

# %%
cti = 'T cell'
ctj = 'malignant cell'
ref_panel = 'lung'
plot_metric = 'df_has_neighbor_counts'


dfs_diffexpr = _utils.get_df_summary_stats_plot(dfs_diffexpr,plot_metric=plot_metric)
dfs_diffexpr = dfs_diffexpr.query("panel == @ref_panel")

dfs_diffexpr[f'{cti}_has_{ctj}_neighbor'] = _utils.extract_info_cell_type_pair(dfs_diffexpr[plot_metric],cti,ctj,True)
dfs_diffexpr[f'{cti}_has_no_{ctj}_neighbor'] = _utils.extract_info_cell_type_pair(dfs_diffexpr[plot_metric],cti,ctj,False)

# plotting params, palette
unique_labels = [c for c in hue_correction_order if c in np.unique(dfs_diffexpr[hue_correction].dropna())]
unique_labels = unique_labels + [c for c in np.unique(dfs_diffexpr[hue_correction].dropna()) if c not in unique_labels]
# palette = {u: palette[u] for u in unique_labels}
palette = dict(zip(unique_labels,sns.palettes.hls_palette(len(unique_labels))))
legend_handles = [mpatches.Patch(color=color, label=label) for label, color in palette.items()]

###  boxplot
for y in [f'{cti}_has_{ctj}_neighbor',f'{cti}_has_no_{ctj}_neighbor']:

    title = f"{y} for {ref_panel}"

    f = plt.figure(figsize=(10, 4))
    ax = plt.subplot()
    g = sns.boxplot(dfs_diffexpr,x='segmentation',y=y, 
                    hue=hue_correction, hue_order=unique_labels, 
                    legend=False, palette=palette,ax=ax,
                    # order=[s for s in hue_segmentation_order if s in dfs_diffexpr['segmentation'].unique()],
                    log_scale=True,
                    showfliers=True
                    )

    sns.despine()
    ax.yaxis.grid(True)
    plt.xticks(rotation=45, ha='right')

    plt.suptitle(title)
    f.legend(
        handles=legend_handles,
        loc="center left",
        bbox_to_anchor=(1, 0.5),
        title=hue_correction,
        frameon=False,
    )

# %% [markdown]
# # Paper figure plot: importance ranks

# %%
cti = 'T cell'
ctj = 'malignant cell'

top_n = 20
lung_genes_only = True
list_mode = ['importances','diffexpr']
list_ref_panels = ['lung','5k','breast']
list_rank_method = ['mean']
list_scale_method = ['abssum']
list_ref_segmentations = ['5µm','ProSeg']
keep_annotations = [
    'T cell', 
    'canonical T cell marker',
    'regulatory T cell',
    'exhausted T cell',
    'cytotoxic T cell',
    'immune response',
    'proliferation',
    'malignant cell',
    'fibroblast', 
    'epithelial cell'
    ]

palette = {
    'T cell': '#2ECC71',
    'canonical T cell marker': '#1ABC9C',
    'regulatory T cell': '#17A589',
    'exhausted T cell': '#2980B9',
    'cytotoxic T cell': '#3498DB',
    'immune response': '#5D6D7E',
    'proliferation': '#E67E22',
    'malignant cell': '#C0392B',
    'fibroblast': '#9B59B6',
    'epithelial cell': '#F1C40F',
    'Other': '#FFFFFF'
}


for mode, ref_panel, rank_method, scale_method in itertools.product(list_mode, list_ref_panels, list_rank_method, list_scale_method):

    # define gene labels
    if ref_panel in ['lung','5k']:
        gene_labels = pd.read_csv(cfg['markers_dir']+'Xenium_hLung_v1_metadata_DB.csv',encoding='latin1')[['Gene','Annotation_DB']]
    elif ref_panel == 'breast':
        gene_labels = pd.read_csv(cfg['markers_dir']+'Xenium_hBreast_v1_metadata_DB.csv',encoding='latin1')[['Genes','Annotation_DB']]
    gene_labels.columns = ['Gene','Label']
    gene_labels.loc[~gene_labels['Label'].isin(keep_annotations),'Label'] = 'Other'
    gene_labels = gene_labels.set_index('Gene')['Label'].to_dict()

    # load data
    if mode =='importances':
        df_importances_logreg = _utils.get_df_importances_cti_ctj(dfs['df_importances_logreg'], cti, ctj, ref_panel, correction_methods)

        # scale data
        df_norm = df_importances_logreg.copy()
        if scale_method == 'abssum':
            df_norm.iloc[:,8:] =  df_norm.iloc[:,8:].div(df_norm.iloc[:,8:].abs().sum(axis=1),axis=0)
        elif scale_method == 'zscore':
            df_norm.iloc[:,8:] =  zscore(df_norm.iloc[:,8:],axis=0)

    elif mode =='diffexpr':
        df_diffexpr = _utils.get_df_diffexpr_cti_ctj(dfs_diffexpr['df_diffexpr'], cti, ctj, ref_panel, correction_methods, rank_metric='logfoldchanges')
        df_norm = df_diffexpr.copy()

    # filter data
    if ref_panel == '5k' and lung_genes_only:
        lung_panel_genes = pd.read_csv(cfg['markers_dir']+'Xenium_hLung_v1_metadata.csv')['Gene'].tolist()
        retain_cols = df_norm.columns[:8].tolist()+[g for g in lung_panel_genes if g in df_norm.columns]
        df_norm = df_norm[retain_cols]

    # --- Identify metadata and importance (gene) columns in df_norm ---
    metadata_cols = ['correction_method', 'segmentation', 'condition', 'panel', 'donor', 'sample', 'cti', 'ctj']
    importance_cols = df_norm.columns.difference(metadata_cols, sort=False).tolist()

    all_plot_data_long = {}
    for ref_segmentation in list_ref_segmentations:
        
        # --- Get unique combinations of grouping variables ---
        groups = [[g,ref_segmentation] for g in hue_correction_order]
        num_groups = len(groups)

        # --- Setup Subplots ---
        ncols = num_groups
        nrows = 1

        base_width_per_plot = 3  # Adjust as needed
        base_height_per_plot = 7 # Taller for vertical plots with rotated labels
        fig_width = base_width_per_plot * ncols
        fig_height = base_height_per_plot * nrows

        fig, axes = plt.subplots(nrows=nrows, ncols=ncols, figsize=(fig_width, fig_height),squeeze=False) # Ensure axes is always 2D
        axes_flat = axes.flatten()

        # --- Generate plot for each group ---
        for i, group_vals in enumerate(groups):
            correction_method, segmentation = group_vals
            ax = axes_flat[i]

            # 1. Filter df_norm for the current group
            group_df = df_norm[
                (df_norm['correction_method'] == correction_method) &
                (df_norm['segmentation'] == segmentation)
            ].copy() # Use .copy() to avoid SettingWithCopyWarning later
        
            group_importances = group_df[importance_cols]
            if rank_method == 'mean':
                overall_importances = group_importances.mean(axis=0).dropna()
            elif rank_method == 'median':
                overall_importances = group_importances.median(axis=0).dropna()

            n_top = min(top_n, len(overall_importances))
            top_genes = overall_importances.nlargest(n_top).index.tolist()
            # top_genes = df_labeling_info['Gene'].values

            # 3. Prepare data for plotting: Melt and Add Labels
            # Ensure only top genes are selected *before* melting
            melt_data = group_df[top_genes]
            plot_data_long = melt_data.melt(
                var_name='Gene',
                value_name='Importance'
            )

            # **** Add the 'Label' column for coloring ****
            plot_data_long['Label'] = plot_data_long['Gene'].map(gene_labels)
            # Handle genes that might be missing a label
            plot_data_long['Label'] = plot_data_long['Label'].fillna('Other')

            # Check if any labels were actually assigned
            hue_param = 'Label'
            all_plot_data_long[correction_method, segmentation] = plot_data_long
            sns.boxplot(
                data=plot_data_long,
                x='Importance',          # Genes on X-axis -> Vertical boxes
                y='Gene',    # Values on Y-axis
                hue=hue_param,     # Color by the 'Label' column
                order=top_genes,   # Order genes by mean importance
                palette=palette, # Use the defined label-color mapping
                dodge=False,       # Don't shift boxes for hue, color the whole box
                ax=ax,             # Draw on the correct subplot axis
                fliersize=1.5,
                legend=False
            )

            # 5. Customize the SUBPLOT
            ax.set_title(f'{correction_method}\n{segmentation}', fontsize=10)
            ax.grid(axis='x', linestyle='--', alpha=0.6)
            ax.axvline(0.0, color='k', linestyle='-', zorder=-1, alpha=0.5)
            if mode == 'diffexpr':
                ax.set_xlabel('Log fold-change', fontsize=9)
            else:
                ax.set_xlabel('Importance Score', fontsize=9)

            if i % ncols == 0:
                ax.set_ylabel('Gene', fontsize=9)
            else:
                ax.set_ylabel('')


        # Adjust legend position
        handles = [Patch(facecolor=color, label=label) for label, color in palette.items()]
        fig.legend(handles=handles, labels=list(palette.keys()), title="Gene Label",
                    bbox_to_anchor=(.94, 0.7), loc='upper left', fontsize=9, title_fontsize=10)
        fig.tight_layout(rect=[0, 0.03, 0.95, 0.95]) 

        # save
        df_save = pd.concat(all_plot_data_long)
        Path(cfg['figures_dir']+f"rankings_{mode}").mkdir(parents=True, exist_ok=True)
        df_save.to_csv(cfg['figures_dir']+f"rankings_{mode}/rankings_{mode}_{ref_panel=}_{ref_segmentation=}_{rank_method=}_{scale_method=}_{cti}_{ctj}.csv")
        plt.savefig(cfg['figures_dir']+f"rankings_{mode}/rankings_{mode}_{ref_panel=}_{ref_segmentation=}_{rank_method=}_{scale_method=}_{cti}_{ctj}.pdf",bbox_inches='tight',dpi=300)
        plt.close()

    #     if ref_panel == 'lung' and ref_segmentation == '5µm' and correction_method=='SPLIT':
    #         break
    # break
# Out:
# /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/workflow/notebooks/xenium/../../../workflow/scripts/_utils.py:695: PerformanceWarning: indexing past lexsort depth may impact performance.
#   if (cti, ctj) in v.index:
# /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/workflow/notebooks/xenium/../../../workflow/scripts/_utils.py:696: PerformanceWarning: indexing past lexsort depth may impact performance.
#   df[(correction_method, *k, cti, ctj)] = v.loc[(cti, ctj), rank_metric]
# /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/workflow/notebooks/xenium/../../../workflow/scripts/_utils.py:695: PerformanceWarning: indexing past lexsort depth may impact performance.
#   if (cti, ctj) in v.index:
# /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/workflow/notebooks/xenium/../../../workflow/scripts/_utils.py:696: PerformanceWarning: indexing past lexsort depth may impact performance.
#   df[(correction_method, *k, cti, ctj)] = v.loc[(cti, ctj), rank_metric]
# /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/workflow/notebooks/xenium/../../../workflow/scripts/_utils.py:695: PerformanceWarning: indexing past lexsort depth may impact performance.
#   if (cti, ctj) in v.index:
# /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/workflow/notebooks/xenium/../../../workflow/scripts/_utils.py:696: PerformanceWarning: indexing past lexsort depth may impact performance.
#   df[(correction_method, *k, cti, ctj)] = v.loc[(cti, ctj), rank_metric]
# /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/workflow/notebooks/xenium/../../../workflow/scripts/_utils.py:678: PerformanceWarning: indexing past lexsort depth may impact performance.
#   if (cti, ctj) in v.index:
# /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/workflow/notebooks/xenium/../../../workflow/scripts/_utils.py:679: PerformanceWarning: indexing past lexsort depth may impact performance.
#   df[(correction_method, *k, cti, ctj)] = v.loc[(cti, ctj)].set_index("names").loc[:, rank_metric]
# /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/workflow/notebooks/xenium/../../../workflow/scripts/_utils.py:678: PerformanceWarning: indexing past lexsort depth may impact performance.
#   if (cti, ctj) in v.index:
# /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/workflow/notebooks/xenium/../../../workflow/scripts/_utils.py:679: PerformanceWarning: indexing past lexsort depth may impact performance.
#   df[(correction_method, *k, cti, ctj)] = v.loc[(cti, ctj)].set_index("names").loc[:, rank_metric]
# /tmp/ipykernel_2326341/202055898.py:166: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_save = pd.concat(all_plot_data_long)
# /tmp/ipykernel_2326341/202055898.py:166: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_save = pd.concat(all_plot_data_long)
# /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/workflow/notebooks/xenium/../../../workflow/scripts/_utils.py:678: PerformanceWarning: indexing past lexsort depth may impact performance.
#   if (cti, ctj) in v.index:
# /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/workflow/notebooks/xenium/../../../workflow/scripts/_utils.py:679: PerformanceWarning: indexing past lexsort depth may impact performance.
#   df[(correction_method, *k, cti, ctj)] = v.loc[(cti, ctj)].set_index("names").loc[:, rank_metric]

# %% [markdown]
# # Plot rankings SPLIT only

# %%
df_ctj_marker_genes = _utils.get_df_ctj_marker_genes(dfs['df_ctj_marker_genes'],correction_methods)
cti = 'T cell'
ctj = 'malignant cell'
ref_panel = 'lung'
n = 20

malignant_markers = df_ctj_marker_genes.query("cell_type == @ctj and correction_method == 'raw' and segmentation == '10x_5um'")['gene'].value_counts()[:n].index
t_cell_markers = df_ctj_marker_genes.query("cell_type == @cti and correction_method == 'raw' and segmentation == '10x_5um'")['gene'].value_counts()[:n].index


df = {}
for correction_method in correction_methods:
    for k, v in dfs['df_importances_logreg'][correction_method].items():
        if k[2] != ref_panel:
            continue
        # for (cti,ctj) in v.index.droplevel(2).unique():
        if (cti,ctj) in v.index:
            df[(correction_method, *k, cti, ctj)] = v.loc[(cti, ctj),'importances']

df = pd.DataFrame(df).T.reset_index()
df.columns = ["correction_method"] + xenium_levels + ["cti", "ctj"] + df.columns[8:].tolist()
_utils.rename_methods(df)

df_norm = df.copy()
df_norm.iloc[:,8:] =  df.iloc[:,8:].div(df.iloc[:,8:].abs().sum(axis=1),axis=0)

# %%
df_labeling_info = pd.DataFrame(columns=['Gene', 'Label'])
df_labeling_info['Gene'] = df_norm.columns[8:]
df_labeling_info['Label'] = 'unknown'

ctj_markers = [g for g in malignant_markers if g in df_labeling_info.Gene.values]
cti_markers = [g for g in t_cell_markers if g in df_labeling_info.Gene.values]
df_labeling_info.loc[df_labeling_info['Gene'].isin(ctj_markers), 'Label'] = 'malignant cell'
df_labeling_info.loc[df_labeling_info['Gene'].isin(cti_markers), 'Label'] = 'T cell'
df_labeling_info = df_labeling_info.query("Label != 'unknown'")

# --- Prepare Labeling Info ---
# Create a dictionary for quick lookup: Gene -> Label
gene_to_label = pd.Series(df_labeling_info.Label.values, index=df_labeling_info.Gene).to_dict()

# Define a color palette for the labels (important for consistency)
unique_labels = df_labeling_info['Label'].unique()
palette_name = 'tab10' 
colors = sns.color_palette(palette_name, n_colors=len(unique_labels))
label_palette = dict(zip(unique_labels, colors))


# --- Identify metadata and importance (gene) columns in df_norm ---
metadata_cols = ['correction_method', 'segmentation', 'condition', 'panel', 'donor', 'sample', 'cti', 'ctj']
importance_cols = df_norm.columns.difference(metadata_cols, sort=False).tolist()

hue_correction_order_SPLIT = ['raw','SPLIT']

df_top = {}

for segmentation in list_ref_segmentations[:1]:
    # --- Get unique combinations of grouping variables ---
    groups = [[g,segmentation] for g in hue_correction_order_SPLIT]
    num_groups = len(groups)

    # --- Setup Subplots ---
    ncols = num_groups
    nrows = 1

    base_width_per_plot = 3  # Adjust as needed
    base_height_per_plot = 7 # Taller for vertical plots with rotated labels
    fig_width = base_width_per_plot * ncols
    fig_height = base_height_per_plot * nrows

    fig, axes = plt.subplots(nrows=nrows, ncols=ncols, figsize=(fig_width, fig_height),squeeze=False) # Ensure axes is always 2D
    axes_flat = axes.flatten()

    # --- Generate plot for each group ---
    plot_handles, plot_labels = [], [] # To collect handles/labels for a single legend

    for i, group_vals in enumerate(groups):
        correction_method, segmentation = group_vals
        ax = axes_flat[i]

        # 1. Filter df_norm for the current group
        group_df = df_norm[
            (df_norm['correction_method'] == correction_method) &
            (df_norm['segmentation'] == segmentation)
        ].copy() # Use .copy() to avoid SettingWithCopyWarning later
    
        group_importances = group_df[importance_cols]
        mean_importances = group_importances.mean(axis=0).dropna()
        n_top = min(40, len(mean_importances))
        top_genes = mean_importances.nlargest(n_top).index.tolist()
        # top_genes = df_labeling_info['Gene'].values

        # 3. Prepare data for plotting: Melt and Add Labels
        # Ensure only top genes are selected *before* melting
        melt_data = group_df[top_genes]
        plot_data_long = melt_data.melt(
            var_name='Gene',
            value_name='Importance'
        )

        # **** Add the 'Label' column for coloring ****
        plot_data_long['Label'] = plot_data_long['Gene'].map(gene_to_label)
        # Handle genes that might be missing a label
        plot_data_long['Label'] = plot_data_long['Label'].fillna('Unknown')
        # Ensure 'Unknown' has a color if it arises
        if 'Unknown' not in label_palette and 'Unknown' in plot_data_long['Label'].unique():
                label_palette['Unknown'] = '#808080' # Add grey for unknown

        # Check if any labels were actually assigned
        hue_param = 'Label'
        palette_param = label_palette

        sns.boxplot(
            data=plot_data_long,
            x='Importance',          # Genes on X-axis -> Vertical boxes
            y='Gene',    # Values on Y-axis
            hue=hue_param,     # Color by the 'Label' column
            order=top_genes,   # Order genes by mean importance
            palette=palette_param, # Use the defined label-color mapping
            dodge=False,       # Don't shift boxes for hue, color the whole box
            ax=ax,             # Draw on the correct subplot axis
            fliersize=1.5
        )

        # 5. Customize the SUBPLOT
        ax.set_title(f'{correction_method}\n{segmentation}', fontsize=10)
        # ax.tick_params(axis='x', rotation=90, labelsize=8)
        # ax.tick_params(axis='y', labelsize=8)
        ax.grid(axis='x', linestyle='--', alpha=0.6)
        ax.axvline(0.0, color='k', linestyle='-', zorder=-1, alpha=0.5)
        ax.set_xlabel('Importance Score', fontsize=9)

        if i % ncols == 0:
            ax.set_ylabel('Gene', fontsize=9)
        else:
            ax.set_ylabel('')

        # Remove individual subplot legends if hue was used (will create one below)
        if hue_param:
                # Collect handles/labels from the first plot that has a legend
                if not plot_labels and ax.get_legend() is not None:
                    handles, labels = ax.get_legend_handles_labels()
                    # Use a dictionary to ensure unique labels/handles
                    unique_hl = dict(zip(labels, handles))
                    plot_handles = list(unique_hl.values())
                    plot_labels = list(unique_hl.keys())

                if ax.get_legend() is not None:
                    ax.get_legend().remove()


    # --- Final Plot Adjustments ---
    # Hide unused subplots
    for j in range(i + 1, len(axes_flat)):
        axes_flat[j].axis('off')

    # Add a single legend for the whole figure if labels were used
    # Adjust legend position: place it outside the top right corner
    fig.legend(handles=plot_handles, labels=plot_labels, title="Gene Label",
                bbox_to_anchor=(.94, 0.5), loc='upper left', fontsize=9, title_fontsize=10)

    # plt.suptitle('Top 20 Feature Importances per Condition', fontsize=16, y=.95)
    # Adjust layout carefully to make space for suptitle and potential legend
    fig.tight_layout(rect=[0, 0.03, 0.95, 0.95]) # Adjust right margin for legend if needed (e.g., 0.9 or 0.85)
    plt.show()

# %% [markdown]
# # Get rankings SPLIT only

# %%
def get_df_ctj_marker_genes(dfs_ctj_marker_genes, correction_methods,):
    df_ctj_marker_genes = {}
    for correction_method in correction_methods:
        for k, v in dfs['df_ctj_marker_genes'][correction_method].items():
            for ctj in v.columns:
                df_ctj_marker_genes[(correction_method,*k,ctj)] = v[ctj]

    df_ctj_marker_genes = pd.concat(df_ctj_marker_genes).reset_index().drop('level_7',axis=1)
    df_ctj_marker_genes.columns = ['correction_method'] + xenium_levels + ['cell_type','gene']
    return df_ctj_marker_genes


df_ctj_marker_genes = get_df_ctj_marker_genes(dfs['df_ctj_marker_genes'],correction_methods)
ctj = 'malignant cell'
ref_panel = 'lung'
n = 20


df = {}
for correction_method in correction_methods:
    for k, v in dfs['df_importances_logreg'][correction_method].items():
        if k[2] != ref_panel:
            continue
        
        u_cell_types_combs = v.index.droplevel(2).unique()
        u_cell_types_combs_ctj = [x for x in u_cell_types_combs if x[1] == ctj]
        for (cti_,ctj_) in u_cell_types_combs_ctj:
        # if (cti,ctj) in v.index:
            df[(correction_method, *k, cti_, ctj_)] = v.loc[(cti_, ctj_),'importances']

df = pd.DataFrame(df).T.reset_index()
df.columns = ["correction_method"] + xenium_levels + ["cti", "ctj"] + df.columns[8:].tolist()
_utils.rename_methods(df)

df_norm = df.copy()
df_norm.iloc[:,8:] =  df.iloc[:,8:].div(df.iloc[:,8:].abs().sum(axis=1),axis=0)

# %%
df_labeling_info = pd.DataFrame(columns=['Gene', 'Label'])
df_labeling_info['Gene'] = df_norm.columns[8:]
df_labeling_info['Label'] = 'unknown'

ctj_markers = [g for g in malignant_markers if g in df_labeling_info.Gene.values]
cti_markers = [g for g in t_cell_markers if g in df_labeling_info.Gene.values]
df_labeling_info.loc[df_labeling_info['Gene'].isin(ctj_markers), 'Label'] = 'malignant cell'
df_labeling_info.loc[df_labeling_info['Gene'].isin(cti_markers), 'Label'] = 'T cell'
df_labeling_info = df_labeling_info.query("Label != 'unknown'")

# --- Prepare Labeling Info ---
# Create a dictionary for quick lookup: Gene -> Label
gene_to_label = pd.Series(df_labeling_info.Label.values, index=df_labeling_info.Gene).to_dict()

# Define a color palette for the labels (important for consistency)
unique_labels = df_labeling_info['Label'].unique()
palette_name = 'tab10' 
colors = sns.color_palette(palette_name, n_colors=len(unique_labels))
label_palette = dict(zip(unique_labels, colors))


# --- Identify metadata and importance (gene) columns in df_norm ---
metadata_cols = ['correction_method', 'segmentation', 'condition', 'panel', 'donor', 'sample', 'cti', 'ctj']
importance_cols = df_norm.columns.difference(metadata_cols, sort=False).tolist()

hue_correction_order_SPLIT = ['raw','SPLIT']

df_top = {}

groups = df_norm[['cti','ctj','correction_method','segmentation']].drop_duplicates().values

for i, group_vals in enumerate(groups):
    cti, ctj, correction_method, segmentation = group_vals

    # 1. Filter df_norm for the current group
    group_df = df_norm[
        (df_norm['cti'] == cti) &
        (df_norm['ctj'] == ctj) &
        (df_norm['correction_method'] == correction_method) &
        (df_norm['segmentation'] == segmentation)
    ].copy() # Use .copy() to avoid SettingWithCopyWarning later

    group_importances = group_df[importance_cols]
    mean_importances = group_importances.mean(axis=0).dropna()
    n_top = min(40, len(mean_importances))
    top_genes = mean_importances.nlargest(n_top).index.tolist()
    # top_genes = df_labeling_info['Gene'].values

    df_top[cti, ctj, segmentation, correction_method] = top_genes
    
df_top = pd.DataFrame(df_top)
df_top.to_csv('../../scratch/df_top_markers.csv')

# %% [markdown]
# # Heatmap diffexpr

# %%
### params
df_ctj_marker_genes = _utils.get_df_ctj_marker_genes(dfs['df_ctj_marker_genes'],correction_methods)
cti = 'T cell'
ctj = 'malignant cell'
lung_genes_only = True
top_n = 20
agg_func='median'
rank_metric='logfoldchanges'
rank_metric_pvals='pvals_adj'
rank_metric_logreg='importances'

list_ref_panel = ['lung','5k']
list_ref_segmentation = ['5µm','ProSeg']
list_scale = ['row','column']
list_show_pvals = [True,False]

Path('../../scratch/heatmaps/').mkdir(parents=True, exist_ok=True)
for ref_panel, ref_segmentation, scale, show_pvals in itertools.product(list_ref_panel,list_ref_segmentation, list_scale, list_show_pvals):

    if ref_panel == '5k' and ref_segmentation == '5µm':
        ref_segmentation = 'MM'

    #### extract data into df
    df_diffexpr = _utils.get_df_diffexpr_cti_ctj(dfs_diffexpr['df_diffexpr'], cti, ctj, ref_panel, correction_methods, rank_metric=rank_metric)
    df_diffexpr_pvals = _utils.get_df_diffexpr_cti_ctj(dfs_diffexpr['df_diffexpr'], cti, ctj, ref_panel, correction_methods, rank_metric=rank_metric_pvals)
    df = _utils.get_df_importances_cti_ctj(dfs['df_importances_logreg'], cti, ctj, ref_panel, correction_methods, rank_metric=rank_metric_logreg)

    id_vars = df.columns[:8].tolist()
    value_vars = df.columns[8:].tolist()

    df_diffexpr_norm = df_diffexpr.copy()
    df_norm = df.copy()
    if ref_panel == '5k' and lung_genes_only:
        lung_panel_genes = pd.read_csv(cfg['markers_dir']+'Xenium_hLung_v1_metadata.csv')['Gene'].tolist()
        value_vars = [g for g in lung_panel_genes if g in df_norm.columns]
        df_norm = df_norm[id_vars+value_vars]

    # optionally normalize values
    scale_axis = 0 if scale=='column' else 1
    df_diffexpr_norm[value_vars] = df_diffexpr_norm[value_vars].replace(np.nan,0)
    df_diffexpr_norm[value_vars] =  zscore(df_diffexpr[value_vars],axis=scale_axis,nan_policy='omit')# df_diffexpr[value_vars].div(df_diffexpr[value_vars].abs().sum(axis=1),axis=0)
    df_norm[value_vars] =  df[value_vars].div(df[value_vars].abs().sum(axis=1),axis=0)
    # df_norm[value_vars] = df[value_vars].div(df[value_vars].abs().rank(axis=1, ascending=True),axis=0)


    ### get median top n genes for each unique correction/segmentation/condition/panel
    if top_n is not None:
        id_vars_rank = ['correction_method', 'segmentation', 'condition', 'panel']

        df_top_genes = (
            df_norm.groupby(list(id_vars_rank))
            .apply(lambda g: get_top_n_genes(g, n=top_n, value_vars=value_vars,agg_func=agg_func))
            .reset_index()
        )
        df_top_genes.columns = id_vars_rank + ['top_genes']
        value_vars = list(set().union(*df_top_genes['top_genes']))
        df_norm = df_norm[id_vars+value_vars]

    ### define plot df
    df_plot = df_diffexpr_norm.melt(id_vars=id_vars,     
                            value_vars=value_vars,  
                            var_name='gene',                 
                            value_name=rank_metric)

    df_plot_pvals = df_diffexpr_pvals.melt(id_vars=id_vars,     
                            value_vars=value_vars,  
                            var_name='gene',                 
                            value_name=rank_metric_pvals)

    df_plot = pd.merge(df_plot,df_plot_pvals,on=id_vars+['gene'])
    df_plot[rank_metric_pvals] = -np.log10(df_plot_pvals[rank_metric_pvals].clip(1e-20,1))

    df_plot['ID'] = df_plot[id_vars].astype(str).agg('-'.join, axis=1)
    df_plot = df_plot.query(f"segmentation == '{ref_segmentation}'")
    df_plot['gene_label'] = df_plot['gene'].map(gene_labels_reverse)
    df_plot['gene_label'] = df_plot['gene_label'].fillna('Other')

    ### palettes
    unique_labels = [c for c in hue_correction_order if c in np.unique(df_plot[hue_correction].dropna())]
    unique_labels = unique_labels + [c for c in np.unique(df_plot[hue_correction].dropna()) if c not in unique_labels]
    palette = {u: count_correction_palette[u] for u in unique_labels}


    ### heatmap row/col labels
    df_col=df_plot[['segmentation','correction_method','panel','ID']].drop_duplicates()#.to_frame()
    df_col.set_index('ID',inplace=True)

    df_row=df_plot[['gene','gene_label']].drop_duplicates()
    df_row.set_index('gene',inplace=True)

    row_ha = HeatmapAnnotation(
                            gene_label=anno_simple(df_row['gene_label'],cmap='tab20',add_text=False,legend=True),
                            label=anno_label(df_row['gene_label'],cmap='tab20', merge=True,rotation=0,arrowprops = dict(visible=False)),
                            label_side='top',label_kws={'rotation':30,'horizontalalignment':'left'},
                            axis=0,verbose=0)


    col_ha = HeatmapAnnotation(
        correction_method=anno_simple(df_col['correction_method'], colors=count_correction_palette.to_dict(),legend=True,add_text=True),
        # panel=anno_simple(df_col['panel'], cmap='Dark2',legend=False,add_text=True),
        # segmentation=anno_simple(df_col['segmentation'], cmap='Set1',legend=False,add_text=True),
        verbose=0,label_side='left')


    ### heatmap 
    plt.figure(figsize=(10, 25))
    cm = DotClustermapPlotter(
        data=df_plot, 
        x='ID',y='gene',value=rank_metric,c=rank_metric,
        s=rank_metric_pvals if show_pvals else None,
        row_cluster=True,col_cluster=False,
        #hue='EnrichType', 
        #cmap={'Enrich':'RdYlGn_r','Depletion':'coolwarm_r'},
        #colors={'Enrich':'red','Depletion':'blue'},
        #marker={'Enrich':'^','Depletion':'v'},
        top_annotation=col_ha,
        right_annotation=row_ha,
        col_split=df_col['correction_method'],
        col_split_order=hue_correction_order,
        row_split=df_row['gene_label'], 
        row_split_order=[k for k in gene_labels.keys() if k in df_row['gene_label'].unique()],

        cmap='bwr',center=0,
        col_split_gap=2,row_split_gap=5,
        show_rownames=True,show_colnames=False,row_dendrogram=False,
        verbose=1,legend_gap=10,grid=None,linewidths=.01,spines=True,
        vmin=-4,vmax=4,
        ) #if the size of dot in legend is too large, use alpha to control, for example: alpha=0.8

    # plt.savefig(f"../../scratch/heatmaps/heatmap_{ref_panel=}_{ref_segmentation=}_{scale=}_{show_pvals=}.pdf",bbox_inches='tight',dpi=300)
    plt.show()

    break

# %% [markdown]
# # Heatmap diffexpr separate scales

# %%
### params
keep_annotations = [
    'T cell', 
    'canonical T cell marker',
    'regulatory T cell',
    'exhausted T cell',
    'cytotoxic T cell',
    'immune response',
    'proliferation',
    'malignant cell',
    'fibroblast', 
    'epithelial cell'
    ]
gene_labels = pd.read_csv(cfg['markers_dir']+'Xenium_hLung_v1_metadata_DB.csv',encoding='latin1').groupby('Annotation_DB')['Gene'].agg(list)
# gene_labels = gene_labels[gene_labels.map(lambda x: len(x))>2].to_dict()
gene_labels = {k:gene_labels[k] for k in keep_annotations}
gene_labels_reverse = {v:k for k,vs in gene_labels.items() for v in vs}

# %%
### params
df_ctj_marker_genes = _utils.get_df_ctj_marker_genes(dfs['df_ctj_marker_genes'],correction_methods)
cti = 'T cell'
ctj = 'malignant cell'
lung_genes_only = True
top_n = None
agg_func='median'
rank_metric='logfoldchanges'
rank_metric_pvals='pvals'
rank_metric_logreg='importances'

list_ref_panel = ['breast'] #['lung','5k']
list_ref_segmentation = ['5µm','ProSeg']
list_show_pvals = [True]

Path('../../scratch/heatmaps/').mkdir(parents=True, exist_ok=True)
for ref_panel, ref_segmentation, show_pvals in itertools.product(list_ref_panel,list_ref_segmentation, list_show_pvals):

    if ref_panel == '5k' and ref_segmentation == '5µm':
        ref_segmentation = 'MM'
        # continue

    #### extract data into df
    df_diffexpr = _utils.get_df_diffexpr_cti_ctj(dfs_diffexpr['df_diffexpr'], cti, ctj, ref_panel, correction_methods, rank_metric=rank_metric)
    df_diffexpr_pvals = _utils.get_df_diffexpr_cti_ctj(dfs_diffexpr['df_diffexpr'], cti, ctj, ref_panel, correction_methods, rank_metric=rank_metric_pvals)
    df = _utils.get_df_importances_cti_ctj(dfs['df_importances_logreg'], cti, ctj, ref_panel, correction_methods, rank_metric=rank_metric_logreg)

    id_vars = df.columns[:8].tolist()
    value_vars = df.columns[8:].tolist()

    df_diffexpr_norm = df_diffexpr.copy()
    df_norm = df.copy()
    if ref_panel == '5k' and lung_genes_only:
        lung_panel_genes = pd.read_csv(cfg['markers_dir']+'Xenium_hLung_v1_metadata.csv')['Gene'].tolist()
        value_vars = [g for g in lung_panel_genes if g in df_norm.columns]
        df_norm = df_norm[id_vars+value_vars]

    df_diffexpr_norm[value_vars] = df_diffexpr_norm[value_vars].replace(np.nan,0)
    # df_diffexpr_norm[value_vars] =  zscore(df_diffexpr[value_vars],axis=scale_axis,nan_policy='omit')# df_diffexpr[value_vars].div(df_diffexpr[value_vars].abs().sum(axis=1),axis=0)
    # df_norm[value_vars] =  df[value_vars].div(df[value_vars].abs().sum(axis=1),axis=0)
    # df_norm[value_vars] = df[value_vars].div(df[value_vars].abs().rank(axis=1, ascending=True),axis=0)


    ### get median top n genes for each unique correction/segmentation/condition/panel
    if top_n is not None:
        id_vars_rank = ['correction_method', 'segmentation', 'condition', 'panel']

        df_top_genes = (
            df_norm.groupby(list(id_vars_rank))
            .apply(lambda g: get_top_n_genes(g, n=top_n, value_vars=value_vars,agg_func=agg_func))
            .reset_index()
        )
        df_top_genes.columns = id_vars_rank + ['top_genes']
        value_vars = list(set().union(*df_top_genes['top_genes']))
        df_norm = df_norm[id_vars+value_vars]

    ### define plot df
    df_plot = df_diffexpr_norm.melt(id_vars=id_vars,     
                            value_vars=value_vars,  
                            var_name='gene',                 
                            value_name=rank_metric)

    df_plot_pvals = df_diffexpr_pvals.melt(id_vars=id_vars,     
                            value_vars=value_vars,  
                            var_name='gene',                 
                            value_name=rank_metric_pvals)


    
    df_plot = pd.merge(df_plot,df_plot_pvals,on=id_vars+['gene'])

    # replace nan values
    df_plot[rank_metric] = df_plot[rank_metric].replace(np.nan,0.)
    df_plot[rank_metric_pvals] = df_plot[rank_metric_pvals].replace(np.nan,1.)

    # clip 
    df_plot[rank_metric_pvals] = -np.log10(df_plot[rank_metric_pvals].clip(1e-10,1))
    # df_plot[rank_metric_pvals] += 1e-2*np.abs(np.random.random((len(df_plot[rank_metric_pvals]))))

    df_plot['ID'] = df_plot[id_vars].astype(str).agg('-'.join, axis=1)
    df_plot = df_plot.query(f"segmentation == '{ref_segmentation}'")
    df_plot['gene_label'] = df_plot['gene'].map(gene_labels_reverse)
    df_plot['gene_label'] = df_plot['gene_label'].fillna('Other')

    ### palettes
    unique_labels = [c for c in hue_correction_order if c in np.unique(df_plot[hue_correction].dropna())]
    unique_labels = unique_labels + [c for c in np.unique(df_plot[hue_correction].dropna()) if c not in unique_labels]
    palette = {u: count_correction_palette[u] for u in unique_labels}

    ### heatmap 
    cmlist=[]
    for i, correction_method in enumerate(hue_correction_order):

        idx_correction_method = df_plot['correction_method'] == correction_method
        if not sum(idx_correction_method):
            continue
        
        df_plot_corr_method = df_plot[idx_correction_method].copy()
        df_plot_corr_method[f'{correction_method}\nlogFC']=df_plot_corr_method[rank_metric]
        # df_plot_corr_method[rank_metric_pvals] = df_plot_corr_method[rank_metric_pvals]+1e-30*np.random.random((len(df_plot_corr_method[rank_metric_pvals])))

        df_col=df_plot_corr_method[['segmentation','correction_method','panel','ID']].drop_duplicates()#.to_frame()
        df_col.set_index('ID',inplace=True)

        df_row=df_plot_corr_method[['gene','gene_label']].drop_duplicates()
        df_row.set_index('gene',inplace=True)

        # display params
        vmin, vmax = winsorize_asymmetric(df_plot_corr_method[rank_metric],neg_q=0.1, pos_q=0.9)
        vmin = np.maximum(-10,vmin)
        vmax = np.minimum(10,vmax)

        if abs(vmin) > (10*vmax):
            vmin = -5*abs(vmax)
        if vmax > (10*abs(vmin)):
            vmax = (5*abs(vmin))


        show_rownames = True if i == 0 else False

        if show_pvals:
            if len(df_plot_corr_method[rank_metric_pvals].unique()) < 2:
                s = 1.
            else:
                s = rank_metric_pvals
        else:
            s = None

        if i == len(hue_correction_order)-1:
            row_ha = HeatmapAnnotation(
                                    gene_label=anno_simple(df_row['gene_label'],cmap='tab20',add_text=False,legend=True),
                                    label=anno_label(df_row['gene_label'],cmap='tab20', merge=True,rotation=0,arrowprops = dict(visible=False)),
                                    label_side='top',label_kws={'rotation':30,'horizontalalignment':'left'},
                                    axis=0,verbose=0)
        else:
            row_ha = None
        
        col_ha = HeatmapAnnotation(
            correction_method=anno_simple(df_col['correction_method'], colors=count_correction_palette.to_dict(),legend=True,add_text=True),
            # panel=anno_simple(df_col['panel'], cmap='Dark2',legend=False,add_text=True),
            # segmentation=anno_simple(df_col['segmentation'], cmap='Set1',legend=False,add_text=True),
            verbose=0,label_kws={'visible':False})


        ### heatmap
        cm = DotClustermapPlotter(
            data=df_plot_corr_method, 
            x='ID',y='gene',value=f'{correction_method}\nlogFC',c=f'{correction_method}\nlogFC',
            s=rank_metric_pvals if show_pvals else None,
            row_cluster=False,col_cluster=False,
            #hue='EnrichType', 
            #cmap={'Enrich':'RdYlGn_r','Depletion':'coolwarm_r'},
            #colors={'Enrich':'red','Depletion':'blue'},
            #marker={'Enrich':'^','Depletion':'v'},
            top_annotation=col_ha,
            right_annotation=row_ha,
            # col_split=df_col_corr_method['correction_method'],
            # col_split_order=hue_correction_order,
            row_split=df_row['gene_label'], 
            row_split_order=[k for k in gene_labels.keys() if k in df_row['gene_label'].unique()],

            cmap='bwr',
            center=0,
            label='correction_method',
            col_split_gap=2,row_split_gap=5,
            show_rownames=show_rownames,
            row_names_side='left',
            show_colnames=False,row_dendrogram=False,
            verbose=0,legend_gap=10,grid=None,linewidths=.01,spines=True,
            vmin=vmin,
            vmax=vmax,
            # vmin=df_plot_corr_method[f'{correction_method}\nlogFC'].quantile(0.08),
            # vmax=df_plot_corr_method[f'{correction_method}\nlogFC'].quantile(0.92),
            plot=False
            ) 
        cmlist.append(cm)
    

    plt.figure(figsize=(10, 25))
    ax, legend_axes = pch.composite(cmlist=cmlist, main=0,legend_gap=10,col_gap=0.1)
    plt.savefig(f"../../figures/heatmaps/heatmap_{ref_panel=}_{ref_segmentation=}_{show_pvals=}.png",bbox_inches='tight',dpi=300)
    plt.close()

# %% [markdown]
# # Heatmap importances

# %%
### params
df_ctj_marker_genes = _utils.get_df_ctj_marker_genes(dfs['df_ctj_marker_genes'],correction_methods)
cti = 'T cell'
ctj = 'malignant cell'
lung_genes_only = True
top_n = 20
agg_func='median'
rank_metric='logfoldchanges'
rank_metric_pvals='pvals_adj'
rank_metric_logreg='importances'

list_ref_panel = ['lung','5k']
list_ref_segmentation = ['5µm','ProSeg']


Path('../../scratch/heatmaps/').mkdir(parents=True, exist_ok=True)
for ref_panel, ref_segmentation, in itertools.product(list_ref_panel,list_ref_segmentation):

    if ref_panel == '5k' and ref_segmentation == '5µm':
        ref_segmentation = 'MM'

    #### extract data into df
    df = _utils.get_df_importances_cti_ctj(dfs['df_importances_logreg'], cti, ctj, ref_panel, correction_methods, rank_metric=rank_metric_logreg)

    id_vars = df.columns[:8].tolist()
    value_vars = df.columns[8:].tolist()

    df_norm = df.copy()
    if ref_panel == '5k' and lung_genes_only:
        lung_panel_genes = pd.read_csv(cfg['markers_dir']+'Xenium_hLung_v1_metadata.csv')['Gene'].tolist()
        value_vars = [g for g in lung_panel_genes if g in df_norm.columns]
        df_norm = df_norm[id_vars+value_vars]

    # optionally normalize values
    scale_axis = 0 if scale=='column' else 1
    df_norm[value_vars] =  df[value_vars].div(df[value_vars].abs().sum(axis=1),axis=0)
    # df_norm[value_vars] =  zscore(df[value_vars].replace(np.nan,0.),axis=1)

    ### get median top n genes for each unique correction/segmentation/condition/panel
    if top_n is not None:
        id_vars_rank = ['correction_method', 'segmentation', 'condition', 'panel']

        df_top_genes = (
            df_norm.groupby(list(id_vars_rank))
            .apply(lambda g: get_top_n_genes(g, n=top_n, value_vars=value_vars,agg_func=agg_func))
            .reset_index()
        )
        df_top_genes.columns = id_vars_rank + ['top_genes']
        value_vars = list(set().union(*df_top_genes['top_genes']))
        df_norm = df_norm[id_vars+value_vars]

    ### define plot df
    df_plot = df_norm.melt(id_vars=id_vars,     
                            value_vars=value_vars,  
                            var_name='gene',                 
                            value_name=rank_metric)


    df_plot = pd.merge(df_plot,df_plot_pvals,on=id_vars+['gene'])

    df_plot['ID'] = df_plot[id_vars].astype(str).agg('-'.join, axis=1)
    df_plot = df_plot.query(f"segmentation == '{ref_segmentation}'")
    df_plot['gene_label'] = df_plot['gene'].map(gene_labels_reverse)
    df_plot['gene_label'] = df_plot['gene_label'].fillna('Other')

    ### palettes
    unique_labels = [c for c in hue_correction_order if c in np.unique(df_plot[hue_correction].dropna())]
    unique_labels = unique_labels + [c for c in np.unique(df_plot[hue_correction].dropna()) if c not in unique_labels]
    palette = {u: count_correction_palette[u] for u in unique_labels}


    ### heatmap row/col labels
    df_col=df_plot[['segmentation','correction_method','panel','ID']].drop_duplicates()#.to_frame()
    df_col.set_index('ID',inplace=True)

    df_row=df_plot[['gene','gene_label']].drop_duplicates()
    df_row.set_index('gene',inplace=True)

    row_ha = HeatmapAnnotation(
                            gene_label=anno_simple(df_row['gene_label'],cmap='tab20',add_text=False,legend=True),
                            label=anno_label(df_row['gene_label'],cmap='tab20', merge=True,rotation=0,arrowprops = dict(visible=False)),
                            label_side='top',label_kws={'rotation':30,'horizontalalignment':'left'},
                            axis=0,verbose=0)


    col_ha = HeatmapAnnotation(
        correction_method=anno_simple(df_col['correction_method'], colors=count_correction_palette.to_dict(),legend=True,add_text=True),
        # panel=anno_simple(df_col['panel'], cmap='Dark2',legend=False,add_text=True),
        # segmentation=anno_simple(df_col['segmentation'], cmap='Set1',legend=False,add_text=True),
        verbose=0,label_side='left')


    ### heatmap 
    plt.figure(figsize=(10, 25))
    cm = DotClustermapPlotter(
        data=df_plot, 
        x='ID',y='gene',value=rank_metric,c=rank_metric,
        s=None,
        row_cluster=True,col_cluster=False,
        #hue='EnrichType', 
        #cmap={'Enrich':'RdYlGn_r','Depletion':'coolwarm_r'},
        #colors={'Enrich':'red','Depletion':'blue'},
        #marker={'Enrich':'^','Depletion':'v'},
        top_annotation=col_ha,
        right_annotation=row_ha,
        col_split=df_col['correction_method'],
        col_split_order=hue_correction_order,
        row_split=df_row['gene_label'], 
        row_split_order=[k for k in gene_labels.keys() if k in df_row['gene_label'].unique()],

        cmap='bwr',center=0,
        col_split_gap=2,row_split_gap=5,
        show_rownames=True,show_colnames=False,row_dendrogram=False,
        verbose=1,legend_gap=10,grid=None,linewidths=.01,spines=True,
        vmin=-0.04,vmax=0.04,
        ) #if the size of dot in legend is too large, use alpha to control, for example: alpha=0.8

    # plt.savefig(f"../../scratch/heatmaps/heatmap_{ref_panel=}_{ref_segmentation=}_{scale=}_{show_pvals=}.pdf",bbox_inches='tight',dpi=300)
    plt.show()

    break

# %% [markdown]
# # Heatmap importances rank

# %%
### params
df_ctj_marker_genes = _utils.get_df_ctj_marker_genes(dfs['df_ctj_marker_genes'],correction_methods)
cti = 'T cell'
ctj = 'malignant cell'
lung_genes_only = True
top_n = None
agg_func='median'
rank_metric='logfoldchanges'
rank_metric_pvals='pvals_adj'
rank_metric_logreg='importances'

list_ref_panel = ['lung','5k']
list_ref_segmentation = ['5µm','ProSeg']

Path('../../scratch/heatmaps/').mkdir(parents=True, exist_ok=True)
for ref_panel, ref_segmentation in itertools.product(list_ref_panel,list_ref_segmentation):

    if ref_panel == '5k' and ref_segmentation == '5µm':
        ref_segmentation = 'MM'

    #### extract data into df
    df = _utils.get_df_importances_cti_ctj(dfs['df_importances_logreg'], cti, ctj, ref_panel, correction_methods, rank_metric=rank_metric_logreg)

    id_vars = df.columns[:8].tolist()
    value_vars = df.columns[8:].tolist()

    df_norm = df.copy()
    if ref_panel == '5k' and lung_genes_only:
        lung_panel_genes = pd.read_csv(cfg['markers_dir']+'Xenium_hLung_v1_metadata.csv')['Gene'].tolist()
        value_vars = [g for g in lung_panel_genes if g in df_norm.columns]
        df_norm = df_norm[id_vars+value_vars]

    # optionally normalize values
    df_norm[value_vars] =  df_norm[value_vars].replace(np.nan,0.)
    df_norm[value_vars] =  df_norm[value_vars].rank(ascending=True,axis=1)

    ### get median top n genes for each unique correction/segmentation/condition/panel
    if top_n is not None:
        id_vars_rank = ['correction_method', 'segmentation', 'condition', 'panel']

        df_top_genes = (
            df_norm.groupby(list(id_vars_rank))
            .apply(lambda g: get_top_n_genes(g, n=top_n, value_vars=value_vars,agg_func=agg_func,ascending=True))
            .reset_index()
        )
        df_top_genes.columns = id_vars_rank + ['top_genes']
        value_vars = list(set().union(*df_top_genes['top_genes']))
        df_norm = df_norm[id_vars+value_vars]

    ### define plot df
    df_plot = df_norm.melt(id_vars=id_vars,     
                            value_vars=value_vars,  
                            var_name='gene',                 
                            value_name=rank_metric)


    df_plot['ID'] = df_plot[id_vars].astype(str).agg('-'.join, axis=1)
    df_plot = df_plot.query(f"segmentation == '{ref_segmentation}'")
    df_plot['gene_label'] = df_plot['gene'].map(gene_labels_reverse)
    df_plot['gene_label'] = df_plot['gene_label'].fillna('Other')

    ### palettes
    unique_labels = [c for c in hue_correction_order if c in np.unique(df_plot[hue_correction].dropna())]
    unique_labels = unique_labels + [c for c in np.unique(df_plot[hue_correction].dropna()) if c not in unique_labels]
    palette = {u: count_correction_palette[u] for u in unique_labels}


    ### heatmap row/col labels
    df_col=df_plot[['segmentation','correction_method','panel','ID']].drop_duplicates()#.to_frame()
    df_col.set_index('ID',inplace=True)

    df_row=df_plot[['gene','gene_label']].drop_duplicates()
    df_row.set_index('gene',inplace=True)

    row_ha = HeatmapAnnotation(
                            gene_label=anno_simple(df_row['gene_label'],cmap='tab20',add_text=False,legend=True),
                            label=anno_label(df_row['gene_label'],cmap='tab20', merge=True,rotation=0,arrowprops = dict(visible=False)),
                            label_side='top',label_kws={'rotation':30,'horizontalalignment':'left'},
                            axis=0,verbose=0)


    col_ha = HeatmapAnnotation(
        correction_method=anno_simple(df_col['correction_method'], colors=count_correction_palette.to_dict(),legend=True,add_text=True),
        # panel=anno_simple(df_col['panel'], cmap='Dark2',legend=False,add_text=True),
        # segmentation=anno_simple(df_col['segmentation'], cmap='Set1',legend=False,add_text=True),
        verbose=0,label_side='left')


    ### heatmap 
    plt.figure(figsize=(10, 35))
    cm = DotClustermapPlotter(
        data=df_plot, 
        x='ID',y='gene',value=rank_metric,c=rank_metric,
        s=None,
        row_cluster=True,col_cluster=False,
        #hue='EnrichType', 
        #cmap={'Enrich':'RdYlGn_r','Depletion':'coolwarm_r'},
        #colors={'Enrich':'red','Depletion':'blue'},
        #marker={'Enrich':'^','Depletion':'v'},
        top_annotation=col_ha,
        right_annotation=row_ha,
        col_split=df_col['correction_method'],
        col_split_order=hue_correction_order,
        row_split=df_row['gene_label'], 
        row_split_order=[k for k in gene_labels.keys() if k in df_row['gene_label'].unique()],

        cmap='Purples',#center=0,
        col_split_gap=2,row_split_gap=5,
        show_rownames=True,show_colnames=False,row_dendrogram=False,
        verbose=1,legend_gap=10,grid=None,linewidths=.01,spines=True,
        # vmin=-0.04,vmax=0.04,
        ) #if the size of dot in legend is too large, use alpha to control, for example: alpha=0.8

    # plt.savefig(f"../../scratch/heatmaps/heatmap_{ref_panel=}_{ref_segmentation=}_{scale=}_{show_pvals=}.pdf",bbox_inches='tight',dpi=300)
    plt.show()

    break

# %% [markdown]
# # Paper figure: Heatmap GSEA

# %%
### params
cti = 'T cell'
ctj = 'malignant cell'
lung_genes_only = False
show_samples = False
agg_func='median'
rank_metric='logfoldchanges'
rank_metric_pvals='FDR q-val'
rank_metric_gsea = 'NES'

CONDITIONS_PANELS = {
    'melanoma':['chuvio'],
    'mesothelioma_pilot':['chuvio'],
    'NSCLC':['chuvio','lung','5k'],
    'breast':['breast'],
}


list_ref_conditions = ['NSCLC','breast','melanoma','mesothelioma_pilot']
list_ref_panel = ['breast','lung','5k','chuvio']
list_ref_segmentation = ['5µm','ProSeg']
list_gene_sets = [
    # 'KEGG_2021_Human',
    # 'Reactome_2022',
    # 'MSigDB_Hallmark_2020',
    # 'Immunologic_Signatures',
    'custom',
    # '/work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/data/markers/c7.immunesigdb.v2024.1.Hs.symbols.gmt'
]

keep_annotations = [
    'T cell', 
    'canonical T cell marker',
    'regulatory T cell',
    'exhausted T cell',
    'cytotoxic T cell',
    'immune response',
    'proliferation',
    'malignant cell',
    'fibroblast', 
    'epithelial cell'
    ]
negative_markers = ['CD28']


Path(cfg['figures_dir']+'heatmap_diffexpr_gsea').mkdir(parents=True, exist_ok=True)
for ref_condition, ref_panel, ref_segmentation, gene_sets_to_use in itertools.product(list_ref_conditions, list_ref_panel, list_ref_segmentation, list_gene_sets):

    print(ref_condition, ref_panel, ref_segmentation, gene_sets_to_use)
    
    if ref_panel not in CONDITIONS_PANELS[ref_condition]:
        continue
    if ref_panel == '5k' and ref_segmentation == '5µm':
        ref_segmentation = 'MM'

    if ref_panel in ['lung','5k','chuvio']:
        gene_labels = pd.read_csv(cfg['markers_dir']+'Xenium_hLung_v1_metadata_DB.csv',encoding='latin1').groupby('Annotation_DB')['Gene'].agg(list)
    elif ref_panel == 'breast':
        gene_labels = pd.read_csv(cfg['markers_dir']+'Xenium_hBreast_v1_metadata_DB.csv',encoding='latin1').groupby('Annotation_DB')['Genes'].agg(list)
    gene_labels = {k:gene_labels[k] for k in keep_annotations}
    # gene_labels = gene_labels[gene_labels.map(lambda x: len(x))>2].to_dict()

    #### extract data into df
    df_diffexpr = _utils.get_df_diffexpr_cti_ctj(dfs_diffexpr['df_diffexpr'], cti, ctj, ref_panel, correction_methods, rank_metric=rank_metric)
    negative_markers_found = [g for g in negative_markers if g in df_diffexpr.columns]
    df_diffexpr[negative_markers_found] = df_diffexpr[negative_markers_found].mul(-1)

    id_vars = df_diffexpr.columns[:8].tolist()
    value_vars = df_diffexpr.columns[8:].tolist()

    df_diffexpr_norm = df_diffexpr.copy()
    # df_norm = df.copy()
    if ref_panel == '5k' and lung_genes_only:
        lung_panel_genes = pd.read_csv(cfg['markers_dir']+'Xenium_hLung_v1_metadata.csv')['Gene'].tolist()
        value_vars = [g for g in lung_panel_genes if g in df_diffexpr_norm.columns]
        df_diffexpr_norm = df_diffexpr_norm[id_vars+value_vars]

    ### define plot df
    if gene_sets_to_use == 'custom': 
        gene_sets = gene_labels
        figsize = (10,2.5)
        min_size = 0
    else:
        gene_sets = gene_sets_to_use
        figsize = (10,20)
        min_size = 15

    df_plot = get_df_gsea(df_diffexpr,gene_sets,id_vars,min_size=min_size)

    df_plot[rank_metric_gsea] = df_plot[rank_metric_gsea].astype(float)
    df_plot[rank_metric_pvals] = df_plot[rank_metric_pvals].astype(float)

    # clip 0 pvalues to minimum * 0.1 (to still distinguish them) 
    rank_metric_pvals_log = '-log10 '+rank_metric_pvals
    df_plot[rank_metric_pvals] = df_plot[rank_metric_pvals].replace(0.,df_plot.loc[df_plot[rank_metric_pvals]>0.,rank_metric_pvals].min()*.1)
    df_plot[rank_metric_pvals_log] = -np.log10(df_plot[rank_metric_pvals])

    df_plot['ID'] = df_plot[id_vars].astype(str).agg('-'.join, axis=1)
    df_plot = df_plot.query(f"segmentation == '{ref_segmentation}'")

    ### palettes
    unique_labels = [c for c in hue_correction_order if c in np.unique(df_plot[hue_correction].dropna())]
    unique_labels = unique_labels + [c for c in np.unique(df_plot[hue_correction].dropna()) if c not in unique_labels]
    palette = {u: count_correction_palette[u] for u in unique_labels}

    ### heatmap row/col labels
    df_col=df_plot[['segmentation','correction_method','panel','sample','ID']].drop_duplicates()#.to_frame()
    df_col.set_index('ID',inplace=True)
    df_col['correction_method'] = pd.Categorical(df_col['correction_method'], categories=hue_correction_order, ordered=True)
    df_col['sample'] = pd.Categorical(df_col['sample'], categories=sample_palette.index, ordered=True)
    df_col.sort_values(['correction_method','sample'],inplace=True)

    col_dict = {'':anno_simple(df_col['correction_method'], colors=count_correction_palette.to_dict(),legend=False,add_text=True),
                }
    if show_samples:
        col_dict[' '] = anno_simple(df_col['sample'], colors={k:v for k,v in sample_palette.items() if k in df_col['sample'].values},legend=True,add_text=False)
    col_ha = HeatmapAnnotation(**col_dict,verbose=0,label_side='left')


    figsize = (10,2.5)
    plt.figure(figsize=figsize)
    cm = DotClustermapPlotter(
        data=df_plot, 
        x='ID',y='Term',value=rank_metric_gsea,c=rank_metric_gsea,
        # x_order=df_col.index,
        s=rank_metric_pvals_log,
        row_cluster=False,col_cluster=False,
        top_annotation=col_ha,
        col_split=df_col['correction_method'],
        col_split_order=[h for h in hue_correction_order if h in df_col['correction_method'].unique()],
        # row_split=False,
        # col_split=df_col.index,
        # col_split_order=df_col.index,
        cmap='bwr',center=0,
        col_split_gap=0,
        show_rownames=True,show_colnames=False,
        row_dendrogram=False,col_dendrogram=False,
        verbose=1,legend_gap=5,linewidths=.5,spines=True,
        # xticklabels_kws={'text':df_col['sample']},
        # vmin = np.percentile(df_plot[rank_metric_gsea],5),
        # vmax = np.percentile(df_plot[rank_metric_gsea],95),
    )
    # cm.data2d.columns =  [s.split('-')[5] for s in cm.data2d.columns ]
    # cm.plot()
    df_plot.to_csv(cfg['figures_dir']+f"heatmap_diffexpr_gsea/heatmap_{ref_condition=}_{ref_panel=}_{ref_segmentation=}.csv")
    plt.savefig(cfg['figures_dir']+f"heatmap_diffexpr_gsea/heatmap_{ref_condition=}_{ref_panel=}_{ref_segmentation=}.pdf",bbox_inches='tight',dpi=300)
    plt.close()
    # plt.show()
# Out:
# NSCLC breast 5µm custom
# NSCLC breast ProSeg custom
# NSCLC lung 5µm custom
# /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/workflow/notebooks/xenium/../../../workflow/scripts/_utils.py:678: PerformanceWarning: indexing past lexsort depth may impact performance.
#   if (cti, ctj) in v.index:
# /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/xenium_paper/workflow/notebooks/xenium/../../../workflow/scripts/_utils.py:679: PerformanceWarning: indexing past lexsort depth may impact performance.
#   df[(correction_method, *k, cti, ctj)] = v.loc[(cti, ctj)].set_index("names").loc[:, rank_metric]
#   3%|▎         | 12/353 [00:06<01:46,  3.21it/s]2026-01-22 14:12:03,008 [WARNING] Duplicated values found in preranked stats: 2.77% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
#   5%|▌         | 18/353 [00:06<00:59,  5.66it/s]2026-01-22 14:12:03,124 [WARNING] Duplicated values found in preranked stats: 0.35% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-22 14:12:03,162 [WARNING] Duplicated values found in preranked stats: 0.69% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
#  10%|█         | 36/353 [00:06<00:18, 16.90it/s]2026-01-22 14:12:03,531 [WARNING] Duplicated values found in preranked stats: 0.35% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
#  13%|█▎        | 47/353 [00:06<00:11, 25.66it/s]2026-01-22 14:12:03,750 [WARNING] Duplicated values found in preranked stats: 1.38% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
#  17%|█▋        | 59/353 [00:07<00:08, 34.64it/s]2026-01-22 14:12:03,954 [WARNING] Input gene rankings contains NA values(gene name and ranking value), drop them all!
# 2026-01-22 14:12:03,991 [WARNING] Input gene rankings contains NA values(gene name and ranking value), drop them all!
# 2026-01-22 14:12:04,013 [WARNING] Input gene rankings contains NA values(gene name and ranking value), drop them all!
#  18%|█▊        | 64/353 [00:07<00:07, 36.38it/s]2026-01-22 14:12:04,034 [WARNING] Input gene rankings contains NA values(gene name and ranking value), drop them all!
# 2026-01-22 14:12:04,056 [WARNING] Input gene rankings contains NA values(gene name and ranking value), drop them all!
# 2026-01-22 14:12:04,078 [WARNING] Input gene rankings contains NA values(gene name and ranking value), drop them all!
# 2026-01-22 14:12:04,100 [WARNING] Input gene rankings contains NA values(gene name and ranking value), drop them all!
# 2026-01-22 14:12:04,121 [WARNING] Input gene rankings contains NA values(gene name and ranking value), drop them all!
#  20%|█▉        | 69/353 [00:07<00:07, 38.59it/s]2026-01-22 14:12:04,143 [WARNING] Input gene rankings contains NA values(gene name and ranking value), drop them all!
# 2026-01-22 14:12:04,164 [WARNING] Input gene rankings contains NA values(gene name and ranking value), drop them all!
# 2026-01-22 14:12:04,186 [WARNING] Input gene rankings contains NA values(gene name and ranking value), drop them all!
# 2026-01-22 14:12:04,207 [WARNING] Input gene rankings contains NA values(gene name and ranking value), drop them all!
# 2026-01-22 14:12:04,228 [WARNING] Input gene rankings contains NA values(gene name and ranking value), drop them all!
#  21%|██        | 74/353 [00:07<00:06, 40.74it/s]2026-01-22 14:12:04,249 [WARNING] Input gene rankings contains NA values(gene name and ranking value), drop them all!
# 2026-01-22 14:12:04,269 [WARNING] Input gene rankings contains NA values(gene name and ranking value), drop them all!
# 2026-01-22 14:12:04,291 [WARNING] Input gene rankings contains NA values(gene name and ranking value), drop them all!
# 2026-01-22 14:12:04,313 [WARNING] Input gene rankings contains NA values(gene name and ranking value), drop them all!
# 2026-01-22 14:12:04,315 [WARNING] Duplicated values found in preranked stats: 0.70% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-22 14:12:04,335 [WARNING] Input gene rankings contains NA values(gene name and ranking value), drop them all!
#  22%|██▏       | 79/353 [00:07<00:06, 42.19it/s]2026-01-22 14:12:04,357 [WARNING] Input gene rankings contains NA values(gene name and ranking value), drop them all!
# 2026-01-22 14:12:04,359 [WARNING] Duplicated values found in preranked stats: 0.70% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-22 14:12:04,378 [WARNING] Input gene rankings contains NA values(gene name and ranking value), drop them all!
# 2026-01-22 14:12:04,400 [WARNING] Input gene rankings contains NA values(gene name and ranking value), drop them all!
# 2026-01-22 14:12:04,402 [WARNING] Duplicated values found in preranked stats: 1.41% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-22 14:12:04,422 [WARNING] Input gene rankings contains NA values(gene name and ranking value), drop them all!
# 2026-01-22 14:12:04,443 [WARNING] Input gene rankings contains NA values(gene name and ranking value), drop them all!
#  24%|██▍       | 84/353 [00:07<00:06, 43.30it/s]2026-01-22 14:12:04,465 [WARNING] Input gene rankings contains NA values(gene name and ranking value), drop them all!
# 2026-01-22 14:12:04,486 [WARNING] Input gene rankings contains NA values(gene name and ranking value), drop them all!
# 2026-01-22 14:12:04,508 [WARNING] Input gene rankings contains NA values(gene name and ranking value), drop them all!
# 2026-01-22 14:12:04,530 [WARNING] Input gene rankings contains NA values(gene name and ranking value), drop them all!
# 2026-01-22 14:12:04,552 [WARNING] Input gene rankings contains NA values(gene name and ranking value), drop them all!
#  25%|██▌       | 89/353 [00:07<00:05, 44.03it/s]2026-01-22 14:12:04,574 [WARNING] Input gene rankings contains NA values(gene name and ranking value), drop them all!
# 2026-01-22 14:12:04,596 [WARNING] Input gene rankings contains NA values(gene name and ranking value), drop them all!
# 2026-01-22 14:12:04,598 [WARNING] Duplicated values found in preranked stats: 1.41% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-22 14:12:04,617 [WARNING] Input gene rankings contains NA values(gene name and ranking value), drop them all!
# 2026-01-22 14:12:04,637 [WARNING] Input gene rankings contains NA values(gene name and ranking value), drop them all!
# 2026-01-22 14:12:04,658 [WARNING] Input gene rankings contains NA values(gene name and ranking value), drop them all!
#  27%|██▋       | 94/353 [00:07<00:05, 45.04it/s]2026-01-22 14:12:04,679 [WARNING] Input gene rankings contains NA values(gene name and ranking value), drop them all!
# 2026-01-22 14:12:04,700 [WARNING] Input gene rankings contains NA values(gene name and ranking value), drop them all!
# 2026-01-22 14:12:04,720 [WARNING] Input gene rankings contains NA values(gene name and ranking value), drop them all!
# 2026-01-22 14:12:04,741 [WARNING] Input gene rankings contains NA values(gene name and ranking value), drop them all!
# 2026-01-22 14:12:04,762 [WARNING] Input gene rankings contains NA values(gene name and ranking value), drop them all!
#  28%|██▊       | 99/353 [00:07<00:05, 45.80it/s]2026-01-22 14:12:04,785 [WARNING] Input gene rankings contains NA values(gene name and ranking value), drop them all!
# 2026-01-22 14:12:04,807 [WARNING] Input gene rankings contains NA values(gene name and ranking value), drop them all!
# 2026-01-22 14:12:04,809 [WARNING] Duplicated values found in preranked stats: 1.06% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-22 14:12:04,829 [WARNING] Input gene rankings contains NA values(gene name and ranking value), drop them all!
# 2026-01-22 14:12:04,849 [WARNING] Input gene rankings contains NA values(gene name and ranking value), drop them all!
# 2026-01-22 14:12:04,870 [WARNING] Input gene rankings contains NA values(gene name and ranking value), drop them all!
#  29%|██▉       | 104/353 [00:08<00:05, 45.94it/s]2026-01-22 14:12:04,892 [WARNING] Input gene rankings contains NA values(gene name and ranking value), drop them all!
# 2026-01-22 14:12:04,913 [WARNING] Input gene rankings contains NA values(gene name and ranking value), drop them all!
# 2026-01-22 14:12:04,935 [WARNING] Input gene rankings contains NA values(gene name and ranking value), drop them all!
# 2026-01-22 14:12:04,956 [WARNING] Input gene rankings contains NA values(gene name and ranking value), drop them all!
# 2026-01-22 14:12:04,976 [WARNING] Input gene rankings contains NA values(gene name and ranking value), drop them all!
#  31%|███       | 109/353 [00:08<00:05, 46.29it/s]2026-01-22 14:12:04,999 [WARNING] Input gene rankings contains NA values(gene name and ranking value), drop them all!
# 2026-01-22 14:12:05,020 [WARNING] Input gene rankings contains NA values(gene name and ranking value), drop them all!
# 2026-01-22 14:12:05,041 [WARNING] Input gene rankings contains NA values(gene name and ranking value), drop them all!
# 2026-01-22 14:12:05,043 [WARNING] Duplicated values found in preranked stats: 1.06% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-22 14:12:05,063 [WARNING] Input gene rankings contains NA values(gene name and ranking value), drop them all!
# 2026-01-22 14:12:05,064 [WARNING] Duplicated values found in preranked stats: 3.17% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-22 14:12:05,084 [WARNING] Input gene rankings contains NA values(gene name and ranking value), drop them all!
#  32%|███▏      | 114/353 [00:08<00:05, 46.30it/s]2026-01-22 14:12:05,106 [WARNING] Input gene rankings contains NA values(gene name and ranking value), drop them all!
# 2026-01-22 14:12:05,127 [WARNING] Input gene rankings contains NA values(gene name and ranking value), drop them all!
# 2026-01-22 14:12:05,148 [WARNING] Input gene rankings contains NA values(gene name and ranking value), drop them all!
# 2026-01-22 14:12:05,169 [WARNING] Input gene rankings contains NA values(gene name and ranking value), drop them all!
# 2026-01-22 14:12:05,190 [WARNING] Input gene rankings contains NA values(gene name and ranking value), drop them all!
#  34%|███▎      | 119/353 [00:08<00:05, 46.74it/s]2026-01-22 14:12:05,211 [WARNING] Input gene rankings contains NA values(gene name and ranking value), drop them all!
# 2026-01-22 14:12:05,231 [WARNING] Input gene rankings contains NA values(gene name and ranking value), drop them all!
# 2026-01-22 14:12:05,233 [WARNING] Duplicated values found in preranked stats: 0.35% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-22 14:12:05,253 [WARNING] Input gene rankings contains NA values(gene name and ranking value), drop them all!
# 2026-01-22 14:12:05,255 [WARNING] Duplicated values found in preranked stats: 46.69% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-22 14:12:05,274 [WARNING] Input gene rankings contains NA values(gene name and ranking value), drop them all!
# 2026-01-22 14:12:05,276 [WARNING] Duplicated values found in preranked stats: 41.85% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-22 14:12:05,295 [WARNING] Input gene rankings contains NA values(gene name and ranking value), drop them all!
# 2026-01-22 14:12:05,297 [WARNING] Duplicated values found in preranked stats: 48.87% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
#  35%|███▌      | 124/353 [00:08<00:04, 46.90it/s]2026-01-22 14:12:05,316 [WARNING] Input gene rankings contains NA values(gene name and ranking value), drop them all!
# 2026-01-22 14:12:05,318 [WARNING] Duplicated values found in preranked stats: 37.69% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-22 14:12:05,338 [WARNING] Input gene rankings contains NA values(gene name and ranking value), drop them all!
# 2026-01-22 14:12:05,340 [WARNING] Duplicated values found in preranked stats: 37.63% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-22 14:12:05,359 [WARNING] Input gene rankings contains NA values(gene name and ranking value), drop them all!
# 2026-01-22 14:12:05,361 [WARNING] Duplicated values found in preranked stats: 32.84% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-22 14:12:05,381 [WARNING] Input gene rankings contains NA values(gene name and ranking value), drop them all!
# 2026-01-22 14:12:05,383 [WARNING] Duplicated values found in preranked stats: 44.81% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-22 14:12:05,403 [WARNING] Input gene rankings contains NA values(gene name and ranking value), drop them all!
# 2026-01-22 14:12:05,404 [WARNING] Duplicated values found in preranked stats: 30.07% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
#  37%|███▋      | 129/353 [00:08<00:04, 46.73it/s]2026-01-22 14:12:05,424 [WARNING] Input gene rankings contains NA values(gene name and ranking value), drop them all!
# 2026-01-22 14:12:05,426 [WARNING] Duplicated values found in preranked stats: 34.32% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-22 14:12:05,446 [WARNING] Input gene rankings contains NA values(gene name and ranking value), drop them all!
# 2026-01-22 14:12:05,448 [WARNING] Duplicated values found in preranked stats: 42.05% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-22 14:12:05,467 [WARNING] Input gene rankings contains NA values(gene name and ranking value), drop them all!
# 2026-01-22 14:12:05,469 [WARNING] Duplicated values found in preranked stats: 48.40% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-22 14:12:05,488 [WARNING] Input gene rankings contains NA values(gene name and ranking value), drop them all!
# 2026-01-22 14:12:05,490 [WARNING] Duplicated values found in preranked stats: 30.71% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-22 14:12:05,508 [WARNING] Input gene rankings contains NA values(gene name and ranking value), drop them all!
# 2026-01-22 14:12:05,511 [WARNING] Duplicated values found in preranked stats: 35.69% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
#  38%|███▊      | 134/353 [00:08<00:04, 46.87it/s]2026-01-22 14:12:05,531 [WARNING] Input gene rankings contains NA values(gene name and ranking value), drop them all!
# 2026-01-22 14:12:05,533 [WARNING] Duplicated values found in preranked stats: 44.76% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-22 14:12:05,551 [WARNING] Input gene rankings contains NA values(gene name and ranking value), drop them all!
# 2026-01-22 14:12:05,554 [WARNING] Duplicated values found in preranked stats: 55.20% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-22 14:12:05,572 [WARNING] Input gene rankings contains NA values(gene name and ranking value), drop them all!
# 2026-01-22 14:12:05,574 [WARNING] Duplicated values found in preranked stats: 53.20% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-22 14:12:05,594 [WARNING] Input gene rankings contains NA values(gene name and ranking value), drop them all!
# 2026-01-22 14:12:05,597 [WARNING] Duplicated values found in preranked stats: 43.45% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-22 14:12:05,616 [WARNING] Input gene rankings contains NA values(gene name and ranking value), drop them all!
# 2026-01-22 14:12:05,618 [WARNING] Duplicated values found in preranked stats: 47.28% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
#  39%|███▉      | 139/353 [00:08<00:04, 46.83it/s]2026-01-22 14:12:05,637 [WARNING] Input gene rankings contains NA values(gene name and ranking value), drop them all!
# 2026-01-22 14:12:05,639 [WARNING] Duplicated values found in preranked stats: 38.89% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-22 14:12:05,658 [WARNING] Input gene rankings contains NA values(gene name and ranking value), drop them all!
# 2026-01-22 14:12:05,660 [WARNING] Duplicated values found in preranked stats: 26.56% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-22 14:12:05,679 [WARNING] Input gene rankings contains NA values(gene name and ranking value), drop them all!
# 2026-01-22 14:12:05,681 [WARNING] Duplicated values found in preranked stats: 32.81% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-22 14:12:05,700 [WARNING] Input gene rankings contains NA values(gene name and ranking value), drop them all!
# 2026-01-22 14:12:05,702 [WARNING] Duplicated values found in preranked stats: 19.55% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-22 14:12:05,721 [WARNING] Input gene rankings contains NA values(gene name and ranking value), drop them all!
# 2026-01-22 14:12:05,723 [WARNING] Duplicated values found in preranked stats: 36.76% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
#  41%|████      | 144/353 [00:08<00:04, 46.99it/s]2026-01-22 14:12:05,743 [WARNING] Input gene rankings contains NA values(gene name and ranking value), drop them all!
# 2026-01-22 14:12:05,745 [WARNING] Duplicated values found in preranked stats: 35.23% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-22 14:12:05,765 [WARNING] Input gene rankings contains NA values(gene name and ranking value), drop them all!
# 2026-01-22 14:12:05,767 [WARNING] Duplicated values found in preranked stats: 43.87% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-22 14:12:05,786 [WARNING] Input gene rankings contains NA values(gene name and ranking value), drop them all!
# 2026-01-22 14:12:05,788 [WARNING] Duplicated values found in preranked stats: 29.25% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-22 14:12:05,809 [WARNING] Input gene rankings contains NA values(gene name and ranking value), drop them all!
# 2026-01-22 14:12:05,811 [WARNING] Duplicated values found in preranked stats: 44.14% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-22 14:12:05,830 [WARNING] Input gene rankings contains NA values(gene name and ranking value), drop them all!
# 2026-01-22 14:12:05,832 [WARNING] Duplicated values found in preranked stats: 31.43% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
#  42%|████▏     | 149/353 [00:09<00:04, 46.65it/s]2026-01-22 14:12:05,852 [WARNING] Input gene rankings contains NA values(gene name and ranking value), drop them all!
# 2026-01-22 14:12:05,854 [WARNING] Duplicated values found in preranked stats: 40.15% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-22 14:12:05,873 [WARNING] Input gene rankings contains NA values(gene name and ranking value), drop them all!
# 2026-01-22 14:12:05,875 [WARNING] Duplicated values found in preranked stats: 34.12% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-22 14:12:05,894 [WARNING] Input gene rankings contains NA values(gene name and ranking value), drop them all!
# 2026-01-22 14:12:05,897 [WARNING] Duplicated values found in preranked stats: 28.24% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-22 14:12:05,915 [WARNING] Input gene rankings contains NA values(gene name and ranking value), drop them all!
# 2026-01-22 14:12:05,917 [WARNING] Duplicated values found in preranked stats: 22.93% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-22 14:12:05,937 [WARNING] Input gene rankings contains NA values(gene name and ranking value), drop them all!
# 2026-01-22 14:12:05,939 [WARNING] Duplicated values found in preranked stats: 35.82% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
#  44%|████▎     | 154/353 [00:09<00:04, 46.66it/s]2026-01-22 14:12:05,959 [WARNING] Input gene rankings contains NA values(gene name and ranking value), drop them all!
# 2026-01-22 14:12:05,961 [WARNING] Duplicated values found in preranked stats: 46.48% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-22 14:12:05,980 [WARNING] Input gene rankings contains NA values(gene name and ranking value), drop them all!
# 2026-01-22 14:12:05,983 [WARNING] Duplicated values found in preranked stats: 35.83% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-22 14:12:06,003 [WARNING] Input gene rankings contains NA values(gene name and ranking value), drop them all!
# 2026-01-22 14:12:06,005 [WARNING] Duplicated values found in preranked stats: 42.97% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-22 14:12:06,026 [WARNING] Input gene rankings contains NA values(gene name and ranking value), drop them all!
# 2026-01-22 14:12:06,028 [WARNING] Duplicated values found in preranked stats: 30.89% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-22 14:12:06,050 [WARNING] Input gene rankings contains NA values(gene name and ranking value), drop them all!
# 2026-01-22 14:12:06,053 [WARNING] Duplicated values found in preranked stats: 31.17% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
#  45%|████▌     | 159/353 [00:09<00:04, 45.75it/s]2026-01-22 14:12:06,074 [WARNING] Input gene rankings contains NA values(gene name and ranking value), drop them all!
# 2026-01-22 14:12:06,076 [WARNING] Duplicated values found in preranked stats: 49.24% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-22 14:12:06,097 [WARNING] Input gene rankings contains NA values(gene name and ranking value), drop them all!
# 2026-01-22 14:12:06,100 [WARNING] Duplicated values found in preranked stats: 57.65% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-22 14:12:06,120 [WARNING] Input gene rankings contains NA values(gene name and ranking value), drop them all!
# 2026-01-22 14:12:06,123 [WARNING] Duplicated values found in preranked stats: 49.80% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-22 14:12:06,143 [WARNING] Input gene rankings contains NA values(gene name and ranking value), drop them all!
# 2026-01-22 14:12:06,145 [WARNING] Duplicated values found in preranked stats: 48.72% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-22 14:12:06,164 [WARNING] Input gene rankings contains NA values(gene name and ranking value), drop them all!
# 2026-01-22 14:12:06,167 [WARNING] Duplicated values found in preranked stats: 37.64% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
#  46%|████▋     | 164/353 [00:09<00:04, 45.33it/s]2026-01-22 14:12:06,186 [WARNING] Input gene rankings contains NA values(gene name and ranking value), drop them all!
# 2026-01-22 14:12:06,188 [WARNING] Duplicated values found in preranked stats: 31.60% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-22 14:12:06,207 [WARNING] Input gene rankings contains NA values(gene name and ranking value), drop them all!
# 2026-01-22 14:12:06,209 [WARNING] Duplicated values found in preranked stats: 42.97% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-22 14:12:06,227 [WARNING] Input gene rankings contains NA values(gene name and ranking value), drop them all!
# 2026-01-22 14:12:06,229 [WARNING] Duplicated values found in preranked stats: 38.31% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-22 14:12:06,247 [WARNING] Input gene rankings contains NA values(gene name and ranking value), drop them all!
# 2026-01-22 14:12:06,249 [WARNING] Duplicated values found in preranked stats: 54.02% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-22 14:12:06,268 [WARNING] Input gene rankings contains NA values(gene name and ranking value), drop them all!
# 2026-01-22 14:12:06,270 [WARNING] Duplicated values found in preranked stats: 42.40% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
#  48%|████▊     | 169/353 [00:09<00:03, 46.21it/s]2026-01-22 14:12:06,289 [WARNING] Input gene rankings contains NA values(gene name and ranking value), drop them all!
# 2026-01-22 14:12:06,291 [WARNING] Duplicated values found in preranked stats: 61.07% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-22 14:12:06,309 [WARNING] Input gene rankings contains NA values(gene name and ranking value), drop them all!
# 2026-01-22 14:12:06,311 [WARNING] Duplicated values found in preranked stats: 41.76% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-22 14:12:06,330 [WARNING] Input gene rankings contains NA values(gene name and ranking value), drop them all!
# 2026-01-22 14:12:06,332 [WARNING] Duplicated values found in preranked stats: 54.79% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-22 14:12:06,350 [WARNING] Input gene rankings contains NA values(gene name and ranking value), drop them all!
# 2026-01-22 14:12:06,353 [WARNING] Duplicated values found in preranked stats: 51.24% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-22 14:12:06,370 [WARNING] Input gene rankings contains NA values(gene name and ranking value), drop them all!
# 2026-01-22 14:12:06,372 [WARNING] Duplicated values found in preranked stats: 57.14% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
#  49%|████▉     | 174/353 [00:09<00:03, 47.11it/s]2026-01-22 14:12:06,391 [WARNING] Input gene rankings contains NA values(gene name and ranking value), drop them all!
# 2026-01-22 14:12:06,393 [WARNING] Duplicated values found in preranked stats: 62.87% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-22 14:12:06,411 [WARNING] Input gene rankings contains NA values(gene name and ranking value), drop them all!
# 2026-01-22 14:12:06,413 [WARNING] Duplicated values found in preranked stats: 64.98% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-22 14:12:06,431 [WARNING] Input gene rankings contains NA values(gene name and ranking value), drop them all!
# 2026-01-22 14:12:06,433 [WARNING] Duplicated values found in preranked stats: 51.61% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-22 14:12:06,451 [WARNING] Input gene rankings contains NA values(gene name and ranking value), drop them all!
# 2026-01-22 14:12:06,453 [WARNING] Duplicated values found in preranked stats: 46.50% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-22 14:12:06,471 [WARNING] Input gene rankings contains NA values(gene name and ranking value), drop them all!
# 2026-01-22 14:12:06,473 [WARNING] Duplicated values found in preranked stats: 57.38% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
#  51%|█████     | 179/353 [00:09<00:03, 47.79it/s]2026-01-22 14:12:06,492 [WARNING] Input gene rankings contains NA values(gene name and ranking value), drop them all!
# 2026-01-22 14:12:06,494 [WARNING] Duplicated values found in preranked stats: 31.02% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-22 14:12:06,513 [WARNING] Input gene rankings contains NA values(gene name and ranking value), drop them all!
# 2026-01-22 14:12:06,515 [WARNING] Duplicated values found in preranked stats: 30.11% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-22 14:12:06,534 [WARNING] Input gene rankings contains NA values(gene name and ranking value), drop them all!
# 2026-01-22 14:12:06,536 [WARNING] Duplicated values found in preranked stats: 47.17% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-22 14:12:06,555 [WARNING] Input gene rankings contains NA values(gene name and ranking value), drop them all!
# 2026-01-22 14:12:06,557 [WARNING] Duplicated values found in preranked stats: 36.92% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-22 14:12:06,575 [WARNING] Input gene rankings contains NA values(gene name and ranking value), drop them all!
# 2026-01-22 14:12:06,577 [WARNING] Duplicated values found in preranked stats: 33.45% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
#  52%|█████▏    | 184/353 [00:09<00:03, 47.66it/s]2026-01-22 14:12:06,598 [WARNING] Input gene rankings contains NA values(gene name and ranking value), drop them all!
# 2026-01-22 14:12:06,599 [WARNING] Duplicated values found in preranked stats: 46.74% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-22 14:12:06,619 [WARNING] Input gene rankings contains NA values(gene name and ranking value), drop them all!
# 2026-01-22 14:12:06,621 [WARNING] Duplicated values found in preranked stats: 37.05% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-22 14:12:06,640 [WARNING] Input gene rankings contains NA values(gene name and ranking value), drop them all!
# 2026-01-22 14:12:06,642 [WARNING] Duplicated values found in preranked stats: 49.62% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-22 14:12:06,661 [WARNING] Input gene rankings contains NA values(gene name and ranking value), drop them all!
# 2026-01-22 14:12:06,663 [WARNING] Duplicated values found in preranked stats: 41.70% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-22 14:12:06,682 [WARNING] Input gene rankings contains NA values(gene name and ranking value), drop them all!
# 2026-01-22 14:12:06,684 [WARNING] Duplicated values found in preranked stats: 39.69% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
#  54%|█████▎    | 189/353 [00:09<00:03, 47.47it/s]2026-01-22 14:12:06,704 [WARNING] Input gene rankings contains NA values(gene name and ranking value), drop them all!
# 2026-01-22 14:12:06,706 [WARNING] Duplicated values found in preranked stats: 55.20% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-22 14:12:06,724 [WARNING] Input gene rankings contains NA values(gene name and ranking value), drop them all!
# 2026-01-22 14:12:06,726 [WARNING] Duplicated values found in preranked stats: 49.60% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-22 14:12:06,744 [WARNING] Input gene rankings contains NA values(gene name and ranking value), drop them all!
# 2026-01-22 14:12:06,746 [WARNING] Duplicated values found in preranked stats: 44.32% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-22 14:12:06,765 [WARNING] Input gene rankings contains NA values(gene name and ranking value), drop them all!
# 2026-01-22 14:12:06,767 [WARNING] Duplicated values found in preranked stats: 31.94% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-22 14:12:06,786 [WARNING] Input gene rankings contains NA values(gene name and ranking value), drop them all!
# 2026-01-22 14:12:06,788 [WARNING] Duplicated values found in preranked stats: 36.58% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
#  55%|█████▍    | 194/353 [00:10<00:03, 47.76it/s]2026-01-22 14:12:06,807 [WARNING] Input gene rankings contains NA values(gene name and ranking value), drop them all!
# 2026-01-22 14:12:06,809 [WARNING] Duplicated values found in preranked stats: 53.23% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-22 14:12:06,827 [WARNING] Input gene rankings contains NA values(gene name and ranking value), drop them all!
# 2026-01-22 14:12:06,829 [WARNING] Duplicated values found in preranked stats: 45.16% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-22 14:12:06,848 [WARNING] Input gene rankings contains NA values(gene name and ranking value), drop them all!
# 2026-01-22 14:12:06,850 [WARNING] Duplicated values found in preranked stats: 51.59% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-22 14:12:06,868 [WARNING] Input gene rankings contains NA values(gene name and ranking value), drop them all!
# 2026-01-22 14:12:06,870 [WARNING] Duplicated values found in preranked stats: 47.44% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-22 14:12:06,888 [WARNING] Input gene rankings contains NA values(gene name and ranking value), drop them all!
# 2026-01-22 14:12:06,890 [WARNING] Duplicated values found in preranked stats: 36.95% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
#  56%|█████▋    | 199/353 [00:10<00:03, 47.95it/s]2026-01-22 14:12:06,910 [WARNING] Input gene rankings contains NA values(gene name and ranking value), drop them all!
# 2026-01-22 14:12:06,912 [WARNING] Duplicated values found in preranked stats: 37.94% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-22 14:12:06,932 [WARNING] Input gene rankings contains NA values(gene name and ranking value), drop them all!
# 2026-01-22 14:12:06,934 [WARNING] Duplicated values found in preranked stats: 36.86% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-22 14:12:06,953 [WARNING] Input gene rankings contains NA values(gene name and ranking value), drop them all!
# 2026-01-22 14:12:06,955 [WARNING] Duplicated values found in preranked stats: 33.21% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-22 14:12:06,974 [WARNING] Input gene rankings contains NA values(gene name and ranking value), drop them all!
# 2026-01-22 14:12:06,976 [WARNING] Duplicated values found in preranked stats: 19.48% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-22 14:12:06,996 [WARNING] Input gene rankings contains NA values(gene name and ranking value), drop them all!
# 2026-01-22 14:12:06,998 [WARNING] Duplicated values found in preranked stats: 30.35% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
#  58%|█████▊    | 204/353 [00:10<00:03, 47.54it/s]2026-01-22 14:12:07,017 [WARNING] Input gene rankings contains NA values(gene name and ranking value), drop them all!
# 2026-01-22 14:12:07,019 [WARNING] Duplicated values found in preranked stats: 32.18% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-22 14:12:07,039 [WARNING] Input gene rankings contains NA values(gene name and ranking value), drop them all!
# 2026-01-22 14:12:07,041 [WARNING] Duplicated values found in preranked stats: 45.85% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-22 14:12:07,060 [WARNING] Input gene rankings contains NA values(gene name and ranking value), drop them all!
# 2026-01-22 14:12:07,062 [WARNING] Duplicated values found in preranked stats: 43.53% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-22 14:12:07,081 [WARNING] Input gene rankings contains NA values(gene name and ranking value), drop them all!
# 2026-01-22 14:12:07,083 [WARNING] Duplicated values found in preranked stats: 35.77% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-22 14:12:07,102 [WARNING] Input gene rankings contains NA values(gene name and ranking value), drop them all!
# 2026-01-22 14:12:07,104 [WARNING] Duplicated values found in preranked stats: 42.41% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
#  59%|█████▉    | 209/353 [00:10<00:03, 47.50it/s]2026-01-22 14:12:07,122 [WARNING] Input gene rankings contains NA values(gene name and ranking value), drop them all!
# 2026-01-22 14:12:07,124 [WARNING] Duplicated values found in preranked stats: 29.41% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-22 14:12:07,143 [WARNING] Input gene rankings contains NA values(gene name and ranking value), drop them all!
# 2026-01-22 14:12:07,146 [WARNING] Duplicated values found in preranked stats: 36.19% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-22 14:12:07,164 [WARNING] Input gene rankings contains NA values(gene name and ranking value), drop them all!
# 2026-01-22 14:12:07,166 [WARNING] Duplicated values found in preranked stats: 28.68% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-22 14:12:07,185 [WARNING] Input gene rankings contains NA values(gene name and ranking value), drop them all!
# 2026-01-22 14:12:07,188 [WARNING] Duplicated values found in preranked stats: 17.67% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-22 14:12:07,208 [WARNING] Input gene rankings contains NA values(gene name and ranking value), drop them all!
# 2026-01-22 14:12:07,209 [WARNING] Duplicated values found in preranked stats: 34.70% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
#  61%|██████    | 214/353 [00:10<00:02, 47.37it/s]2026-01-22 14:12:07,229 [WARNING] Input gene rankings contains NA values(gene name and ranking value), drop them all!
# 2026-01-22 14:12:07,231 [WARNING] Duplicated values found in preranked stats: 34.66% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-22 14:12:07,249 [WARNING] Input gene rankings contains NA values(gene name and ranking value), drop them all!
# 2026-01-22 14:12:07,251 [WARNING] Duplicated values found in preranked stats: 42.63% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-22 14:12:07,269 [WARNING] Input gene rankings contains NA values(gene name and ranking value), drop them all!
# 2026-01-22 14:12:07,271 [WARNING] Duplicated values found in preranked stats: 33.20% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-22 14:12:07,289 [WARNING] Input gene rankings contains NA values(gene name and ranking value), drop them all!
# 2026-01-22 14:12:07,291 [WARNING] Duplicated values found in preranked stats: 40.64% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-22 14:12:07,310 [WARNING] Input gene rankings contains NA values(gene name and ranking value), drop them all!
# 2026-01-22 14:12:07,312 [WARNING] Duplicated values found in preranked stats: 39.77% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
#  62%|██████▏   | 219/353 [00:10<00:02, 47.78it/s]2026-01-22 14:12:07,332 [WARNING] Input gene rankings contains NA values(gene name and ranking value), drop them all!
# 2026-01-22 14:12:07,334 [WARNING] Duplicated values found in preranked stats: 44.66% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-22 14:12:07,353 [WARNING] Input gene rankings contains NA values(gene name and ranking value), drop them all!
# 2026-01-22 14:12:07,355 [WARNING] Duplicated values found in preranked stats: 36.36% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-22 14:12:07,374 [WARNING] Input gene rankings contains NA values(gene name and ranking value), drop them all!
# 2026-01-22 14:12:07,376 [WARNING] Duplicated values found in preranked stats: 29.74% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-22 14:12:07,397 [WARNING] Input gene rankings contains NA values(gene name and ranking value), drop them all!
# 2026-01-22 14:12:07,399 [WARNING] Duplicated values found in preranked stats: 52.36% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-22 14:12:07,418 [WARNING] Input gene rankings contains NA values(gene name and ranking value), drop them all!
# 2026-01-22 14:12:07,421 [WARNING] Duplicated values found in preranked stats: 48.82% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
#  63%|██████▎   | 224/353 [00:10<00:02, 47.21it/s]2026-01-22 14:12:07,440 [WARNING] Input gene rankings contains NA values(gene name and ranking value), drop them all!
# 2026-01-22 14:12:07,442 [WARNING] Duplicated values found in preranked stats: 56.32% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-22 14:12:07,461 [WARNING] Input gene rankings contains NA values(gene name and ranking value), drop them all!
# 2026-01-22 14:12:07,463 [WARNING] Duplicated values found in preranked stats: 41.98% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-22 14:12:07,483 [WARNING] Input gene rankings contains NA values(gene name and ranking value), drop them all!
# 2026-01-22 14:12:07,485 [WARNING] Duplicated values found in preranked stats: 45.05% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-22 14:12:07,505 [WARNING] Input gene rankings contains NA values(gene name and ranking value), drop them all!
# 2026-01-22 14:12:07,507 [WARNING] Duplicated values found in preranked stats: 42.69% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-22 14:12:07,526 [WARNING] Input gene rankings contains NA values(gene name and ranking value), drop them all!
# 2026-01-22 14:12:07,528 [WARNING] Duplicated values found in preranked stats: 61.48% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
#  65%|██████▍   | 229/353 [00:10<00:02, 47.05it/s]2026-01-22 14:12:07,548 [WARNING] Input gene rankings contains NA values(gene name and ranking value), drop them all!
# 2026-01-22 14:12:07,550 [WARNING] Duplicated values found in preranked stats: 44.67% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-22 14:12:07,569 [WARNING] Input gene rankings contains NA values(gene name and ranking value), drop them all!
# 2026-01-22 14:12:07,571 [WARNING] Duplicated values found in preranked stats: 52.05% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-22 14:12:07,589 [WARNING] Input gene rankings contains NA values(gene name and ranking value), drop them all!
# 2026-01-22 14:12:07,591 [WARNING] Duplicated values found in preranked stats: 49.24% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-22 14:12:07,610 [WARNING] Input gene rankings contains NA values(gene name and ranking value), drop them all!
# 2026-01-22 14:12:07,612 [WARNING] Duplicated values found in preranked stats: 40.38% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-22 14:12:07,630 [WARNING] Input gene rankings contains NA values(gene name and ranking value), drop them all!
# 2026-01-22 14:12:07,632 [WARNING] Duplicated values found in preranked stats: 61.76% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
#  66%|██████▋   | 234/353 [00:10<00:02, 47.46it/s]2026-01-22 14:12:07,651 [WARNING] Input gene rankings contains NA values(gene name and ranking value), drop them all!
# 2026-01-22 14:12:07,653 [WARNING] Duplicated values found in preranked stats: 48.19% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-22 14:12:07,671 [WARNING] Input gene rankings contains NA values(gene name and ranking value), drop them all!
# 2026-01-22 14:12:07,673 [WARNING] Duplicated values found in preranked stats: 48.35% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-22 14:12:07,691 [WARNING] Input gene rankings contains NA values(gene name and ranking value), drop them all!
# 2026-01-22 14:12:07,693 [WARNING] Duplicated values found in preranked stats: 62.66% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-22 14:12:07,712 [WARNING] Input gene rankings contains NA values(gene name and ranking value), drop them all!
# 2026-01-22 14:12:07,715 [WARNING] Duplicated values found in preranked stats: 49.57% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-22 14:12:07,734 [WARNING] Duplicated values found in preranked stats: 10.03% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
#  69%|██████▉   | 244/353 [00:11<00:02, 48.01it/s]2026-01-22 14:12:07,940 [WARNING] Duplicated values found in preranked stats: 10.38% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
#  71%|███████   | 249/353 [00:11<00:02, 48.19it/s]2026-01-22 14:12:08,020 [WARNING] Duplicated values found in preranked stats: 0.35% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-22 14:12:08,041 [WARNING] Duplicated values found in preranked stats: 0.35% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
#  72%|███████▏  | 254/353 [00:11<00:02, 48.38it/s]2026-01-22 14:12:08,063 [WARNING] Duplicated values found in preranked stats: 0.35% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-22 14:12:08,084 [WARNING] Duplicated values found in preranked stats: 0.35% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-22 14:12:08,105 [WARNING] Duplicated values found in preranked stats: 0.69% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-22 14:12:08,126 [WARNING] Duplicated values found in preranked stats: 0.35% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
#  73%|███████▎  | 259/353 [00:11<00:01, 48.39it/s]2026-01-22 14:12:08,242 [WARNING] Duplicated values found in preranked stats: 2.42% of genes
# ...
# 2026-01-22 14:15:04,747 [WARNING] Duplicated values found in preranked stats: 36.00% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
#  66%|██████▌   | 340/518 [00:07<00:03, 51.02it/s]2026-01-22 14:15:04,764 [WARNING] Input gene rankings contains NA values(gene name and ranking value), drop them all!
# 2026-01-22 14:15:04,767 [WARNING] Duplicated values found in preranked stats: 41.23% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-22 14:15:04,783 [WARNING] Input gene rankings contains NA values(gene name and ranking value), drop them all!
# 2026-01-22 14:15:04,785 [WARNING] Duplicated values found in preranked stats: 41.15% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
#  67%|██████▋   | 346/518 [00:07<00:03, 50.54it/s]2026-01-22 14:15:04,906 [WARNING] Duplicated values found in preranked stats: 4.41% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-22 14:15:04,927 [WARNING] Duplicated values found in preranked stats: 1.47% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-22 14:15:04,989 [WARNING] Duplicated values found in preranked stats: 0.29% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
#  68%|██████▊   | 352/518 [00:07<00:03, 49.87it/s]2026-01-22 14:15:05,010 [WARNING] Duplicated values found in preranked stats: 1.18% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
#  69%|██████▉   | 357/518 [00:07<00:03, 49.25it/s]2026-01-22 14:15:05,115 [WARNING] Duplicated values found in preranked stats: 0.29% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-22 14:15:05,197 [WARNING] Duplicated values found in preranked stats: 0.29% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
#  70%|██████▉   | 362/518 [00:07<00:03, 48.94it/s]2026-01-22 14:15:05,239 [WARNING] Duplicated values found in preranked stats: 2.65% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-22 14:15:05,259 [WARNING] Duplicated values found in preranked stats: 3.24% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-22 14:15:05,282 [WARNING] Duplicated values found in preranked stats: 0.29% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
#  71%|███████   | 367/518 [00:07<00:03, 48.39it/s]2026-01-22 14:15:05,325 [WARNING] Duplicated values found in preranked stats: 0.29% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
#  72%|███████▏  | 372/518 [00:07<00:03, 48.22it/s]2026-01-22 14:15:05,514 [WARNING] Duplicated values found in preranked stats: 3.24% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
#  73%|███████▎  | 377/518 [00:07<00:02, 47.85it/s]2026-01-22 14:15:05,536 [WARNING] Duplicated values found in preranked stats: 2.65% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-22 14:15:05,558 [WARNING] Duplicated values found in preranked stats: 0.29% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-22 14:15:05,622 [WARNING] Duplicated values found in preranked stats: 7.06% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
#  75%|███████▍  | 387/518 [00:08<00:02, 44.53it/s]2026-01-22 14:15:05,857 [WARNING] Duplicated values found in preranked stats: 6.47% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
#  76%|███████▌  | 392/518 [00:08<00:02, 45.16it/s]2026-01-22 14:15:05,880 [WARNING] Duplicated values found in preranked stats: 2.94% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-22 14:15:05,943 [WARNING] Duplicated values found in preranked stats: 2.06% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
#  79%|███████▊  | 407/518 [00:08<00:02, 45.74it/s]2026-01-22 14:15:06,206 [WARNING] Duplicated values found in preranked stats: 6.76% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-22 14:15:06,228 [WARNING] Duplicated values found in preranked stats: 1.18% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
#  81%|████████  | 417/518 [00:08<00:02, 46.98it/s]2026-01-22 14:15:06,436 [WARNING] Duplicated values found in preranked stats: 0.29% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-22 14:15:06,498 [WARNING] Input gene rankings contains NA values(gene name and ranking value), drop them all!
# 2026-01-22 14:15:06,501 [WARNING] Duplicated values found in preranked stats: 13.86% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
#  81%|████████▏ | 422/518 [00:08<00:02, 46.88it/s]2026-01-22 14:15:06,521 [WARNING] Duplicated values found in preranked stats: 3.24% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-22 14:15:06,542 [WARNING] Duplicated values found in preranked stats: 3.82% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
#  82%|████████▏ | 427/518 [00:08<00:01, 47.14it/s]2026-01-22 14:15:06,626 [WARNING] Duplicated values found in preranked stats: 0.29% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
#  83%|████████▎ | 432/518 [00:09<00:01, 47.58it/s]2026-01-22 14:15:06,795 [WARNING] Duplicated values found in preranked stats: 0.59% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-22 14:15:06,819 [WARNING] Duplicated values found in preranked stats: 1.76% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
#  84%|████████▍ | 437/518 [00:09<00:01, 46.53it/s]2026-01-22 14:15:06,842 [WARNING] Duplicated values found in preranked stats: 10.00% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-22 14:15:06,866 [WARNING] Duplicated values found in preranked stats: 4.12% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
#  85%|████████▌ | 442/518 [00:09<00:01, 45.94it/s]2026-01-22 14:15:06,954 [WARNING] Duplicated values found in preranked stats: 0.29% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-22 14:15:07,038 [WARNING] Duplicated values found in preranked stats: 1.18% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
#  86%|████████▋ | 447/518 [00:09<00:01, 46.30it/s]2026-01-22 14:15:07,060 [WARNING] Duplicated values found in preranked stats: 0.59% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-22 14:15:07,081 [WARNING] Duplicated values found in preranked stats: 0.59% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-22 14:15:07,142 [WARNING] Duplicated values found in preranked stats: 5.88% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
#  87%|████████▋ | 452/518 [00:09<00:01, 47.00it/s]2026-01-22 14:15:07,163 [WARNING] Duplicated values found in preranked stats: 4.71% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-22 14:15:07,184 [WARNING] Duplicated values found in preranked stats: 0.59% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-22 14:15:07,225 [WARNING] Duplicated values found in preranked stats: 1.18% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-22 14:15:07,246 [WARNING] Duplicated values found in preranked stats: 0.88% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
#  88%|████████▊ | 457/518 [00:09<00:01, 47.29it/s]2026-01-22 14:15:07,348 [WARNING] Duplicated values found in preranked stats: 0.59% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
#  89%|████████▉ | 462/518 [00:09<00:01, 47.76it/s]2026-01-22 14:15:07,369 [WARNING] Duplicated values found in preranked stats: 0.59% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-22 14:15:07,411 [WARNING] Duplicated values found in preranked stats: 4.71% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-22 14:15:07,453 [WARNING] Duplicated values found in preranked stats: 6.47% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
#  90%|█████████ | 467/518 [00:09<00:01, 47.76it/s]2026-01-22 14:15:07,494 [WARNING] Duplicated values found in preranked stats: 0.29% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
#  91%|█████████ | 472/518 [00:09<00:00, 48.03it/s]2026-01-22 14:15:07,618 [WARNING] Duplicated values found in preranked stats: 0.59% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-22 14:15:07,639 [WARNING] Duplicated values found in preranked stats: 0.88% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
#  92%|█████████▏| 477/518 [00:10<00:00, 48.09it/s]2026-01-22 14:15:07,720 [WARNING] Duplicated values found in preranked stats: 4.71% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-22 14:15:07,740 [WARNING] Input gene rankings contains NA values(gene name and ranking value), drop them all!
# 2026-01-22 14:15:07,742 [WARNING] Duplicated values found in preranked stats: 11.21% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-22 14:15:07,763 [WARNING] Duplicated values found in preranked stats: 7.35% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
#  94%|█████████▍| 487/518 [00:10<00:00, 48.35it/s]2026-01-22 14:15:07,886 [WARNING] Duplicated values found in preranked stats: 0.59% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-22 14:15:07,985 [WARNING] Duplicated values found in preranked stats: 0.29% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
#  95%|█████████▌| 493/518 [00:10<00:00, 48.85it/s]2026-01-22 14:15:08,006 [WARNING] Duplicated values found in preranked stats: 0.88% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-22 14:15:08,028 [WARNING] Duplicated values found in preranked stats: 2.06% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-22 14:15:08,049 [WARNING] Input gene rankings contains NA values(gene name and ranking value), drop them all!
# 2026-01-22 14:15:08,051 [WARNING] Duplicated values found in preranked stats: 11.50% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-22 14:15:08,073 [WARNING] Duplicated values found in preranked stats: 0.29% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
#  96%|█████████▌| 498/518 [00:10<00:00, 48.17it/s]2026-01-22 14:15:08,114 [WARNING] Duplicated values found in preranked stats: 0.29% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
#  97%|█████████▋| 503/518 [00:10<00:00, 48.34it/s]2026-01-22 14:15:08,236 [WARNING] Duplicated values found in preranked stats: 0.59% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-22 14:15:08,257 [WARNING] Duplicated values found in preranked stats: 0.29% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
#  98%|█████████▊| 508/518 [00:10<00:00, 48.42it/s]2026-01-22 14:15:08,340 [WARNING] Duplicated values found in preranked stats: 5.88% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-22 14:15:08,361 [WARNING] Duplicated values found in preranked stats: 0.29% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-22 14:15:08,381 [WARNING] Duplicated values found in preranked stats: 6.47% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-22 14:15:08,403 [WARNING] Duplicated values found in preranked stats: 0.29% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 100%|██████████| 518/518 [00:10<00:00, 47.70it/s]
# /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/jbac/miniforge3/envs/spatial/lib/python3.13/site-packages/PyComplexHeatmap/dotHeatmap.py:360: FutureWarning: The provided callable <function mean at 0x7fb33834b4c0> is currently using DataFrameGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   data2d = data.pivot_table(
# /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/jbac/miniforge3/envs/spatial/lib/python3.13/site-packages/PyComplexHeatmap/dotHeatmap.py:379: FutureWarning: The provided callable <function mean at 0x7fb33834b4c0> is currently using DataFrameGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   self.kwargs["s"] = data.pivot_table(
# /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/jbac/miniforge3/envs/spatial/lib/python3.13/site-packages/PyComplexHeatmap/dotHeatmap.py:395: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   self.kwargs["s"]=self.kwargs["s"].applymap(lambda x:(x-self.smin)/delta)
# /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/jbac/miniforge3/envs/spatial/lib/python3.13/site-packages/PyComplexHeatmap/dotHeatmap.py:409: FutureWarning: The provided callable <function mean at 0x7fb33834b4c0> is currently using DataFrameGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   self.kwargs["c"] = data.pivot_table(
# /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/jbac/miniforge3/envs/spatial/lib/python3.13/site-packages/PyComplexHeatmap/clustermap.py:1836: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   col_clusters = self.col_split.groupby(cols).apply(
# /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/jbac/miniforge3/envs/spatial/lib/python3.13/site-packages/PyComplexHeatmap/clustermap.py:1836: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   col_clusters = self.col_split.groupby(cols).apply(
# Starting plotting..
# Starting calculating row orders..
# Reordering rows..
# Starting calculating col orders..
# Reordering cols..
# Plotting matrix..
# Inferred max_s (max size of scatter point) is: 39.40240232962737
# Collecting legends..
# Plotting legends..
# Estimated legend width: 39.68888888888889 mm
# Incresing ncol
